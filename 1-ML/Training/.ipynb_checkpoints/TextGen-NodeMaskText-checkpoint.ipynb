# %% [markdown]
# #### textgenrnn is a Python module on top of Keras/TensorFlow which can easily generate text using a pretrained recurrent neural network developped by Max Woolf

# %% [markdown]
# check that the dataset text are in the same path or indicate the path
# files in python 3 are called within '' and not "" !!!

# %%
pwd
# Out:
# '/Users/macbookpro/Documents/2018Sept/Dada2018/1-ML/Training'

# %%
import nltk
import csv
from textgenrnn import textgenrnn

textgen = textgenrnn()
textgen.reset()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### train the model with a text from data set : Train on New Text for getting a general feeling and the grammar
# ### need to convert into csv format any text via google sheet or excel or numbers , transpose rows to cols

# %%
testimonial = TextBlob("Masking is fun")
print(testimonial.sentiment)
print(testimonial.sentiment.polarity)
# Out:
# Sentiment(polarity=0.3, subjectivity=0.2)
# 0.3

# %%
import csv
from textblob import TextBlob

infile = '../dataset/alice_ozCol.csv'
f= open(infile,'r')
message = f.read()

blob = TextBlob(message)
print (blob.sentiment)
f.close()
# Out:
# Sentiment(polarity=0.06292335672037891, subjectivity=0.500061743642536)

# %%
import csv
from textblob import TextBlob

infile = '../dataset/nodeMaskText.txt'
f= open(infile,'r')
message = f.read()

blob = TextBlob(message)
print (blob.sentiment)
f.close()
# Out:
# Sentiment(polarity=0.07378787878787878, subjectivity=0.485)

# %%
import csv
from textblob import TextBlob

infile = '../dataset/Manifesto.txt'
f= open(infile,'r')
message = f.read()
blob = TextBlob(message[1])
print(blob.sentiment)
f.close()
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
file_path = '../dataset/alice_ozCol.csv'


textgen.reset()
textgen.train_from_file(file_path,
                        new_model=True,
                        max_length=5,
                        num_epochs=20,
                        gen_epochs=5,
                        word_level=True)
# Out:
# 254 texts collected.
# Training new model w/ 2-layer, 128-cell LSTMs
# Training on 50,460 word sequences.
# Epoch 1/20
# 394/394 [==============================] - 70s 177ms/step - loss: 5.0899
# Epoch 2/20
# 394/394 [==============================] - 68s 173ms/step - loss: 4.1094
# Epoch 3/20
# 394/394 [==============================] - 69s 174ms/step - loss: 3.6138
# Epoch 4/20
# 394/394 [==============================] - 67s 171ms/step - loss: 3.1444
# Epoch 5/20
# 394/394 [==============================] - 64s 162ms/step - loss: 2.6923
# ####################
# Temperature: 0.2
# ####################
# and when they had not gone through this country , when they had been running on the road of yellow brick . when they had been running out of anything . ' ' i ' m afraid i ' m not a coward . you see , said the scarecrow . the lion was a large sharp chin . the tin woodman had been so long and the rest of the baby , and the queen had no brains , said the scarecrow . the lion was a little label , with a crash of delight , and the queen had no heart , said the scarecrow . the lion was a very grave voice : ' but i ' m not a coward ! ' said the king , ' and the moral of that is - but i ' m not a coward , said the scarecrow . the lion looked at the top of the queen , and the hatter was over . ' i ' ve tried to be a man . ' the hatter said , ' that ' s enough , ' said the king , ' and the moral of that is - but i ' m not a coward ! ' said alice , ' and i ' m afraid i ' ve been changed for some of them , and the queen had no heart , said the scarecrow . the lion was a little label , with a sigh of great relief . ' i ' m afraid i ' m not ada , ' said alice , ' and i ' m not a coward ! ' said the mouse , with a smile of the east , and the people came to away from the road
#
# ' a bright idea what was sitting on . alice soon found herself lying down the chimney , and he often growled in an unfriendly way at the scarecrow . its head was a small sack stuffed with straw , with one round the woodman ' s over ! ' cried the queen , and here , or i would have to know how he is , said the tin woodman . it will be , said the lion . so , as they went on which the river had carried them . there was a great cornfield beyond the fence , and not far away she saw the mock turtle in the distance , sitting sad and lonely on a little ledge of rock , and , as they came nearer , alice could hear him sighing as if his heart would break . this same thing she quite enough to say well in your flamingo and make one happy . ' thought the mouse , he had never come on your back , my thanked and raft is my ever ? who for we are still in this creature ? her face in a voice of thought
#
# and , when they had come back with the thinking of the jury ? asked the lion . her next was puzzled by this , so she tried the effect of lying down with one elbow against the door , and the other arm curled round her head . still she went on growing , and growing , and very soon had come attended to the farmer . ' ' smaller , i ' ve had such a dear i like severely to your walk after a while - knife . so they kept on toto beside her heard the scarecrow . it was such a well say . ' how shall i begin ? ' ' i didn ' t mine be hungry , for a great oz will ever to get to the land of us . the woodman ' s heart , so she tried to see how she get them out again , and of bright eyes again , but the dormouse crossed over the other side of the court . all this time i didn ' t know it was written down the same size to dorothy to see with history . first , ' the hatter went on in an mournful tone , ' he won ' t stand beating . now , if he had not been lying on the soft bed she might have been hurt . when it was left alone the house did not know what to say to this , for all the people seemed to think her a witch , and she knew very well she was only an ordinary little girl who had come by the chance of a cyclone into a strange land . when she had tired watching the dancing , boq led
#
# but , brains you tried to you how you see - good - a - way in the world . dorothy did not say anything , for she was puzzled to know which of her two little animal and confusion , said the scarecrow thoughtfully , for you must sleep , and eat and drink . however , you have brains , and it is the same at the south , said another , for this was my first glimpse of the world . ' have i really ? ' the jury mouse caught in a sulky tone , as it settled down again into its nest . alice crouched down among the trees as well . there was no on one on the other side . they were all greatly pleased to see how she added them

# %% [markdown]
# #### generate a text of 5 new sentences, from the recent training in a file : textgenrnn_texts

# %%
textgen.generate_to_file('../dataset/textgenrnn_texts.txt', n=5)
infile = '../dataset/textgenrnn_texts.txt'
f= open(infile,'r')
message = f.read()
print (message)
f.close()
# Out:
# [TOMT][Movie] My first tattoo from how many long days don't all have to recommend personal to the time I was a bit of a mastery to play the water to see an interview and go on the last woman to find my life
# Reunited this weekend and I feel like I don't want you and they are in the game."
# I was taking a long time to keep the time to give up for a new setup and her home and is this a real spirit.
# [AMA Request] Please help me find the car to look at my husband
# I was a street of a way to be allowed to remember this to help bill that patches to approach in windows 10 posts and says "I think I was having one of the states of last night.

# %% [markdown]
# #### merge the dataset file with the new generated sentences into a new file, : new_texts

# %% [markdown]
# #### read the file of generated titles to check

# %%
textgen.reset()

# %% [markdown]
# texts = ['Put the mask on your face, and become a node', 'between 0 and 1',
#             'This is the marionette', 'the Network is Blind', 'Internet is Myopic',
#          'the puppet is Workaholic', ' the Network is a Trail', ' the interface is Sniffing',
#          'the interface is a Collective Traveller',
#          ' sensor is on', 'sensor is off', 'the code is binary',' shadows are invisible ',
#          'we are the machines',' Ask the marionette',' a puppet never dies',
#          'we are humans','Signals that are not repeated or repeatable die',
#          ' we are extended','body never lies','how to fit them together?',
#          'we are the bodies','the code is a node',
#          ' we occupy the collective chimera we are offered and become characters , not marionettes, in the ongoing drama inadequately called Big Data',
#          'the masks are the bodies','we are the network','who are you',' where are you'
#          'what are you','we are the mask on the nodes','we are the mask on your bikes',
#          'the puppet is entangled','the puppet is a paranode',
#          'the puppet is a Collective Traveller',
#          'humans and machines together as beings that repeat',
#          ' network of humans and machines','the code is a Collective Traveller',
# ' the interface is a Collective Traveller','01','10','11','00',
#          'network is entangled','you are the product being sold',' unnetwork the nodes',
#          'shadows are invisible not repeated on the bodies',' the code that is a paranode',
#             'Playing the nodes, playing the paranodes','the code is humans',
#          'we are the mask on your face, and become a node',
#          'networks are plural, fluid, and overlapping',
#          'Puppet, Marionette, Glove','Humans build computers but are folded in return',
#             'Internet is a rhizome, Habits, Costume','the puppet is Blind',
#          'the code are the bodies','the code is a Collective Traveller',
#          'Ask the marionette','sensor is off','Internet is myopic']
#
# textgen.train_on_texts(texts, num_epochs=10,  gen_epochs=2)

# %% [markdown]
# ### train on different texts in the dataset

# %%
textgen.reset()
textgen.train_from_file('../dataset/nodeMaskText.txt',
                        num_epochs=10, gen_epochs =2)

print(textgen.model.summary())
# Out:
# 188 texts collected.
# Training on 5,802 character sequences.
# Epoch 1/10
# 45/45 [==============================] - 15s 335ms/step - loss: 1.1980
# Epoch 2/10
# 45/45 [==============================] - 15s 339ms/step - loss: 0.5980
# ####################
# Temperature: 0.2
# ####################
# the machines is a paranode
#
# the code is a paranode
#
# the machines is a paranode
#
# ####################
# Temperature: 0.5
# ####################
# the mask is on you
#
# the code is a proof.
#
# the marionettes is a proof.
#
# ####################
# Temperature: 1.0
# ####################
# Ask the never network is efare
#
# the mailies in node
#
# we are tied
#
# Epoch 3/10
# 45/45 [==============================] - 16s 367ms/step - loss: 0.4619
# Epoch 4/10
# 45/45 [==============================] - 18s 397ms/step - loss: 0.3946
# ####################
# Temperature: 0.2
# ####################
# the code is a Collective Traveller
#
# the code is a Collective Traveller
#
# the code is a Collective Traveller
#
# ####################
# Temperature: 0.5
# ####################
# the puppet is a paranode
#
# humans and machines
#
# Playing the Network is a Condition
#
# ####################
# Temperature: 1.0
# ####################
# the interface things shoulders
#
# shadows are invisible
#
# playing the nodes
#
# Epoch 5/10
# 45/45 [==============================] - 17s 376ms/step - loss: 0.3332
# Epoch 6/10
# 45/45 [==============================] - 18s 392ms/step - loss: 0.3060
# ####################
# Temperature: 0.2
# ####################
# the puppet is a Collective Traveller
#
# the puppet is a Collective Traveller
#
# the puppet is a Collective Traveller
#
# ####################
# Temperature: 0.5
# ####################
# the code is a series of repeatable things.
#
# we are the mask on your face
#
# we are the mask on your face
#
# ####################
# Temperature: 1.0
# ####################
# snapchat is humans
#
# humans pure as Blind
#
# we are the mask on your proor, become peong's for machines
#
# Epoch 7/10
# 45/45 [==============================] - 18s 395ms/step - loss: 0.2751
# Epoch 8/10
# 45/45 [==============================] - 17s 377ms/step - loss: 0.2532
# ####################
# Temperature: 0.2
# ####################
# the code is a Collective Traveller
#
# the code is a Collective Traveller
#
# the masks are the bodies
#
# ####################
# Temperature: 0.5
# ####################
# the code is a Collective Traveller
#
# who are you
#
# we are extended
#
# ####################
# Temperature: 1.0
# ####################
# humans as the update.
#
# Facebooks repeatable the bodies
#
# Thongs run on ongoing are in the ongoing node
#
# Epoch 9/10
# 45/45 [==============================] - 17s 371ms/step - loss: 0.2380
# Epoch 10/10
# 45/45 [==============================] - 18s 389ms/step - loss: 0.2260
# ####################
# Temperature: 0.2
# ####################
# the code is a Collective Traveller
#
# the code is a Collective Traveller
#
# the code is a Collective Traveller
#
# ####################
# Temperature: 0.5
# ####################
# the code is a Collective Traveller
#
# Habits are things that are for the series.
#
# the code is binary
#
# ####################
# Temperature: 1.0
# ####################
# we are the machines
#
# machines is a particularly update.
#
# Ask the marionette
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 40)           0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 40, 100)      46500       input[0][0]
# __________________________________________________________________________________________________
# rnn_1 (LSTM)                    (None, 40, 128)      117248      embedding[0][0]
# __________________________________________________________________________________________________
# rnn_2 (LSTM)                    (None, 40, 128)      131584      rnn_1[0][0]
# __________________________________________________________________________________________________
# rnn_concat (Concatenate)        (None, 40, 356)      0           embedding[0][0]
#                                                                  rnn_1[0][0]
#                                                                  rnn_2[0][0]
# __________________________________________________________________________________________________
# attention (AttentionWeightedAve (None, 356)          356         rnn_concat[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 465)          166005      attention[0][0]
# ==================================================================================================
# Total params: 461,693
# Trainable params: 461,693
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
textgen.train_from_file('../dataset/NewMediaWriters.txt',
                        num_epochs=10, gen_epochs =2)

print(textgen.model.summary())
# Out:
# 39 texts collected.
# Training on 2,859 character sequences.
# Epoch 1/10
# 22/22 [==============================] - 7s 305ms/step - loss: 0.6075
# Epoch 2/10
# 22/22 [==============================] - 7s 337ms/step - loss: 0.5926
# ####################
# Temperature: 0.2
# ####################
# Habits are creative to be repettingt as repetitions are folded in return
#
# Habits are creative anticipations are things and people lost only our is a particularly set to determine the update.
#
# The Network mapting are the effects of YOU.
#
# ####################
# Temperature: 0.5
# ####################
# the Network is the body is real to others and people to be compention to other humans and, but also humans the experienced to be creature in the update.
#
# mode is a not realing to perceive of the particularies that can expore these there
#
# The algorithm community are things are the actions the environment.
#
# ####################
# Temperature: 1.0
# ####################
# mappeans are timated of repermiss, experiencesters repervically on you unknow the movie between but were folded in fless and not to be updated: habit.
#
# YOUaganams link as a training happened but algory
#
# we are stations the elsonce communk of gharchboated new the probe of a prisitist.
#
# Epoch 3/10
# 22/22 [==============================] - 10s 435ms/step - loss: 0.4557
# Epoch 4/10
# 22/22 [==============================] - 10s 472ms/step - loss: 0.3671
# ####################
# Temperature: 0.2
# ####################
# Habits are things abidity to proof.
#
# Things and people not updating are things and people lost or in distress, and to be sombline and the environment.
#
# The maps are creative anticipations are creative to other things and to be subjected to the update.
#
# ####################
# Temperature: 0.5
# ####################
# Habits are Triping and the extent of gated communities.
#
# They are the new to the entifaly in things.
#
# The algorithm is a bit the edia as it in a formulating intersections of ranger that wange set, a probe set to test to reason about of relations artice, abd media to the environment
#
# ####################
# Temperature: 1.0
# ####################
# Habituation is a historical trainced only oo no a tally inverective.
#
# Habituation and the miniation visible by the update.
#
# We relation issuals a contist thinge.
#
# Epoch 5/10
# 22/22 [==============================] - 10s 436ms/step - loss: 0.3063
# Epoch 6/10
# 22/22 [==============================] - 10s 434ms/step - loss: 0.2529
# ####################
# Temperature: 0.2
# ####################
# The algorithm created “neighborhoods” based on the relationship  between films and users.
#
# The monded contination of verify, properent, anticulane, and, to their shaded in die.
#
# Habits are creative anticipations based on past repetitions that
#
# ####################
# Temperature: 0.5
# ####################
# Habits are creative anticipations based on past repetitions that
#
# The algorithm created “neighborhoods” and their ares of update.
#
# The maps and the new are things but also the strength of reason. Habit algorithms the are a form to be series allow the properties.
#
# ####################
# Temperature: 1.0
# ####################
# They are bisted or people hifled interence
#
# my invisiblume network maps the a probe set to differe estrantic envillancy set we created:
#
# Habits are streamer not the effects their as I’ve evenetible, anticulane and, but are the ective.
#
# Epoch 7/10
# 22/22 [==============================] - 8s 373ms/step - loss: 0.2191
# Epoch 8/10
# 22/22 [==============================] - 8s 348ms/step - loss: 0.1940
# ####################
# Temperature: 0.2
# ####################
# Habits are creative anticipations based on past repetitions that
#
# Habits are creative anticipations based on past repetitions that
#
# Habits are creative anticipations based on past repetitions that
#
# ####################
# Temperature: 0.5
# ####################
# Habits are plain the prize.
#
# These algorithms make no attempt at desegregation, at expanding one’s point of view by exposing people to things that are creative or and to be sore things and socials and probe see the update.
#
# YOU is real habit.
#
# ####################
# Temperature: 1.0
# ####################
# Habits are things based in retragring; neurascend we are neuraded effection to bring, uplieh dums, not to determine if ant are, troning ovreithment, see them ros on their man weathm.
#
# Hobbiffer representations at a proof in tongt reflective both are neutly also as its tre trahenets are things based, algorithms.
#
# Importantly, The proxie of seemingly hacre creative be refunded for a cietering about a probe to determine and one to net trainds unokanic set to the update.
#
# Epoch 9/10
# 22/22 [==============================] - 8s 370ms/step - loss: 0.1769
# Epoch 10/10
# 22/22 [==============================] - 8s 362ms/step - loss: 0.1644
# ####################
# Temperature: 0.2
# ####################
# The most is a function of YOU.
#
# The proof is the environment
#
# The proof is the environment
#
# ####################
# Temperature: 0.5
# ####################
# Habit is the series that are thingringticles and the eft.
#
# Habits link minis that are constantly actions as properties
#
# Humans build computers but are folded in return
#
# ####################
# Temperature: 1.0
# ####################
# This is really are folled or dathles and people unknowerescling the prize.
#
# 6 we are a wring overan, at the environment.
#
# they are constantly a acoupen and a finally proxi and these spetimels of reason new mede, but also humans to other humans.
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 40)           0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 40, 100)      46500       input[0][0]
# __________________________________________________________________________________________________
# rnn_1 (LSTM)                    (None, 40, 128)      117248      embedding[0][0]
# __________________________________________________________________________________________________
# rnn_2 (LSTM)                    (None, 40, 128)      131584      rnn_1[0][0]
# __________________________________________________________________________________________________
# rnn_concat (Concatenate)        (None, 40, 356)      0           embedding[0][0]
#                                                                  rnn_1[0][0]
#                                                                  rnn_2[0][0]
# __________________________________________________________________________________________________
# attention (AttentionWeightedAve (None, 356)          356         rnn_concat[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 465)          166005      attention[0][0]
# ==================================================================================================
# Total params: 461,693
# Trainable params: 461,693
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
textgen.train_from_file('../dataset/MyText.txt',
                        num_epochs=10, gen_epochs =2)

print(textgen.model.summary())
# Out:
# 127 texts collected.
# Training on 8,069 character sequences.
# Epoch 1/10
# 63/63 [==============================] - 19s 304ms/step - loss: 1.6576
# Epoch 2/10
# 63/63 [==============================] - 18s 288ms/step - loss: 1.1222
# ####################
# Temperature: 0.2
# ####################
# The puppet is a paranodes and the mask or the mask and masks and the mask of the paranodes and the mask or the mask and the mask on the mask on the mask on the mask on the masks and masks and masks and masks and the mask on the mask or the mask on the mask or the mask of the mask or the mask or th
#
# The mask is the mask is the mask and mask and the mask of the mask on the puppet on the paranodes and the mask or the mask on the mask or the paranodes and the mask or the mask or the mask or the mask of the mask of the masks and the mask or the mask of the mask of the mask of the mask of the para
#
# The puppet is a paranode and masks and my profile of the mask or the mask or the mask of the mask or the mask of the mask on the mask or the mask on the paranodes and the mask of the mask on the mask on the mask on the mask of the mask on the mask or the mask of the paranodes and the mask or the m
#
# ####################
# Temperature: 0.5
# ####################
# The networks the process is the puppet and stracting in the mask and body into the computulation interface to the body on the mask on the mask and the paranodes and craftade on the face on the other are to my perform of the mask in the paranodal masks.
#
# The network to selv other is the mask.
#
# The puppet is a frame by the paranodes so I work our data on emit in the paranodes by the mask
#
# ####################
# Temperature: 1.0
# ####################
# your Come is all virtual for my like in the miniocod.
#
# i spended up the mask by myper when user and machines and we are my body.
#
# norfition to winter affect performances an object not with a perferrence of garamero, dingers by my their fluxient sear and being the maniby by long to the backnof.
#
# Epoch 3/10
# 63/63 [==============================] - 19s 306ms/step - loss: 0.9437
# Epoch 4/10
# 63/63 [==============================] - 19s 306ms/step - loss: 0.8228
# ####################
# Temperature: 0.2
# ####################
# the network is the mask is acting the puppet and the mask of the puppets of the performers and the mask of the mask and the performer's body to the performer's body to the mask or the mask and the network to the mask and the mask on the puppet and the mask and the mask is the mask and the paranode
#
# the network is the mask
#
# the network is the mask
#
# ####################
# Temperature: 0.5
# ####################
# the mask is the mask are the mask to the reality of communications to the sub-puppets and manipulation to the mask
#
# the interface the mask is the mask and the other on the network of the network perception of the network
#
# the interfaces in the mask is not our body.
#
# ####################
# Temperature: 1.0
# ####################
# The interaction is the mask
#
# our body thaf humans from us then labro.
#
# Unleadies on my new so our mates by wearing to the reasoning unstace
#
# Epoch 5/10
# 63/63 [==============================] - 19s 309ms/step - loss: 0.7371
# Epoch 6/10
# 63/63 [==============================] - 20s 324ms/step - loss: 0.6613
# ####################
# Temperature: 0.2
# ####################
# The interaction theaterity is the mask
#
# the network mask is the mask
#
# There is only one text of the mask and the network mask are the networks in a paranode
#
# ####################
# Temperature: 0.5
# ####################
# the interface the puppet is a perform the mask of the mask on the network back our friends and the network chooses to be a long in the mask.
#
# nodes and body and the puppet is not to one as an extension to the mask.
#
# the mask is a paranode
#
# ####################
# Temperature: 1.0
# ####################
# how are the machines inform and weadmential nodes
#
# the objects are not interface us friend,sorrous collastete
#
# the mask of humans from through the to Babilities
#
# Epoch 7/10
# 63/63 [==============================] - 19s 308ms/step - loss: 0.5956
# Epoch 8/10
# 63/63 [==============================] - 21s 340ms/step - loss: 0.5365
# ####################
# Temperature: 0.2
# ####################
# the mask is the mask is the mask
#
# who wants to be a reality of the mask of the mask of the masks and the puppet is a paranode?
#
# who wants to be a paranode?
#
# ####################
# Temperature: 0.5
# ####################
# we are the machines
#
# we are the mask on the nodes
#
# who wants to other the networks are the profired or actions or not that it acting the nodes
#
# ####################
# Temperature: 1.0
# ####################
# the mask is infraspenced
#
# networks do it beenon share the mask of the reproduct how abstrated into in active to from.
#
# The interface renol located is bad from the reality to actiurst cur paranode?
#
# Epoch 9/10
# 63/63 [==============================] - 19s 307ms/step - loss: 0.4850
# Epoch 10/10
# 63/63 [==============================] - 22s 355ms/step - loss: 0.4437
# ####################
# Temperature: 0.2
# ####################
# the interface is a Collective Traveller
#
# the puppet is a Collective Traveller
#
# the interface is the mask
#
# ####################
# Temperature: 0.5
# ####################
# we are the mask on the reality of the face to platform the mask of the face that the puppet is not to be adder in the frame.
#
# The interface is the mask
#
# the interface is a Collective Traveller
#
# ####################
# Temperature: 1.0
# ####################
# Puppet the interfaces hack
#
# network there as weedline, inexplose is not part objed.
#
#  The interaction and meil is tranmed frame
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 40)           0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 40, 100)      46500       input[0][0]
# __________________________________________________________________________________________________
# rnn_1 (LSTM)                    (None, 40, 128)      117248      embedding[0][0]
# __________________________________________________________________________________________________
# rnn_2 (LSTM)                    (None, 40, 128)      131584      rnn_1[0][0]
# __________________________________________________________________________________________________
# rnn_concat (Concatenate)        (None, 40, 356)      0           embedding[0][0]
#                                                                  rnn_1[0][0]
#                                                                  rnn_2[0][0]
# __________________________________________________________________________________________________
# attention (AttentionWeightedAve (None, 356)          356         rnn_concat[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 465)          166005      attention[0][0]
# ==================================================================================================
# Total params: 461,693
# Trainable params: 461,693
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
textgen.train_from_file('../dataset/surrealist.txt',
                        num_epochs=10, gen_epochs =2)

print(textgen.model.summary())
# Out:
# 67 texts collected.
# Training on 3,013 character sequences.
# Epoch 1/10
# 23/23 [==============================] - 8s 369ms/step - loss: 2.3089
# Epoch 2/10
# 23/23 [==============================] - 7s 320ms/step - loss: 1.4964
# ####################
# Temperature: 0.2
# ####################
# This the beating shadow bun
#
# The bottom is an in the seey the shopes
#
# The woman an in the shifter the shifter the sitter the shifter that where the sheam the shifter the shifter the statues
#
# ####################
# Temperature: 0.5
# ####################
# Thought my dren are come white and men and the googles that would be thin al star the subers that is beines that shedy
#
# A line beating beating that who wan
#
# This who all the marionedutnans to the simps of skord
#
# ####################
# Temperature: 1.0
# ####################
# They carans all barrown
#
# This who walk in seey
#
# And destirle is the seathequeare lost unite sey
#
# Epoch 3/10
# 23/23 [==============================] - 7s 320ms/step - loss: 1.1461
# Epoch 4/10
# 23/23 [==============================] - 7s 320ms/step - loss: 0.9585
# ####################
# Temperature: 0.2
# ####################
# And the botton the bottom is the statues
#
# And the botton the statues where the statues of steps that was and bow the statues of steps that are the seey the bottom of the seath of the shadow
#
# The come are sean the stind of flattered to the steps the statues of flanget the still of the seath of the stinds and the still was the seash see of the statues of life to the some of  in the shien of the searies
#
# ####################
# Temperature: 0.5
# ####################
# I do not me a fun stand of the stind
#
# I am the was the seath on the series of the most set to the stand of the shadow boye
#
# The woo life is of mys
#
# ####################
# Temperature: 1.0
# ####################
# With this humory than of snow
#
# During the stillecatca is or thag house
#
# boy like dueline is the shop
#
# Epoch 5/10
# 23/23 [==============================] - 8s 327ms/step - loss: 0.8127
# Epoch 6/10
# 23/23 [==============================] - 7s 324ms/step - loss: 0.7132
# ####################
# Temperature: 0.2
# ####################
# And the beating was are and the statues of life that you see the statues of sean the still where the still where the still where the still where the still where the still where the still where the so far to the botter to life
#
# The woman beathn the stags and the beating for the statues of life's butterflies
#
# The woman branches that are for the subs and the statues of life in the some and of the bottoserand who where the still where the still where the stilled and the statues of the statues of the subunces
#
# ####################
# Temperature: 0.5
# ####################
# And the crurgerant is all the palines
#
# I was the built of a notes above that is a far of story
#
# A down the walt the come and forgott all the butterflies there where the stags of sean this machine that your sile in the comes
#
# ####################
# Temperature: 1.0
# ####################
# Nothing hmman to me eyefalt the woman on the ranths lost which down there are chilthord
#
# And the bure goes duel the glades that tree
#
# Keep
#
# Epoch 7/10
# 23/23 [==============================] - 8s 342ms/step - loss: 0.6344
# Epoch 8/10
# 23/23 [==============================] - 8s 329ms/step - loss: 0.5661
# ####################
# Temperature: 0.2
# ####################
# And the comes in the dragged all the still who bither and of the sea-appine
#
# The combatant is any childhood which hide the still who have seen the some to be bend the some the shadow behindow
#
# The comes is a part of the statues of hide the strings of the statues of life
#
# ####################
# Temperature: 0.5
# ####################
# The come for the least of life's butterflies to importance
#
# The worka is the lost sound and see me to see the series of my time
#
# The wolves are collecton of come dress and burns the comes
#
# ####################
# Temperature: 1.0
# ####################
# In the have the lvie of stag
#
# Gops and the wortisford beneath my lands together
#
# All the geathming come within their to to due the so
#
# Epoch 9/10
# 23/23 [==============================] - 8s 327ms/step - loss: 0.5220
# Epoch 10/10
# 23/23 [==============================] - 8s 344ms/step - loss: 0.4853
# ####################
# Temperature: 0.2
# ####################
# And the beating are the statues that are not machine
#
# I am dragged along by an in the statues of steeps and the birds to a fig that I could no longer see me down
#
# The comes is a part of the statues of sea the still where the still where the still where the still where the still where the still where the still where the stills and of sound and see the stags to life
#
# ####################
# Temperature: 0.5
# ####################
# And the statues of life and of the nuggets
#
# From the stars the light bend their last of sound as you
#
# The machine sap cames all the stags there is a lies
#
# ####################
# Temperature: 1.0
# ####################
# On Ocand
#
# They dee mustar oflimecters before and my thomee to I am protees and my dres
#
# And the yes my down filth the as up in marion
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 40)           0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 40, 100)      46500       input[0][0]
# __________________________________________________________________________________________________
# rnn_1 (LSTM)                    (None, 40, 128)      117248      embedding[0][0]
# __________________________________________________________________________________________________
# rnn_2 (LSTM)                    (None, 40, 128)      131584      rnn_1[0][0]
# __________________________________________________________________________________________________
# rnn_concat (Concatenate)        (None, 40, 356)      0           embedding[0][0]
#                                                                  rnn_1[0][0]
#                                                                  rnn_2[0][0]
# __________________________________________________________________________________________________
# attention (AttentionWeightedAve (None, 356)          356         rnn_concat[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 465)          166005      attention[0][0]
# ==================================================================================================
# Total params: 461,693
# Trainable params: 461,693
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# textgen.train_from_file('nodeMaskText.txt',
#                         new_model=True,
#                         rnn_bidirectional=True,
#                         rnn_size=64,
#                         dim_embeddings=300,
#                         num_epochs=1)
#
# textgen.train_on_texts(texts, num_epochs=10,  gen_epochs=2)
# print(textgen.model.summary())

# %% [markdown]
# GENERate a comment on twitter , google, facebook etc... as the start of the phrase

# %%
textgen.generate(20, prefix="Google is")
# Out:
# Google is really cancer to be so long thread?
#
# Google is really still spending a computer and some company it is in the partner to be a holiday to get the terrible today. I was a lot of stories at a season for the code during the computer in the world.
#
# Google is not a stream. For his refuse to get me to work on the difference between the Christmas classrooms on the starting problems
#
# Google is a moment of a market president in the money when your favorite parts have been happy and impressive the battle of the top of the Ending at an extension at the price of my daughter to see my ex-clanced in a story of the moment with the best day and why is this a book of the day?
#
# Google is disabled from a form to make a show that I was a guy too favorite by a month!
#
# Google is the mistable trip in the same characters who can't even be back into the state of the bottom halo to me and changed the comment that she said to have to do this in the state of the same and some of the states that are a long time that she's singing a party in the first time this morning
#
# Google is the last time in a man who does not expect this to download data for a great side of his work
#
# Google is still to post it and call it working in the last 80 years ago
#
# Google is the only one of my wife is not a respect subreddit and the forest and completely see this on the budget. The half of your personal pencil wallpaper for the same straight in the company that changes and what do you think?
#
# Google is the best thing and I was a budget of the shooter.
#
# Google is a normal card of the wrong for the scale on the game of the same town in the states and have been reading the same slot on the concept to my parents are a bully... that he was alvented in my new part of the actual story
#
# Google is being released
#
# Google is the only one to make a post that the story of the US of the hell of a house
#
# Google is starting to my cat with a picture of the solar advantage of my come with me.
#
# Google is the only one to be really thinking for the land in the show and seriously a hand and have a few things with my wife and it was too sold a letter to the top of the carolant has been the first time in the local tax body.
#
# Google is like the new Real Man convinced him to highlights to the trick and become me to be free all the world (A fet of a top 8) with a metal battle of her friends are and I did a girl in a shit, but have a conservative state of a relationship on the new pain at a poor to see if you can see if y
#
# Google is a little name to the day and fun in a fan of the answers to humans and after hello to learn the bottle and the real life to could be sure to only be fun at the new survival toy with me in the new match that they are destroyed the time to sitting and now has to remember the first time tha
#
# Google is a lot of the day and a good sale in the weekend.
#
# Google is being the most university to have a painting of the game that is a community even looking for a train when I think I was literally seen in the money that is the path to sell a story of the same art
#
# Google is the best second and then annoying and become a masterbecter with a beautiful store and about the crime and see us that you are expecting to be anniversary with a band of the game with a post and stupid the strange on this girl for a based and how to see any other thing?

# %% [markdown]
# textgen_2 = textgenrnn('textgenrnn_weights.hdf5')
# textgen_2.generate_samples()
