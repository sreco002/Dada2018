# %% [markdown]
# One artefact / One voice / One writing text generator

# %% [markdown]
# <h1>Allison Parrish, https://github.com/aparrish/rwet</h1>

# %%
import random

# %%
pwd
# Out:
# '/Users/macbookpro/Documents/2018Sept/Dada2018/1-ML/Markov-Parrish'

# %%
words = open("../dataset/SurrealistManifesto.txt").read().split()
a_words = [item for item in words if item.startswith("M")]
a_words
# Out:
# ['Man,',
#  'Menace',
#  'Man',
#  'Madness',
#  'Man,',
#  'Marquise',
#  'Man,',
#  'Memory',
#  'My',
#  'Man’s',
#  'Mystery.',
#  'Monk',
#  'Matilda',
#  'Monk',
#  'Max',
#  'Morise,',
#  'Marcel',
#  'Malkine,',
#  'Marcel',
#  'Moreover,',
#  'My',
#  'Man',
#  'MEDIUMS',
#  'MÉDIUMS,',
#  'March',
#  'Man',
#  'Morning',
#  'My',
#  'MEMORABILIA',
#  'Messrs.',
#  'Malkine,',
#  'Morise,',
#  'Mallarmé',
#  'Moreau,',
#  'Matisse,',
#  'Musique',
#  'Man',
#  'Max',
#  'Masson.)',
#  'Max',
#  'Morise:',
#  'Mississippi',
#  'Miracle',
#  'Miró',
#  'Magical',
#  'M',
#  'Memory',
#  'Man',
#  'My',
#  'Magnetic',
#  'Man',
#  'Man',
#  'Morise)',
#  'Men',
#  'Man',
#  'MADAME',
#  'Mauvais',
#  'Musketeers.',
#  'Man',
#  'My']

# %%
r_words = [item for item in words if item.startswith("m")]
print(random.choice(r_words).capitalize())
# Out:
# Modern

# %%
words = open("../dataset/SurrealistManifesto.txt").read().split() # read in a text file, split into words
initials = {} # create an empty dictionary

for item in words: # run this code for every word in the text
    
    first_let = item[0] # first_let now has the first character of the string
    
    # check to see if the letter is already a key in the dictionary.
    # if not, add a new key/value pair with an empty list as the value.
    if first_let not in initials:
        initials[first_let] = []
        
    # append the current word to the list that is the value for this key
    initials[first_let].append(item)
    
    # uncomment line below to see debug output
    #print(item, first_let, initials[first_let])

# %%
initials
# Out:
# {'(': ['(what',
#   '(as',
#   '(or',
#   '(Dostoevsky,',
#   '(since,',
#   '(or',
#   '(Account',
#   '(a',
#   '(and',
#   '(the',
#   '(What',
#   '(there',
#   '(ENTRÉE',
#   '(and',
#   '(since',
#   '(Mont',
#   '(I',
#   '(the',
#   '(I',
#   '(Nord-Sud,',
#   '(Were',
#   '(Knut',
#   '(migraine,',
#   '(I',
#   '(Filles',
#   '(Book',
#   '(1766),',
#   '(See',
#   '(I',
#   '(New',
#   '(Discours',
#   '(for',
#   '(Enough!',
#   '(Echolalia)',
#   '(Ganser',
#   '(Les',
#   '(Barrières)',
#   '(Baudelaire)',
#   '(note',
#   '(abruptly',
#   '(Lautréamont)',
#   '(Lautréamont)',
#   '(Philippe',
#   '(Robert',
#   '(André',
#   '(Louis',
#   '(Roger',
#   '(Max',
#   '(Let',
#   '(observe,',
#   '(Whatever',
#   '(Rimbaud:',
#   '(And',
#   '(do'],
#  ',': [','],
#  '-': ['-', '-', '-', '-', '-', '-'],
#  '1': ['1.',
#   '1820,',
#   '1,',
#   '1922)',
#   '1919),',
#   '1918)',
#   '1854)',
#   '1939',
#   '1922,',
#   '1974,',
#   '1922/23,',
#   '1924)',
#   '1927)',
#   '1.',
#   '1924,',
#   '1919,'],
#  '2': ['2.', '2.'],
#  '3': ['3.', '36', '3.'],
#  '4': ['4.'],
#  '6': ['6'],
#  '8': ['8th,'],
#  'A': ['A',
#   'Amidst',
#   'And,',
#   'America.',
#   'And',
#   'Aquinas',
#   'Anatole',
#   'And',
#   'A',
#   'Allow',
#   'A',
#   'And',
#   'Analysts',
#   'And,',
#   'And',
#   'Are',
#   'And',
#   'And',
#   'And',
#   'AT',
#   'At',
#   'A',
#   'And',
#   'An',
#   'Ambrosio’s',
#   'At',
#   'Amidst',
#   'A',
#   'Aragon',
#   'Auric,',
#   'Antonin',
#   'Artaud,',
#   'Are',
#   'And',
#   'At',
#   'At',
#   'A',
#   'And',
#   'Apollinaire',
#   'At',
#   'All',
#   'Apollinaire,',
#   'Apollinaire.',
#   'Apollinaire,',
#   'ABSOLUTE',
#   'Aragon,',
#   'And',
#   'André',
#   'Ask',
#   'Ask',
#   'Ask',
#   'Ask',
#   'And',
#   'Ask',
#   'Aragon:',
#   'And',
#   'Ask',
#   'Art',
#   'And',
#   'A',
#   'Against',
#   'And',
#   'And',
#   'As',
#   'As',
#   'And',
#   'At',
#   'A',
#   'A',
#   'Aragon)',
#   'All',
#   'A',
#   'A',
#   'A',
#   'ARTISAN',
#   'A',
#   'A',
#   'A',
#   'AT',
#   'And',
#   'AND',
#   'And,'],
#  'B': ['But',
#   'But',
#   'But',
#   'B114)',
#   'But',
#   'Because',
#   'But',
#   'But',
#   'By',
#   'Baudelaire’s',
#   'Benjamin',
#   'Boiffard,',
#   'Baron',
#   'Besides,',
#   'BLACK-FOREST',
#   'But',
#   'But',
#   'But',
#   'Baron,',
#   'Boiffard,',
#   'Breton,',
#   'Bertrand',
#   'Baudelaire',
#   'Braque,',
#   'But',
#   'Barriers',
#   'Baudelaire’s',
#   'Breton)',
#   'But',
#   'But',
#   'Braque',
#   'BENEATH',
#   'BOLTS',
#   'BEAUTY',
#   'BLANK',
#   'BALL',
#   'Béthune.’',
#   'Béthune,',
#   'Béthune',
#   'Béthune,',
#   'Bravo,'],
#  'C': ['Columbus',
#   'Crime',
#   'Can',
#   'Camaret,',
#   'Cinderella.',
#   'Charming',
#   'Cuisin',
#   'Carrive;',
#   'Cubist',
#   'Certainly',
#   'Chirico’s',
#   'Carlyle',
#   'Chapter',
#   'Carrive,',
#   'Crevel,',
#   'Chateaubriand',
#   'Constant',
#   'Chirico,',
#   'Chancellor',
#   'Continue',
#   'Champs',
#   'Champagne.',
#   'Ceylon',
#   'COLOUR',
#   'CHANCE',
#   'Certainly,',
#   'Chesterton',
#   'Cumae,',
#   'Cinema?',
#   'Charming',
#   'Curie’s'],
#  'D': ['Dear',
#   'Dream',
#   'Disc’.',
#   'Desnos',
#   'Delteil;',
#   'Duchamp',
#   'Does',
#   'Desnos,',
#   'DES',
#   'Dada',
#   'Desnos:',
#   'Died',
#   'Dumas,',
#   'Dictated',
#   'Delteil,',
#   'Desnos,',
#   'Ducasse,',
#   'Dante,',
#   'De',
#   'Desbordes-Valmour',
#   'Duchamp,',
#   'Delteil:',
#   'Desnos,',
#   'DÉSORDRE',
#   'DEUIL',
#   'DEUIL',
#   'Disorder',
#   'Desnos',
#   'Desnos',
#   'Do',
#   'Discourse',
#   'Day',
#   'Desnos)',
#   'DAY',
#   'DAY',
#   'DAILY',
#   'Dodona',
#   'Delphi'],
#  'E': ['Each',
#   'Everything',
#   'Each',
#   'ENTRANCE',
#   'Ease',
#   'ENCYCLOPEDIA.',
#   'Ernst,',
#   'Each',
#   'Each',
#   'Everything',
#   'Everything',
#   'Everything',
#   'Enfer:',
#   'Existence'],
#  'F': ['France,',
#   'Feeling',
#   'Freud',
#   'Freud',
#   'For',
#   'From',
#   'Fear,',
#   'For',
#   'Fraenkel',
#   'Francis',
#   'Francis',
#   'Fontaine,',
#   'Farewell',
#   'Feuilles',
#   'Freud',
#   'Fire',
#   'Fargue',
#   'FORMEL,',
#   'Formal',
#   'Forget',
#   'Following',
#   'Forty-five',
#   'Fields',
#   'For',
#   'Firstly,',
#   'For',
#   'From',
#   'FISH,',
#   'Fish,',
#   'Following',
#   'FADED',
#   'FROM',
#   'FIRST',
#   'Far',
#   'France.',
#   'Fine.'],
#  'G': ['German',
#   'Ghosts',
#   'Greeks,',
#   'Georges',
#   'Georges',
#   'Georges',
#   'Georges',
#   'Georges',
#   'Gérard,',
#   'Guillaume',
#   'Gérard',
#   'Girls',
#   'Germans',
#   'Gérard,',
#   'Gustave',
#   'Grief',
#   'Grief',
#   'God,',
#   'Gave'],
#  'H': ['His',
#   'However',
#   'Here',
#   'Hamson',
#   'Here',
#   'Hegel’s',
#   'Hugo',
#   'HÉBRIDES,',
#   'Hebrides',
#   'He',
#   'Have',
#   'How',
#   'How',
#   'How',
#   'Here',
#   'How',
#   'He',
#   'However',
#   'Here,',
#   'He',
#   'He',
#   'Here,',
#   'Here',
#   'HAVE',
#   'HE?',
#   'His',
#   'He',
#   'He',
#   'Hello,',
#   'Here',
#   'He',
#   'He'],
#  'I': ['I',
#   'If',
#   'In',
#   'I',
#   'I',
#   'Indeed',
#   'It',
#   'Is',
#   'I',
#   'I',
#   'I',
#   'I',
#   'It',
#   'It',
#   'It',
#   'It',
#   'It',
#   'If',
#   'I',
#   'I',
#   'I',
#   'It',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I’m',
#   'I’ll',
#   'I',
#   'I',
#   'If',
#   'It',
#   'If',
#   'I',
#   'It',
#   'I',
#   'It',
#   'It',
#   'It',
#   'Imagination',
#   'If',
#   'It',
#   'It',
#   'It',
#   'I',
#   'I',
#   'I',
#   'I',
#   'In',
#   'I',
#   'I',
#   'I',
#   'I',
#   'It’s',
#   'I',
#   'I',
#   'I',
#   'I',
#   'Is',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'It',
#   'It',
#   'I',
#   'I',
#   'I',
#   'I',
#   'If',
#   'I',
#   'I',
#   'I',
#   'I',
#   'In',
#   'I',
#   'It',
#   'It',
#   'It',
#   'I',
#   'In',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'It',
#   'I,',
#   'If',
#   'I',
#   'I',
#   'I,',
#   'I',
#   'I,',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'It',
#   'It',
#   'It',
#   'It',
#   'It',
#   'It',
#   'I',
#   'It',
#   'If',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'In',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'It',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'In',
#   'I,',
#   'It',
#   'I',
#   'It',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'It',
#   'I',
#   'I',
#   'I',
#   'In',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'It',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'It',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'It',
#   'It',
#   'I',
#   'I,',
#   'I',
#   'I',
#   'In',
#   'It',
#   'It',
#   'In',
#   'I',
#   'I',
#   'III,',
#   'It',
#   'It',
#   'I',
#   'It',
#   'Isidore',
#   'I',
#   'In',
#   'I',
#   'I',
#   'In',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'It',
#   'It',
#   'If',
#   'Incapable',
#   'It',
#   'I',
#   'In',
#   'I',
#   'I',
#   'If',
#   'I',
#   'I',
#   'It',
#   'It',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'It',
#   'I',
#   'In',
#   'I',
#   'Is',
#   'I',
#   'I',
#   'It',
#   'It',
#   'It',
#   'If,',
#   'I',
#   'I',
#   'In',
#   'It',
#   'It',
#   'I',
#   'I',
#   'I',
#   'It',
#   'It',
#   'It',
#   'I',
#   'I',
#   'I',
#   'In',
#   'I',
#   'In',
#   'It’s',
#   'I',
#   'I',
#   'I',
#   'It',
#   'It',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'It',
#   'IS',
#   'IS',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'It',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'If',
#   'I',
#   'If',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'It',
#   'I',
#   'It'],
#  'J': ['J.P.R',
#   'Jean',
#   'Joseph',
#   'Jean',
#   'J.-A.',
#   'Jacques',
#   'Juliet,',
#   'Jarry',
#   'Joseph',
#   'Jules',
#   'June'],
#  'K': ['Kill,', 'Klee,', 'Know', 'Kant’s'],
#  'L': ['Let',
#   'L’Intelligence,',
#   'Let',
#   'Let’s',
#   'Lewis’s',
#   'Long',
#   'Likewise',
#   'Louis',
#   'Limbour,',
#   'Limbour',
#   'Limbour);',
#   'Littérature,',
#   'Limbour,',
#   'La',
#   'Lord',
#   'Lady,',
#   'Lord,',
#   'Louis',
#   'Life’s',
#   'Let',
#   'Language',
#   'Lovely',
#   'Lutheranism.’)',
#   'Love',
#   'LARGE'],
#  'M': ['Man,',
#   'Menace',
#   'Man',
#   'Madness',
#   'Man,',
#   'Marquise',
#   'Man,',
#   'Memory',
#   'My',
#   'Man’s',
#   'Mystery.',
#   'Monk',
#   'Matilda',
#   'Monk',
#   'Max',
#   'Morise,',
#   'Marcel',
#   'Malkine,',
#   'Marcel',
#   'Moreover,',
#   'My',
#   'Man',
#   'MEDIUMS',
#   'MÉDIUMS,',
#   'March',
#   'Man',
#   'Morning',
#   'My',
#   'MEMORABILIA',
#   'Messrs.',
#   'Malkine,',
#   'Morise,',
#   'Mallarmé',
#   'Moreau,',
#   'Matisse,',
#   'Musique',
#   'Man',
#   'Max',
#   'Masson.)',
#   'Max',
#   'Morise:',
#   'Mississippi',
#   'Miracle',
#   'Miró',
#   'Magical',
#   'M',
#   'Memory',
#   'Man',
#   'My',
#   'Magnetic',
#   'Man',
#   'Man',
#   'Morise)',
#   'Men',
#   'Man',
#   'MADAME',
#   'Mauvais',
#   'Musketeers.',
#   'Man',
#   'My'],
#  'N': ['Nothing',
#   'Nothing',
#   'Not',
#   'North',
#   'Noll;',
#   'Naville,',
#   'Not',
#   'November',
#   'Nevertheless,',
#   'Nerval',
#   'Nerval',
#   'Nerval',
#   'Nodier',
#   'Naville,',
#   'Noll,',
#   'Night',
#   'Nouveau',
#   'NOUVELLES',
#   'Never',
#   'Not',
#   'Now',
#   'Novalis’',
#   'NEWSPAPER',
#   'Nijinksi,',
#   'No'],
#  'O': ['On',
#   'Only',
#   'One',
#   'Our',
#   'On',
#   'Oriental',
#   'Only',
#   'OF',
#   'One',
#   'On',
#   'One',
#   'One',
#   'One',
#   'One',
#   'Of',
#   'Only',
#   'Or',
#   'One',
#   'On',
#   'One',
#   'Of',
#   'On',
#   'OF',
#   'Of',
#   'OF'],
#  'P': ['Paul',
#   'Paul',
#   'Punishment)',
#   'Pensées,',
#   'Pointless',
#   'POET',
#   'Paris.',
#   'Philippe',
#   'Paul',
#   'Paulhan;',
#   'Péret,',
#   'Pierre',
#   'Picabia',
#   'Picasso',
#   'Poetry',
#   'Pawn-Shop',
#   'Picasso’s',
#   'Pierre',
#   'Philippe',
#   'Poetically',
#   'Pure',
#   'Philosophy.',
#   'Péret,',
#   'Picon,',
#   'Poe',
#   'Perse',
#   'Picabia,',
#   'Philippe',
#   'Paul',
#   'POUR',
#   'Put',
#   'Put',
#   'Paucity',
#   'Peu',
#   'Perhaps.',
#   'Poetic',
#   'Protestantism',
#   'Purgatory.',
#   'Picasso',
#   'POEM',
#   'POEM',
#   'PARIS',
#   'PRAYER',
#   'Press',
#   'Philippe',
#   'Perhaps',
#   'Photography?',
#   'Pasteur’s'],
#  'R': ['Rather,',
#   'Racine’s',
#   'Robert',
#   'Roger',
#   'Rue',
#   'Robert',
#   'Rimbaud',
#   'Reverdy,',
#   'Reverdy’s',
#   'Robert',
#   'Romeo',
#   'Resartus',
#   'Revolution;',
#   'Rabbe',
#   'Rimbaud',
#   'Reverdy',
#   'Roussel',
#   'Ray,',
#   'Roger',
#   'Robert',
#   'Reality.',
#   'Réalité',
#   'Reverdy’s',
#   'Reverdy’s',
#   'Renard)',
#   'Reverdy',
#   'Rrose',
#   'Reformation;',
#   'Red',
#   'Russian',
#   'Radio?'],
#  'S': ['Such',
#   'Such',
#   'So',
#   'Stendhal’s',
#   'Stendhal',
#   'Saint-Pol-Roux',
#   'Symbolist',
#   'She',
#   'Soupault',
#   'So',
#   'Sibylline',
#   'Since',
#   'Suddenly',
#   'Soupault,',
#   'Soupault’s',
#   'Soupault’s',
#   'Soupault',
#   'SURREALISM.',
#   'SUPERNATURALISM,',
#   'Sartor',
#   'Supernaturalism’).',
#   'Surrealism,',
#   'SUPERNATURALISTIC',
#   'Swedenborg’s',
#   'Saint-Pol-Roux)',
#   'SURREALISM',
#   'SURREALISM,',
#   'Surrealism',
#   'SURREALISM,',
#   'Soupault,',
#   'Surrealists,',
#   'Shakespeare.',
#   'Swift',
#   'Sade',
#   'Saint-Pol-Roux',
#   'Saint-John',
#   'Seurat,',
#   'So',
#   'Soupault:',
#   'Secrets',
#   'Surrealist',
#   'Simplicity,',
#   'Surrealism',
#   'Surrealism',
#   'Since,',
#   'Soupault',
#   'Surrealism',
#   'Soupault)',
#   'Sélavy’s',
#   'So',
#   'Soupault',
#   'SOLUBLE',
#   'Surrealist',
#   'STAG',
#   'Short',
#   'SUITOR’S',
#   'Several',
#   'Saison',
#   'Sang):',
#   'Someone',
#   'Similarly,',
#   'Soupault',
#   'Soupault',
#   'Syphilis?',
#   'Such',
#   'Surrealism,',
#   'Surrealism'],
#  'T': ['There,',
#   'The',
#   'That',
#   'That',
#   'The',
#   'To',
#   'That',
#   'They',
#   'The',
#   'Taine’s',
#   'The',
#   'They',
#   'The',
#   'The',
#   'The',
#   'Thomas',
#   'The',
#   'The',
#   'The',
#   'The',
#   'They',
#   'The',
#   'The',
#   'The',
#   'The',
#   'The',
#   'The',
#   'The',
#   'The',
#   'This',
#   'This',
#   'The',
#   'The',
#   'The',
#   'That',
#   'They',
#   'There',
#   'The',
#   'That',
#   'The',
#   'The',
#   'The',
#   'There',
#   'The',
#   'They',
#   'They',
#   'The',
#   'There',
#   'There',
#   'T.',
#   'These',
#   'The',
#   'Then',
#   'The',
#   'There',
#   'The',
#   'THE',
#   'THE',
#   'The',
#   'Those',
#   'That',
#   'The',
#   'The',
#   'The',
#   'These',
#   'Truly',
#   'Then',
#   'The',
#   'This',
#   'Thoughts',
#   'The',
#   'Totally',
#   'The',
#   'Thought,',
#   'The',
#   'To',
#   'Thomas',
#   'There',
#   'They',
#   'The',
#   'They',
#   'Thoughts',
#   'They',
#   'They',
#   'They',
#   'The',
#   'Tell',
#   'The',
#   'That',
#   'Trust',
#   'This',
#   'Through',
#   'To',
#   'They',
#   'Thus',
#   'The',
#   'To',
#   'To',
#   'To',
#   'There',
#   'To',
#   'That',
#   'There',
#   'To',
#   'This',
#   'This',
#   'There',
#   'The',
#   'The',
#   'The',
#   'This',
#   'The',
#   'The',
#   'The',
#   'The',
#   'The',
#   'The',
#   'To',
#   'The',
#   'The',
#   'The',
#   'The',
#   'This',
#   'These',
#   'The',
#   'The',
#   'Thanks',
#   'Thank',
#   'The',
#   'The',
#   'The',
#   'The',
#   'THE',
#   'TO',
#   'THE',
#   'The',
#   'THE',
#   'THE',
#   'The',
#   'THE',
#   'Theatre,',
#   'There',
#   'The',
#   'Today,',
#   'The',
#   'Three',
#   'That',
#   'The',
#   'The',
#   'This',
#   'The',
#   'Try',
#   'Thank',
#   'They',
#   'This',
#   'This',
#   'The'],
#  'U': ['Ultimately,', 'Understand', 'Under', 'Ucello', 'Une'],
#  'V': ['Valéry',
#   'Valéry',
#   'Very',
#   'Villon’s',
#   'Vitrac,',
#   'VIII,',
#   'Vitrac.',
#   'Vaché',
#   'Vitrac:',
#   'Vitrac)',
#   'VILLAGE'],
#  'W': ['Where',
#   'Whoa,',
#   'Whatever',
#   'What',
#   'Where',
#   'We',
#   'We',
#   'Within',
#   'What',
#   'What',
#   'When',
#   'Why',
#   'What',
#   'When',
#   'Who',
#   'What',
#   'WORK.',
#   'What',
#   'We',
#   'With',
#   'Without',
#   'We',
#   'Written',
#   'Write',
#   'Whoever',
#   'Who',
#   'Words,',
#   'When',
#   'We',
#   'Whether',
#   'We',
#   'Watch',
#   'WHERE',
#   'What',
#   'Will',
#   'What',
#   'When',
#   'What',
#   'What',
#   'War?'],
#  'Y': ['You',
#   'You',
#   'You',
#   'Young’s',
#   'You',
#   'Your',
#   'You’',
#   'You',
#   'YOUR',
#   'YET….We',
#   'Youth?'],
#  'a': ['aspects',
#   'and',
#   'around',
#   'almost',
#   'always',
#   'at',
#   'averse',
#   'affairs',
#   'are',
#   'a',
#   'and',
#   'as',
#   'admit',
#   'any',
#   'as',
#   'absence',
#   'all',
#   'a',
#   'anything',
#   'and',
#   'are',
#   'are',
#   'again.',
#   'a',
#   'accumulates,',
#   'abandons',
#   'a',
#   'according',
#   'arbitrary',
#   'assuming',
#   'and',
#   'at',
#   'about',
#   'age',
#   'abandon',
#   'and',
#   'all',
#   'as',
#   'an',
#   'as',
#   'and',
#   'and',
#   'an',
#   'all',
#   'all',
#   'a',
#   'assess',
#   'account,',
#   'as',
#   'about',
#   'aspiration.',
#   'all',
#   'are',
#   'abuse',
#   'any',
#   'a',
#   'at',
#   'and',
#   'a',
#   'also',
#   'abandon',
#   'any',
#   'and',
#   'a',
#   'away’',
#   'as',
#   'aptly',
#   'another…Everyone',
#   'a',
#   'actions,',
#   'and',
#   'actions,',
#   'as',
#   'at',
#   'am',
#   'all',
#   'aware',
#   'and',
#   'allows',
#   'are',
#   'and',
#   'are',
#   'are',
#   'a',
#   'and',
#   'against',
#   'after',
#   'admittedly',
#   'a',
#   'a',
#   'a',
#   'and',
#   'above',
#   'all,',
#   'as',
#   'a',
#   'against',
#   'a',
#   'appears',
#   'all',
#   'and',
#   'arises',
#   'and',
#   'all',
#   'and',
#   'articles,',
#   'and',
#   'and',
#   'art,',
#   'applying',
#   'activity',
#   'affected',
#   'as',
#   'amusing',
#   'a',
#   'an',
#   'anthology',
#   'as',
#   'a',
#   'as',
#   'authors',
#   'an',
#   'ago,',
#   'assured',
#   'as',
#   'as',
#   'at',
#   'and',
#   'an',
#   'almost',
#   'as',
#   'authors’',
#   'ambition',
#   'are',
#   'amusing',
#   'at',
#   'a',
#   'and',
#   'all,',
#   'am',
#   'at',
#   'about',
#   'a',
#   'author',
#   'and',
#   'and',
#   'a',
#   'all…There',
#   'about',
#   'all',
#   'a',
#   'an',
#   'a',
#   'and',
#   'against',
#   'against',
#   'amounted',
#   'all',
#   'and',
#   'am',
#   'admit,',
#   'a',
#   'argued',
#   'and',
#   'at',
#   'author',
#   'avoid',
#   'a',
#   'and',
#   'am',
#   'and',
#   'an',
#   'action',
#   'any',
#   'a',
#   'along',
#   'a',
#   'a',
#   'about',
#   'author',
#   'a',
#   'and,',
#   'about',
#   'actions',
#   'and',
#   'are',
#   'admirably',
#   'about',
#   'appear',
#   'about,',
#   'and',
#   'again,',
#   'always',
#   'am',
#   'a',
#   'adversary.',
#   'are',
#   'as',
#   'avoid',
#   'as',
#   'as',
#   'all',
#   'a',
#   'alike,',
#   'among',
#   'among',
#   'all',
#   'a',
#   'are',
#   'analysis',
#   'and',
#   'an',
#   'abstract',
#   'a',
#   'and',
#   'achieving',
#   'action',
#   'at',
#   'a',
#   'are',
#   'author’s',
#   'appraisal,',
#   'a',
#   'adds',
#   'are',
#   'am',
#   'at.',
#   'are',
#   'applicable',
#   'absolute',
#   'allows',
#   'aims',
#   'add',
#   'about',
#   'a',
#   'and',
#   'and',
#   'accompanied',
#   'any',
#   'accepted',
#   'a',
#   'and',
#   'a',
#   'at',
#   'able',
#   'authorised',
#   'as',
#   'account',
#   'against',
#   'and',
#   'an',
#   'a',
#   'as',
#   'as',
#   'and',
#   'are',
#   'applied',
#   'activity',
#   'at',
#   'a',
#   'and',
#   'attention.',
#   'awake',
#   'and',
#   'asleep,',
#   'always',
#   'astonished',
#   'are',
#   'above',
#   'all',
#   'and',
#   'all',
#   'and',
#   'a',
#   'a',
#   'a',
#   'as',
#   'as',
#   'affairs',
#   'are',
#   'all',
#   'appearances,',
#   'are',
#   'and',
#   'alone',
#   'arrogates',
#   'and',
#   'as',
#   'a',
#   'at',
#   'any',
#   'a',
#   'a',
#   'about',
#   'a',
#   'awake,',
#   'all',
#   'activities,',
#   'a',
#   'according',
#   'a',
#   'as',
#   'and',
#   'as',
#   'accord',
#   'a',
#   'acute?',
#   'also',
#   'applied',
#   'as',
#   'and',
#   'are',
#   'already',
#   'any',
#   'age,',
#   'and',
#   'ages',
#   'awake.',
#   'am',
#   'as',
#   'a',
#   'a',
#   'and',
#   'all',
#   'a',
#   'and,',
#   'an',
#   'a',
#   'and',
#   'as',
#   'all',
#   'a',
#   'attributes',
#   'angle',
#   'at',
#   'agonising',
#   'are',
#   'among',
#   'allow',
#   'all',
#   'ask,',
#   'a',
#   'a',
#   'as',
#   'and',
#   'arrived,',
#   'awakening',
#   'abruptly,',
#   'accept',
#   'an',
#   'accounting',
#   'a',
#   'all',
#   'and',
#   'amplitude,',
#   'are',
#   'and',
#   'a',
#   'absolute',
#   'a',
#   'am',
#   'about,',
#   'a',
#   'at',
#   'a',
#   'a',
#   'a',
#   'alone',
#   'a',
#   'altogether',
#   'about',
#   'always',
#   'alone',
#   'a',
#   'as',
#   'admirable',
#   'animates',
#   'author',
#   'all',
#   'act',
#   'an',
#   'and',
#   'and',
#   'aspires',
#   'and',
#   'an',
#   'a',
#   'accuracy',
#   'and',
#   'admirable',
#   'about',
#   'and',
#   'a',
#   'a',
#   'a',
#   'a',
#   'and',
#   'a',
#   'a',
#   'accepted',
#   'as',
#   'a',
#   'arbitrary',
#   'and',
#   'and',
#   'again,',
#   'are',
#   'are',
#   'addressed',
#   'an',
#   'age',
#   'are',
#   'and',
#   'as',
#   'adults',
#   'and',
#   'agree',
#   'are',
#   'adorable',
#   'a',
#   'and',
#   'attraction',
#   'are',
#   'are',
#   'as',
#   'all',
#   'ages;',
#   'any',
#   'any',
#   'appurtenances',
#   'an',
#   'and',
#   'are',
#   'affected',
#   'are',
#   'an',
#   'am',
#   'a',
#   'age,',
#   'anyone',
#   'and',
#   'as',
#   'all',
#   'a',
#   'at',
#   'a',
#   'are',
#   'and',
#   'as',
#   'a',
#   'are',
#   'autos',
#   'are',
#   'and',
#   'are',
#   'and',
#   'an',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'a',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'a',
#   'are,',
#   'as',
#   'about',
#   'and',
#   'a',
#   'and',
#   'a',
#   'are',
#   'always',
#   'and',
#   'another.',
#   'are',
#   'and',
#   'and',
#   'about',
#   'and',
#   'a',
#   'are',
#   'are',
#   'another,',
#   'and',
#   'and',
#   'alone',
#   'a',
#   'anarchy.',
#   'a',
#   'also',
#   'a',
#   'a',
#   'an',
#   'and',
#   'and',
#   'absurd',
#   'abyss,',
#   'artificial',
#   'are',
#   'already',
#   'a',
#   'and',
#   'a',
#   'and',
#   'a',
#   'at',
#   'appears',
#   'all',
#   'are',
#   'all',
#   'are',
#   'also',
#   'an',
#   'arrow',
#   'and',
#   'attain',
#   'an',
#   'analysis',
#   'attention',
#   'able',
#   'any',
#   'at',
#   'attempted',
#   'aspirations',
#   'as',
#   'a',
#   'a',
#   'as',
#   'apologising',
#   'and',
#   'ability',
#   'a',
#   'a',
#   'a',
#   'a',
#   'achieved',
#   'and',
#   'admit',
#   'around',
#   'a',
#   'and',
#   'a',
#   'at',
#   'a',
#   'and',
#   'as',
#   'as',
#   'as',
#   'as',
#   'am).',
#   'a',
#   'a',
#   'and',
#   'appear)',
#   'and',
#   'an',
#   'application',
#   'advertising',
#   'a',
#   'a',
#   'advertisement',
#   'a',
#   'at',
#   'as',
#   'as',
#   'a',
#   'a',
#   'a',
#   'and',
#   'and',
#   'and',
#   'a',
#   'aesthetic,',
#   'an',
#   'aesthetic',
#   'a',
#   'amidst',
#   'all',
#   'asleep,',
#   'articulated',
#   'a',
#   'any',
#   'a',
#   'any',
#   'agrees,',
#   'at',
#   'a',
#   'a',
#   'at',
#   'and',
#   'astonished',
#   'a',
#   'ambiguity,',
#   'accompanied',
#   'as',
#   'a',
#   'a',
#   'a',
#   'at',
#   'angles',
#   'axis',
#   'a',
#   'attention',
#   'at',
#   'apparitions,',
#   'and',
#   'are',
#   'as',
#   'as',
#   'auditory',
#   'a',
#   'and',
#   'a',
#   'again',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'am',
#   'achieving',
#   'a',
#   'at',
#   'am',
#   'and',
#   'accepted',
#   'as',
#   'a',
#   'and',
#   'as',
#   'a',
#   'a',
#   'a',
#   'an',
#   'a',
#   'and',
#   'among',
#   'accorded',
#   'an',
#   'almost',
#   'and',
#   'an',
#   'and',
#   'all',
#   'an',
#   'attributes',
#   'as',
#   'and',
#   'are',
#   'a',
#   'a',
#   'apartment',
#   'above',
#   'awake',
#   'and',
#   'a',
#   'a',
#   'a',
#   'as',
#   'and',
#   'a',
#   'and',
#   'as',
#   'a',
#   'an',
#   'artery',
#   'another,',
#   'adapted',
#   'after',
#   'another',
#   'and',
#   'and',
#   'a',
#   'and',
#   'as',
#   'as',
#   'an',
#   'as',
#   'and',
#   'a',
#   'as',
#   'as',
#   'as',
#   'as',
#   'appeared',
#   'and',
#   'about',
#   'and',
#   'and',
#   'a',
#   'a',
#   'achieved',
#   'able',
#   'and',
#   'all,',
#   'and',
#   'analogous:',
#   'also,',
#   'a',
#   'a',
#   'a',
#   'a',
#   'and,',
#   'and',
#   'a',
#   'apparent',
#   'and',
#   'allow',
#   'at',
#   'and',
#   'a',
#   'a',
#   'and',
#   'any',
#   'appeared',
#   'at',
#   'all',
#   'absolutely',
#   'and',
#   'and',
#   'at',
#   'and',
#   'an',
#   'assess',
#   'at',
#   'appreciate',
#   'at',
#   'are,',
#   'all',
#   'appearances,',
#   'as',
#   'as',
#   'and',
#   'are',
#   'above',
#   'all',
#   'a',
#   'absurdity,',
#   'absurdity,',
#   'admissible,',
#   'a',
#   'and',
#   'all',
#   'and',
#   'a',
#   'an',
#   'and',
#   'adopted',
#   'and',
#   'a',
#   'appropriate',
#   'appropriated',
#   'and',
#   'also',
#   'a',
#   'as',
#   'and',
#   'are',
#   'are,',
#   'asked',
#   'again.’',
#   'as',
#   'all.',
#   'at',
#   'are',
#   'and',
#   'at',
#   'also',
#   'and',
#   'all:',
#   'automatism',
#   'any',
#   'actual',
#   'absence',
#   'any',
#   'any',
#   'aesthetic',
#   'association,',
#   'all',
#   'and',
#   'acts',
#   'appear,',
#   'and',
#   'about',
#   'a',
#   'and',
#   'attempts',
#   'at',
#   'an',
#   'abuse',
#   'attributed',
#   'any',
#   'are',
#   'a',
#   'a',
#   'a',
#   'adventure.',
#   'and',
#   'absinthe.',
#   'atmosphere.',
#   'at',
#   'at',
#   'a',
#   'anecdote.',
#   'are',
#   'always',
#   'a',
#   'at',
#   'and',
#   'above',
#   'and',
#   'at',
#   'all',
#   'a',
#   'and',
#   'artists,',
#   'among',
#   'among',
#   'and',
#   'admirable',
#   'and',
#   'are',
#   'any',
#   'attempt',
#   'are',
#   'a',
#   'as',
#   'above.',
#   'ask',
#   'and',
#   'a',
#   'at',
#   'and',
#   'a',
#   'an',
#   'a',
#   'am',
#   'against',
#   'a',
#   'and',
#   'and',
#   'and',
#   'and',
#   'accomplice,',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'a',
#   'a',
#   'around',
#   'a',
#   'asked',
#   'ask',
#   'any',
#   'and',
#   'and',
#   'at',
#   'agility',
#   'as',
#   'as',
#   'an',
#   'and',
#   'and',
#   'are',
#   'a',
#   'as',
#   'as',
#   'about',
#   'and',
#   'and',
#   'are',
#   'arise',
#   'a',
#   'asks',
#   'about',
#   'activity',
#   'and',
#   'agree',
#   'a',
#   'and',
#   'a',
#   'absolute',
#   'although',
#   'as',
#   'as',
#   'a',
#   'as',
#   'as',
#   'an',
#   'an',
#   'a',
#   'a',
#   'and',
#   'arbitrary',
#   'at',
#   'anyone,',
#   'and',
#   'activity,',
#   'arms',
#   'are',
#   'an',
#   'all',
#   'all',
#   'and',
#   'a',
#   'an',
#   'a',
#   'and',
#   'a',
#   'apart.',
#   'achieve',
#   'allowing',
#   'and',
#   'among',
#   'and',
#   'all-consuming',
#   'are,',
#   'a',
#   'and',
#   'a',
#   'at',
#   'and',
#   'are',
#   'appearance:',
#   'and',
#   'as',
#   'active',
#   'as',
#   'about,',
#   'and',
#   'and',
#   'assistance',
#   'assured',
#   'a',
#   'a',
#   'and',
#   'a',
#   'appearing',
#   'about',
#   'a',
#   'a',
#   'a',
#   'and',
#   'all',
#   'agree',
#   'as',
#   'an',
#   'analogous',
#   'and',
#   'a',
#   'a',
#   'arrangements',
#   'ask',
#   'a',
#   'and',
#   'accomplish',
#   'among',
#   'a',
#   'a',
#   'average,',
#   'about',
#   'a',
#   'a',
#   'absence',
#   'a',
#   'and',
#   'anything',
#   'at',
#   'all',
#   'advance.',
#   'a',
#   'a',
#   'about',
#   'abundance.',
#   'admirable',
#   'am',
#   'always',
#   'and',
#   'a',
#   'a',
#   'again',
#   'another',
#   'among',
#   'at',
#   'a',
#   'and',
#   'adapt',
#   'all',
#   'any',
#   'an',
#   'and',
#   ...],
#  'b': ['belief',
#   'by',
#   'belief',
#   'by',
#   'been',
#   'been',
#   'been',
#   'babe,',
#   'been',
#   'by',
#   'becomes',
#   'beyond',
#   'black',
#   'be',
#   'be',
#   'by',
#   'become',
#   'because,',
#   'belongs',
#   'body',
#   'believe',
#   'be',
#   'begin,',
#   'been',
#   'be',
#   'be,',
#   'be',
#   'but',
#   'banner',
#   'be',
#   'but',
#   'be',
#   'by',
#   'be',
#   'books,',
#   'back',
#   'bordering',
#   'by',
#   'best',
#   'by',
#   'brings',
#   'bouts',
#   'be',
#   'because,',
#   'be',
#   'be',
#   'book,',
#   'be',
#   'but',
#   'back,',
#   'birds',
#   'be',
#   'burdening',
#   'but',
#   'best.',
#   'be',
#   'be',
#   'being',
#   'be',
#   'being',
#   'bear',
#   'bearing',
#   'broad',
#   'blowing',
#   'bunch',
#   'brains',
#   'by',
#   'by',
#   'by',
#   'be',
#   'been',
#   'banter;',
#   'by',
#   'being',
#   'by',
#   'by',
#   'banish',
#   'be',
#   'by',
#   'be',
#   'brought',
#   'back',
#   'basis',
#   'by',
#   'be',
#   'be',
#   'be',
#   'be,',
#   'be',
#   'be',
#   'birth',
#   'beings',
#   'being',
#   'be',
#   'because',
#   'beings,',
#   'bounds',
#   'be',
#   'back',
#   'beneath',
#   'branches.',
#   'be',
#   'be',
#   'back',
#   'behind',
#   'be',
#   'believe',
#   'being',
#   'beginning',
#   'be',
#   'but',
#   'balanced',
#   'be',
#   'by',
#   'be',
#   'become,',
#   'binds',
#   'be',
#   'be',
#   'believe',
#   'beast',
#   'breaks',
#   'because',
#   'been',
#   'by',
#   'be',
#   'but',
#   'by',
#   'believe',
#   'but',
#   'before',
#   'be',
#   'but',
#   'beneath',
#   'bury',
#   'beat',
#   'bush:',
#   'beautiful,',
#   'beautiful,',
#   'be',
#   'beautiful.',
#   'belong',
#   'bears',
#   'breath',
#   'before',
#   'book,',
#   'beginning',
#   'belonging',
#   'bettered',
#   'being.',
#   'by',
#   'borrowed',
#   'by',
#   'be,',
#   'be',
#   'be',
#   'by',
#   'bad',
#   'blood-stained',
#   'banal',
#   'belongs',
#   'been',
#   'be',
#   'by',
#   'birds;',
#   'balloon,',
#   'brother,',
#   'both',
#   'but',
#   'by',
#   'be',
#   'bother',
#   'belong',
#   'bears',
#   'be',
#   'break',
#   'bread',
#   'be',
#   'balustrade',
#   'between',
#   'be',
#   'being',
#   'been',
#   'become',
#   'being',
#   'but',
#   'benefit',
#   'blank',
#   'book.',
#   'believed',
#   'but',
#   'begun',
#   'but',
#   'brain',
#   'be',
#   'but',
#   'bets',
#   'best',
#   'barrage',
#   'be',
#   'book,',
#   'but',
#   'brilliant',
#   'boring',
#   'be',
#   'born',
#   'but',
#   'between',
#   'before',
#   'but',
#   'bizarre',
#   'bearing',
#   'been',
#   'but',
#   'by',
#   'but',
#   'by',
#   'by',
#   'body.',
#   'blank',
#   'but',
#   'be',
#   'been',
#   'by',
#   'by',
#   'but',
#   'by',
#   'be',
#   'been',
#   'back',
#   'but',
#   'be',
#   'by',
#   'by',
#   'behind',
#   'bed.',
#   'burst',
#   'bubbled',
#   'because',
#   'by',
#   'bears',
#   'blacken',
#   'began',
#   'but',
#   'both',
#   'been',
#   'buffoonery.',
#   'between',
#   'being',
#   'by',
#   'believe,',
#   'be',
#   'by',
#   'blame',
#   'be',
#   'by',
#   'being',
#   'benefit',
#   'bestow',
#   'by',
#   'bestow',
#   'by',
#   'by',
#   'by',
#   'being',
#   'by',
#   'back',
#   'been',
#   'before',
#   'by',
#   'by',
#   'by',
#   'based',
#   'belief',
#   'be',
#   'be',
#   'beginning',
#   'basic',
#   'by',
#   'be',
#   'bad',
#   'but',
#   'being',
#   'because',
#   'because',
#   'by',
#   'bicorn',
#   'bittern,',
#   'brother',
#   'believe',
#   'birds.',
#   'break',
#   'bowl',
#   'by',
#   'better',
#   'book',
#   'brought,',
#   'being',
#   'be',
#   'both',
#   'break',
#   'blank',
#   'by',
#   'be',
#   'bored',
#   'be',
#   'broken',
#   'better',
#   'banality.',
#   'baubles',
#   'by',
#   'be',
#   'ballot.',
#   'blow',
#   'by',
#   'be',
#   'by',
#   'be',
#   'burn',
#   'begin',
#   'begin.',
#   'be',
#   'be',
#   'beings,',
#   'by',
#   'become',
#   'belly’,',
#   'by',
#   'burying',
#   'be',
#   'been',
#   'by',
#   'beyond',
#   'beyond',
#   'be',
#   'before',
#   'beginning',
#   'but',
#   'believe',
#   'become',
#   'been',
#   'best',
#   'being',
#   'but',
#   'be',
#   'be',
#   'beside',
#   'book',
#   'battle',
#   'by',
#   'between',
#   'by',
#   'because',
#   'by',
#   'behaviour.',
#   'be',
#   'be',
#   'be',
#   'by',
#   'but',
#   'be',
#   'be',
#   'believe,',
#   'between',
#   'before',
#   'be',
#   'beauty',
#   'between',
#   'barely',
#   'be',
#   'by',
#   'by',
#   'beautiful',
#   'by',
#   'becomes',
#   'becomes',
#   'betray',
#   'borne',
#   'by',
#   'beautiful',
#   'because',
#   'because',
#   'because',
#   'because',
#   'because',
#   'because',
#   'because',
#   'because',
#   'breast',
#   'brilliant',
#   'bell.',
#   'bread',
#   'bridge',
#   'but',
#   'blood',
#   'blazing',
#   'benign',
#   'bad',
#   'by',
#   'bids',
#   'best',
#   'being',
#   'being',
#   'beyond',
#   'bring',
#   'born',
#   'believe',
#   'balance',
#   'because',
#   'benefits',
#   'be',
#   'by',
#   'burst',
#   'beautiful',
#   'be',
#   'be',
#   'be',
#   'be',
#   'be',
#   'by',
#   'be',
#   'benefit',
#   'because',
#   'barely',
#   'book',
#   'book,',
#   'book',
#   'being',
#   'book',
#   'begin',
#   'be',
#   'believe',
#   'but',
#   'bottom',
#   'been',
#   'been',
#   'book',
#   'by',
#   'buildings',
#   'been',
#   'by',
#   'be',
#   'be',
#   'briefly,',
#   'be',
#   'ballet,',
#   'be',
#   'ballets.',
#   'be',
#   'because',
#   'but',
#   'by',
#   'believe,',
#   'beaten,',
#   'by',
#   'bring',
#   'be',
#   'bringing',
#   'before',
#   'below.',
#   'blue;'],
#  'c': ['consented',
#   'chancing',
#   'calls',
#   'consent',
#   'conscience,',
#   'can',
#   'childhood,',
#   'charm.',
#   'constraint,',
#   'children',
#   'concern.',
#   'circumstances',
#   'conquered.',
#   'collect',
#   'consider',
#   'called',
#   'could',
#   'circumstance',
#   'conducive',
#   'concede',
#   'certain',
#   'curious',
#   'confidences',
#   'could',
#   'compels',
#   'case',
#   'considered,',
#   'considering',
#   'complete',
#   'certain',
#   'certain',
#   'contrast,',
#   'conceit.',
#   'clarity',
#   'common',
#   'compilation',
#   'concerned,',
#   'continue',
#   'circumstantial,',
#   'characterisation:',
#   'called,',
#   'choice',
#   'close',
#   'care',
#   'can',
#   'compared',
#   'catalogue,',
#   'curtains',
#   'cast',
#   'chamber.',
#   'curved',
#   'chairs',
#   'childish',
#   'continuity',
#   'ceases',
#   'condemning',
#   'crystallise',
#   'care',
#   'character,',
#   'calculations',
#   'can',
#   'chess',
#   'can’t',
#   'candle,',
#   'categories?',
#   'coughing,',
#   'contains',
#   'classifiable.',
#   'carries',
#   'capacity',
#   'commit',
#   'certain',
#   'ceases',
#   'course,',
#   'consider',
#   'contrast,',
#   'cage',
#   'common',
#   'civilisation,',
#   'conform',
#   'chance,',
#   'concerned,',
#   'current',
#   'contain',
#   'capable',
#   'control',
#   'conducting',
#   'can',
#   'capricious,',
#   'critical',
#   'considerable',
#   'continuity:',
#   'considering',
#   'cease',
#   'concern.',
#   'continuing',
#   'curious',
#   'call',
#   'certain',
#   'continuous',
#   'configuration',
#   'coordination',
#   'can',
#   'contemplating',
#   'concerning',
#   'constituent',
#   'cease',
#   'conscious',
#   'continues',
#   'continued',
#   'certainty',
#   'consciousness',
#   'case',
#   'consider',
#   'come',
#   'commend',
#   'can',
#   'calls',
#   'chance,',
#   'can',
#   'capable',
#   'content',
#   'content.',
#   'certain',
#   'confers',
#   'confound',
#   'can',
#   'curve',
#   'contradictory,',
#   'certain',
#   'certain',
#   'could',
#   'capable',
#   'characters',
#   'constraint,',
#   'constitutes',
#   'character',
#   'creation',
#   'could',
#   'credit',
#   'character',
#   'continual',
#   'character',
#   'convincing',
#   'critical',
#   'contest',
#   'critical',
#   'children.',
#   'children',
#   'consider',
#   'change',
#   'chance,',
#   'capable',
#   'consideration,',
#   'certain',
#   'couches.',
#   'coincide',
#   'castle,',
#   'castle',
#   'comfort.',
#   'cloaked',
#   'captive',
#   'cordial,',
#   'could',
#   'commands.',
#   'certain',
#   'castle,',
#   'commence',
#   'convicted',
#   'castle',
#   'castle',
#   'could',
#   'completely,',
#   'compensation',
#   'can',
#   'choose',
#   'coming',
#   'choice,',
#   'careful',
#   'case',
#   'complete',
#   'contract',
#   'concluded',
#   'composed,',
#   'concern',
#   'closed',
#   'complicity,',
#   'cherish',
#   'confessions.',
#   'concerned',
#   'could,',
#   'claimed',
#   'creation',
#   'cannot',
#   'comparison',
#   'causes.',
#   'clearly',
#   'change',
#   'came',
#   'consciousness',
#   'came',
#   'clear',
#   'could',
#   'could',
#   'currently',
#   'convinced',
#   'convince',
#   'contains',
#   'could',
#   'construction.',
#   'continuous',
#   'control',
#   'could',
#   'clearly',
#   'clock',
#   'could',
#   'choice',
#   'came',
#   'chance,',
#   'conceived.',
#   'correct',
#   'context,',
#   'came',
#   'copiously',
#   'could',
#   'could,',
#   'continual',
#   'continued',
#   'claimed',
#   'created',
#   'cenesthetic',
#   'colic,',
#   'critical',
#   'consequently',
#   'comprising,',
#   'came',
#   'capture',
#   'confided',
#   'conclusions,',
#   'comparing',
#   'construction,',
#   'considerable',
#   'capable',
#   'creating',
#   'certain',
#   'criticism,',
#   'committed',
#   'certain',
#   'constantly,',
#   'correction,',
#   'closer',
#   'certain',
#   'could',
#   'claim',
#   'contrast,',
#   'certain',
#   'cannot',
#   'characters.',
#   'convincingly',
#   'convinced',
#   'composed',
#   'charm',
#   'concede',
#   'clear',
#   'currency.',
#   'control',
#   'concern.',
#   'certain',
#   'completely,',
#   'case',
#   'course,',
#   'considers',
#   'course',
#   'confidence,',
#   'called',
#   'can',
#   'clergyman',
#   'clergyman,',
#   'clergyman.',
#   'confidences.',
#   'certain',
#   'clung.',
#   'clung',
#   'continues',
#   'close',
#   'cause.',
#   'cheap',
#   'cities.’',
#   'cave-bear',
#   'carnivore',
#   'carnival,',
#   'coral',
#   'could',
#   'closest',
#   'course',
#   'composition,',
#   'can.',
#   'cannot',
#   'case',
#   'conscious',
#   'conscious',
#   'case',
#   'counter',
#   'continuity',
#   'concerns',
#   'committed',
#   'company',
#   'crossed,',
#   'can’t',
#   'country',
#   'considers',
#   'consultations.',
#   'carve',
#   'carcase.',
#   'concede',
#   'characters',
#   'can',
#   'capital',
#   'conduct',
#   'credit',
#   'characteristics,',
#   'conduct',
#   'care',
#   'course,',
#   'can',
#   'criticism.',
#   'catch',
#   'conducted',
#   'cemetery',
#   'copy',
#   'can',
#   'conversing',
#   'conversing)',
#   'capable',
#   'contracted',
#   'can',
#   'could',
#   'convince',
#   'chooses',
#   'comprehend',
#   'comprehend',
#   'causes',
#   'compensation',
#   'circumstances',
#   'corresponded',
#   'consciousness',
#   'contact',
#   'confront',
#   'consideration',
#   'can',
#   'cannot',
#   'conversation,',
#   'certain',
#   'continuing',
#   'conversation',
#   'considerable',
#   'conceal',
#   'constant',
#   'case,',
#   'construed,',
#   'creates',
#   'certain',
#   'can',
#   'comes',
#   'criticism,',
#   'can',
#   'cannot',
#   'can',
#   'conjoin',
#   'conjunction',
#   'consciously.',
#   'certain',
#   'consequently,',
#   'conductors.',
#   'comparison',
#   'conjunction',
#   'conceive',
#   'conjure',
#   'created',
#   'conducive',
#   'convinced',
#   'confining',
#   'conscious',
#   'constantly',
#   'cool',
#   'compared',
#   'call',
#   'classification,',
#   'common',
#   'contains',
#   'contradiction;',
#   'compass);',
#   'concrete',
#   'conversely,',
#   'church',
#   'comes',
#   'cool.',
#   'colour',
#   'commonly',
#   'charged',
#   'circumstances',
#   'commonly',
#   'circumstances,',
#   'consequences',
#   'cited',
#   'conviction',
#   'convicting',
#   'childhood.',
#   'conviction',
#   'childhood',
#   'childhood',
#   'comes',
#   'closest',
#   'childhood',
#   'complimentary',
#   'childhood',
#   'conspires',
#   'call',
#   'common',
#   'characteristics',
#   'cited,',
#   'consider',
#   'comprise',
#   'contribution',
#   'consciousness.',
#   'certain',
#   'commonplace',
#   'collection',
#   'café',
#   'could',
#   'covers',
#   'could',
#   'criticism',
#   'concern',
#   'concerning',
#   'considerations',
#   'complete',
#   'character',
#   'clearly',
#   'circumstances?',
#   'case,',
#   'citizens',
#   'complaint',
#   'charged',
#   'charges',
#   'claiming',
#   'concoction',
#   'certain',
#   'city,',
#   'cellar,',
#   'concierge',
#   'childish',
#   'could',
#   'comprehend',
#   'certain',
#   'constitutes',
#   'confess',
#   'chooses,',
#   'can.',
#   'confess,',
#   'credit',
#   'cutaneous',
#   'continuously.',
#   'clearly',
#   'can',
#   'court,',
#   'contrary,',
#   'carcase.’',
#   'ceasing'],
#  'd': ['dreamer,',
#   'discontented',
#   'day',
#   'day',
#   'difficulty',
#   'does',
#   'degree',
#   'do',
#   'dare',
#   'distance.',
#   'destiny.',
#   'do',
#   'deepest',
#   'dreadful',
#   'does',
#   'derive',
#   'delirium',
#   'discover',
#   'degeneration.',
#   'dull',
#   'day.',
#   'dogs.',
#   'denominator',
#   'declarative',
#   'do',
#   'descriptions!',
#   'decorated',
#   'dressing',
#   'description',
#   'does',
#   'depression',
#   'description',
#   'disturb,',
#   'despite',
#   'do',
#   'disinterested',
#   'debates',
#   'does,',
#   'do',
#   'describe',
#   'dulled',
#   'desire',
#   'derives',
#   'discussion',
#   'date',
#   'definitive',
#   'domain,',
#   'driving',
#   'day,',
#   'directly',
#   'difficult',
#   'does',
#   'discoveries.',
#   'depths',
#   'defined',
#   'depend',
#   'dreams.',
#   'death',
#   'dream',
#   'dream',
#   'difference',
#   'dreams',
#   'depriving',
#   'distancing',
#   'determinant',
#   'delivers',
#   'does.',
#   'dreams,',
#   'dreams',
#   'dream',
#   'distinct',
#   'depth',
#   'dream.',
#   'delight',
#   'dream',
#   'day’s',
#   'dark',
#   'dense',
#   'dissipation',
#   'dream.',
#   'dream,',
#   'dreamers,',
#   'deliver',
#   'dream',
#   'doing',
#   'dream',
#   'dream',
#   'domain',
#   'dream-signs',
#   'degree',
#   'daily',
#   'dream',
#   'dream?',
#   'dream',
#   'dream,',
#   'due',
#   'does',
#   'display,',
#   'disorientation',
#   'does',
#   'depths',
#   'dares',
#   'does,',
#   'depositing',
#   'divinity',
#   'distraction.',
#   'dream,',
#   'data',
#   'dreams',
#   'die,',
#   'dead?',
#   'defer',
#   'dream,',
#   'day',
#   'determined,',
#   'dream',
#   'discipline',
#   'dream',
#   'death',
#   'door',
#   'deal',
#   'discussion:',
#   'do',
#   'delivered',
#   'dares’',
#   'does',
#   'denouement.',
#   'discussing',
#   'demeaning',
#   'do',
#   'devices',
#   'deceitful',
#   'dissimulate’',
#   'desired',
#   'door,',
#   'departing;',
#   'deciphering',
#   'duelling;',
#   'demoralisation',
#   'deal',
#   'doors',
#   'does',
#   'don’t',
#   'deceit:',
#   'does',
#   'disposes.',
#   'desires,',
#   'daily',
#   'do',
#   'disappointment',
#   'decree',
#   'dared',
#   'dreams',
#   'danger,',
#   'degree',
#   'disproportion',
#   'defence',
#   'done',
#   'deal',
#   'direction',
#   'depends',
#   'discover',
#   'disapproved.',
#   'doubtless',
#   'difficulty',
#   'do,',
#   'differently.',
#   'de',
#   'derive',
#   'deceit',
#   'delight',
#   'difficulty',
#   'did',
#   'derives',
#   'did',
#   'day.',
#   'dull',
#   'ditchwater',
#   'defying',
#   'definitions',
#   'days,',
#   'driven',
#   'distinct',
#   'dare',
#   'doubt',
#   'decided',
#   'day,',
#   'depicting',
#   'dive',
#   'demonstrated',
#   'drawings,',
#   'drawings',
#   'dealing',
#   'deriving',
#   'did',
#   'day',
#   'during',
#   'describes',
#   'day',
#   'dark.',
#   'draft,',
#   'details',
#   'disorder',
#   'during',
#   'delivered',
#   'does',
#   'does',
#   'defy',
#   'disdain',
#   'day,',
#   'deficiencies,',
#   'difference',
#   'derive',
#   'doubt',
#   'do',
#   'distraction',
#   'definition,',
#   'detecting',
#   'difficult',
#   'degree',
#   'disclosure',
#   'died,',
#   'discipline',
#   'doing',
#   'designated',
#   'dwelling',
#   'doubt',
#   'de',
#   'dedication',
#   'du',
#   'degree',
#   'dear',
#   'during',
#   'dishonest',
#   'dispute',
#   'define',
#   'dream,',
#   'disinterested',
#   'destruction',
#   'date,',
#   'data.',
#   'doubt,',
#   'death.',
#   'distance.',
#   'discern',
#   'death',
#   'designs',
#   'door,',
#   'destroy',
#   'daughter',
#   'dog,',
#   'disappear',
#   'die',
#   'disturbing',
#   'derived',
#   'do',
#   'does',
#   'draft',
#   'difficult',
#   'doubt',
#   'definitely',
#   'distribution',
#   'difficult.',
#   'doubtless',
#   'do',
#   'do.',
#   'despair',
#   'demands',
#   'does',
#   'depart',
#   'denouement',
#   'degree;',
#   'devote',
#   'death',
#   'death',
#   'destroy',
#   'de',
#   'doing',
#   'difficulty',
#   'doing,',
#   'does',
#   'dealings',
#   'draft',
#   'do',
#   'disservice',
#   'delicate',
#   'disappointment,',
#   'display',
#   'does.',
#   'does',
#   'does',
#   'deprive',
#   'definitions.',
#   'do',
#   'dialogue',
#   'delivered,',
#   'does',
#   'depths',
#   'demand',
#   'decency',
#   'degree',
#   'disorders',
#   'disorder',
#   'does',
#   'dictates',
#   'dialogue',
#   'doctor',
#   'doctor’s',
#   'dedicating',
#   'date',
#   'dialogue',
#   'derive',
#   'dialectical',
#   'developing',
#   'disinterested',
#   'does',
#   'devote',
#   'drugs',
#   'do;',
#   'dependence',
#   'drive',
#   'drugs',
#   'do.',
#   'does',
#   'does',
#   'despotically.',
#   'dispel',
#   'do,',
#   'definition,',
#   'does',
#   'distant',
#   'degree',
#   'depends',
#   'difference',
#   'difference',
#   'distant',
#   'deplores',
#   'do.',
#   'deduced',
#   'does',
#   'desire',
#   'desires',
#   'diminished,',
#   'does',
#   'delight',
#   'day,',
#   'do',
#   'degree',
#   'derives',
#   'development',
#   'dwarf',
#   'dew',
#   'divined',
#   'doubtless',
#   'disturbances.',
#   'declare:',
#   'demands.',
#   'dissipates',
#   'disadvantages',
#   'disconcert',
#   'disconcert',
#   'draws',
#   'drowning',
#   'delinquent,',
#   'disposal;',
#   'dangerous',
#   'deal.',
#   'do',
#   'do',
#   'disordered',
#   'do',
#   'demonstrating',
#   'demand',
#   'desired',
#   'driveable',
#   'do',
#   'dance',
#   'did,',
#   'do',
#   'do',
#   'determine',
#   'degree',
#   'doubt',
#   'decency.',
#   'defaming',
#   'defence',
#   'does',
#   'document',
#   'do',
#   'did',
#   'detective',
#   'detail.',
#   'door.)',
#   'does',
#   'dictates',
#   'destiny?',
#   'devil',
#   'do',
#   'do',
#   'detailed',
#   'days.',
#   'done,',
#   'done,',
#   'don’t',
#   'darkened',
#   'development',
#   'discovery',
#   'directly',
#   'designed',
#   'don’t',
#   'does',
#   'domain',
#   'does',
#   'discoverer',
#   'distantly,',
#   'down',
#   'do',
#   'devoted',
#   'declares',
#   'defence.',
#   'distraction',
#   'distraction',
#   'distraction',
#   'day',
#   'draped'],
#  'e': ['end',
#   'efforts,',
#   'efforts,',
#   'extreme',
#   'everything.',
#   'exercised',
#   'except',
#   'exceptional',
#   'expansiveness,',
#   'events',
#   'events,',
#   'events',
#   'events.',
#   'events,',
#   'exalts',
#   'even',
#   'enough',
#   'enough',
#   'error',
#   'error).',
#   'error',
#   'end',
#   'error,',
#   'even',
#   'enjoy',
#   'enough',
#   'endure',
#   'etc,',
#   'evenings',
#   'endured.',
#   'engenders',
#   'end,',
#   'example,',
#   'ensuing',
#   'example,',
#   'expense.',
#   'encounter',
#   'employs',
#   'etchings',
#   'even',
#   'entering',
#   'equate',
#   'empty',
#   'eating?',
#   'every',
#   'endowed',
#   'enfeeble.',
#   'even,',
#   'exist.',
#   'experience.',
#   'escape',
#   'experience',
#   'everything',
#   'explorer',
#   'every',
#   'everything',
#   'enterprise',
#   'events',
#   'events',
#   'excerpts,',
#   'elements',
#   'excludes',
#   'eyes',
#   'exemplary',
#   'exists',
#   'exposure',
#   'expect',
#   'expect',
#   'errors',
#   'equilibrium',
#   'express',
#   'effect',
#   'else',
#   'even',
#   'eye,',
#   'events',
#   'easiness',
#   'episodes',
#   'eyes,',
#   'ears;',
#   'expiation.',
#   'entirety',
#   'every',
#   'evening,',
#   'everything',
#   'everything',
#   'eternity',
#   'end,',
#   'exalts',
#   'extreme',
#   'example,',
#   'every',
#   'examples',
#   'early',
#   'enjoy',
#   'extravagant,',
#   'eclipse',
#   'endure,',
#   'else.',
#   'endless,',
#   'edict',
#   'equations',
#   'encounter',
#   'essential',
#   'everyone',
#   'exists!',
#   'endure.',
#   'ever',
#   'end',
#   'earth!',
#   'endless',
#   'everything!',
#   'enquiry,',
#   'establish',
#   'everything',
#   'else',
#   'elsewhere.',
#   'endurance.',
#   'entitled:',
#   'elaboration,',
#   'end',
#   'exposition',
#   'eye,',
#   'emerged',
#   'end,',
#   'emotive',
#   'extremely',
#   'eluded',
#   'effects',
#   'evening',
#   'events',
#   'even',
#   'easily',
#   'even',
#   'eyes',
#   'etc.,',
#   'exercised',
#   'end',
#   'eat',
#   'every',
#   'early.',
#   'eyes',
#   'excellent.',
#   'events',
#   'enjoying',
#   'escaped',
#   'etc.)',
#   'even',
#   'ensue',
#   'execution',
#   'end',
#   'extraordinary',
#   'eloquence,',
#   'emotion,',
#   'essence',
#   'error',
#   'error.',
#   'elements',
#   'even',
#   'elements',
#   'examination,',
#   'everything',
#   'end,',
#   'expression',
#   'employed',
#   'explain',
#   'earlier.',
#   'enough',
#   'end',
#   'explained,',
#   'expression…’',
#   'extreme',
#   'employ',
#   'express,',
#   'either',
#   'exercised',
#   'error',
#   'end',
#   'end',
#   'end;',
#   'exoticism.',
#   'elsewhere.',
#   'each',
#   'era',
#   'example,',
#   'echoes,',
#   'ears',
#   'experiments',
#   'everything.',
#   'enough',
#   'each',
#   'externalised.',
#   'entails',
#   'extent,',
#   'establish',
#   'error:',
#   'error,',
#   'example,',
#   'every',
#   'extremely',
#   'eve',
#   'election,',
#   'eternal',
#   'entire',
#   'enemies',
#   'elevated',
#   'elect',
#   'easily',
#   'etc.',
#   'endowed',
#   'eye',
#   'every',
#   'extent',
#   'express',
#   'establish',
#   'effect',
#   'expense',
#   'extraordinary',
#   'expected.',
#   'even',
#   'employed',
#   'exactly',
#   'ever',
#   'entirely',
#   'external;',
#   'enemy;',
#   'employed;',
#   'employ',
#   'effort',
#   'exacting,',
#   'examining',
#   'elicit,',
#   'effects',
#   'engender',
#   'engendered',
#   'evoke',
#   'ever',
#   'emitted',
#   'exists',
#   'effect',
#   'else',
#   'elliptical',
#   'extent',
#   'everyone,',
#   'especially',
#   'even',
#   'expanses',
#   'essentially,',
#   'everyday',
#   'either',
#   'ending',
#   'elementary',
#   'examples:',
#   'eat',
#   'eyes,',
#   'enough',
#   'events',
#   'events',
#   'events.',
#   'equally',
#   'extent',
#   'encompass',
#   'everything.',
#   'exaltation',
#   'events',
#   'encouraging.',
#   'encouraging',
#   'emerges',
#   'exists.',
#   'everything',
#   'efficiently',
#   'elephants',
#   'encounter,',
#   'establishment',
#   'evolution',
#   'essays',
#   'enough',
#   'extremely',
#   'effect',
#   'elaborated.',
#   'employed',
#   'even',
#   'employ',
#   'edge',
#   'examples.',
#   'extenuating',
#   'etc.',
#   'expressed.',
#   'enjoy',
#   'enough,',
#   'en',
#   'evokes',
#   'even',
#   'exteriors',
#   'entered',
#   'endure',
#   'endure',
#   'exhibited',
#   'every',
#   'esteem',
#   'experiments,',
#   'encumber',
#   'envisage',
#   'enough',
#   'episodes,',
#   'earth',
#   'effect',
#   'elsewhere.'],
#  'f': ['fate,',
#   'foolish',
#   'for',
#   'full',
#   'familiar',
#   'furnishes',
#   'facility',
#   'fine.',
#   'far,',
#   'for',
#   'felt',
#   'from',
#   'freedom',
#   'forever,',
#   'fanaticism.',
#   'freedom',
#   'fail',
#   'for',
#   'for',
#   'fear',
#   'for',
#   'for',
#   'fact,',
#   'for',
#   'feels',
#   'for',
#   'from',
#   'fact',
#   'folly',
#   'fear',
#   'foolishness',
#   'furled.',
#   'former,',
#   'from',
#   'from',
#   'feeds',
#   'flattering',
#   'for',
#   'from',
#   'from',
#   'famous',
#   'far',
#   'from',
#   'five.',
#   'fair-haired,',
#   'for',
#   'first',
#   'from',
#   'fall',
#   'furniture,',
#   'furniture.’',
#   'for',
#   'for',
#   'fatigue',
#   'fragile',
#   'feel.',
#   'for',
#   'for',
#   'form,',
#   'for',
#   'for',
#   'feeling.',
#   'force',
#   'from',
#   'for',
#   'first',
#   'flashes',
#   'from',
#   'focusing',
#   'for',
#   'fashion',
#   'facts',
#   'finds',
#   'from',
#   'free',
#   'flag',
#   'from',
#   'fancy,',
#   'forbidding',
#   'for',
#   'flowing,',
#   'further,',
#   'forces',
#   'from',
#   'further',
#   'followed.',
#   'faculties',
#   'from',
#   'from',
#   'feebly,',
#   'from',
#   'finds',
#   'for',
#   'from',
#   'forgotten',
#   'fall.)',
#   'formula',
#   'from',
#   'following',
#   'failing',
#   'free',
#   'from',
#   'from',
#   'from',
#   'fundamental',
#   'functioning',
#   'from',
#   'female',
#   'female,',
#   'for',
#   'from',
#   'fails,',
#   'fault',
#   'fly',
#   'faster,',
#   'for',
#   'facts)',
#   'future',
#   'find',
#   'fertile',
#   'from',
#   'feels',
#   'for',
#   'from',
#   'fantasy',
#   'fantastic',
#   'figurative',
#   'full',
#   'for',
#   'from',
#   'furnish',
#   'for',
#   'fail',
#   'fairy-tales,',
#   'for',
#   'finely,',
#   'for',
#   'faculties',
#   'for',
#   'for',
#   'for',
#   'forever',
#   'from',
#   'force',
#   'further',
#   'from',
#   'far',
#   'from',
#   'for',
#   'few',
#   'friends',
#   'from',
#   'fancy',
#   'fantasies',
#   'falls',
#   'formidable,',
#   'for',
#   'for',
#   'flight',
#   'for',
#   'fall',
#   'for',
#   'field',
#   'follows.',
#   'first',
#   'fact',
#   'focus',
#   'from',
#   'for',
#   'from',
#   'facts,',
#   'for',
#   'from',
#   'from',
#   'for',
#   'for',
#   'from',
#   'for',
#   'for',
#   'from',
#   'foolish',
#   'from',
#   'far',
#   'from',
#   'formulae',
#   'for',
#   'for',
#   'from',
#   'from',
#   'for',
#   'for',
#   'falling',
#   'from',
#   'found',
#   'faint',
#   'focus',
#   'finding',
#   'first',
#   'from',
#   'followed',
#   'for',
#   'from',
#   'five.',
#   'flooded',
#   'few',
#   'fragments',
#   'for',
#   'found,',
#   'followed.',
#   'from',
#   'followed',
#   'found',
#   'flowed',
#   'fast',
#   'first',
#   'familiar',
#   'from',
#   'from',
#   'flow',
#   'frame',
#   'for',
#   'first',
#   'fifty',
#   'from',
#   'from',
#   'fact',
#   'few',
#   'forcefully,',
#   'first',
#   'from',
#   'for',
#   'from',
#   'fact,',
#   'first',
#   'for',
#   'facts',
#   'friends,',
#   'feu,',
#   'fact,',
#   'friend',
#   'find',
#   'for',
#   'functioning',
#   'free',
#   'forms',
#   'following',
#   'for',
#   'fascinating',
#   'fair',
#   'for',
#   'finer',
#   'found',
#   'from',
#   'failed',
#   'full',
#   'failed',
#   'for',
#   'for',
#   'free',
#   'from',
#   'filter,',
#   'filled',
#   'famous',
#   'friend',
#   'for',
#   'from',
#   'feather',
#   'for',
#   'flaming',
#   'for',
#   'fully',
#   'for',
#   'follows',
#   'from',
#   'fly',
#   'first',
#   'favourable',
#   'for',
#   'focusing',
#   'first',
#   'fact',
#   'first',
#   'flow',
#   'for',
#   'for',
#   'full',
#   'flow',
#   'first',
#   'failure,',
#   'failures.',
#   'false',
#   'few',
#   'fan',
#   'flame,',
#   'from',
#   'fixed',
#   'from',
#   'false',
#   'false',
#   'forget',
#   'for',
#   'friends',
#   'functions',
#   'from',
#   'forthcoming',
#   'formulate',
#   'first',
#   'from',
#   'fatal',
#   'for',
#   'favour',
#   'for',
#   'free',
#   'flow',
#   'forever',
#   'fail',
#   'further',
#   'far',
#   'forgotten.',
#   'familiar',
#   'forms',
#   'for',
#   'for',
#   'feed',
#   'fact',
#   'figures',
#   'fragment',
#   'finds',
#   'finest,',
#   'free',
#   'freeing',
#   'from',
#   'for',
#   'for',
#   'first',
#   'for',
#   'few;',
#   'for',
#   'found',
#   'for',
#   'faculties.’',
#   'formal;',
#   'flows',
#   'false,',
#   'fortuitous',
#   'function',
#   'far',
#   'forced',
#   'from',
#   'first',
#   'for',
#   'fire',
#   'fingers.',
#   'for',
#   'far',
#   'for',
#   'from',
#   'formal',
#   'few',
#   'from',
#   'firmament,',
#   'frosted',
#   'freedom’s',
#   'forest,',
#   'for',
#   'forget',
#   'formula,',
#   'for',
#   'from',
#   'fear',
#   'fair',
#   'few',
#   'feeling',
#   'fecund',
#   'from',
#   'few',
#   'fear',
#   'flying’',
#   'fish’',
#   'frightens',
#   'fish,',
#   'fauna',
#   'flora',
#   'from',
#   'five',
#   'for',
#   'furnish',
#   'for',
#   'for',
#   'from',
#   'for',
#   'from',
#   'fragments',
#   'from',
#   'farm',
#   'for',
#   'for',
#   'fire',
#   'fine',
#   'finished',
#   'find',
#   'future',
#   'for',
#   'first',
#   'for',
#   'fellow',
#   'further,',
#   'foreign',
#   'for',
#   'for',
#   'favour.',
#   'for',
#   'far',
#   'foggiest',
# ...
#   'the',
#   'taken',
#   'the',
#   'to',
#   'there',
#   'to',
#   'the',
#   'the',
#   'the',
#   'the',
#   'thing',
#   'that',
#   'too?',
#   'the',
#   'they',
#   'that',
#   'tale.',
#   'they',
#   'that',
#   'the',
#   'to',
#   'them',
#   'the',
#   'there',
#   'to',
#   'their',
#   'the',
#   'that',
#   'there.',
#   'there.',
#   'there,',
#   'the',
#   'to',
#   'to',
#   'to',
#   'that',
#   'to',
#   'the',
#   'teaches',
#   'to',
#   'the',
#   'the',
#   'to',
#   'take',
#   'time',
#   'to',
#   'the',
#   'to',
#   'take',
#   'to',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'time',
#   'take',
#   'to',
#   'to',
#   'to',
#   'try',
#   'to',
#   'that',
#   'there',
#   'this',
#   'the',
#   'that',
#   'to',
#   'the',
#   'there.',
#   'that',
#   'to',
#   'to',
#   'take',
#   'to',
#   'to',
#   'those',
#   'troublesome,',
#   'the',
#   'to',
#   'there.',
#   'there.',
#   'taking',
#   'that',
#   'trouble,',
#   'tempted',
#   'to',
#   'that',
#   'the',
#   'those',
#   'that',
#   'to',
#   'the',
#   'true',
#   'the',
#   'traveller’s',
#   'the',
#   'travelled.',
#   'to',
#   'the',
#   'that',
#   'to',
#   'the',
#   'to',
#   'the',
#   'to',
#   'them',
#   'that',
#   'time',
#   'the',
#   'that',
#   'the',
#   'today,',
#   'trusted',
#   'tardiness',
#   'to',
#   'that',
#   'thought',
#   'the',
#   'to',
#   'to',
#   'to',
#   'the',
#   'to',
#   'the',
#   'the',
#   'that',
#   'the',
#   'that',
#   'to',
#   'the',
#   'that',
#   'the',
#   'to',
#   'the',
#   'thought',
#   'that',
#   'them.',
#   'the',
#   'to',
#   'they',
#   'they',
#   'them,',
#   'their',
#   'tangencies',
#   'this',
#   'took',
#   'to',
#   'take',
#   'that',
#   'that',
#   'time,',
#   'these',
#   'that',
#   'time,',
#   'trying',
#   'to',
#   'thought',
#   'to',
#   'that',
#   'the',
#   'taken',
#   'turning,',
#   'the',
#   'to',
#   'to',
#   'to',
#   'that',
#   'the',
#   'those',
#   'the',
#   'two',
#   'the',
#   'the',
#   'two',
#   'true,',
#   'the',
#   'the',
#   'the',
#   'to',
#   'the',
#   'them',
#   'the',
#   'totally',
#   'to',
#   'this',
#   'that',
#   'to',
#   'then,',
#   'that',
#   'to',
#   'the',
#   'to',
#   'trace',
#   'the',
#   'that',
#   'time,',
#   'to',
#   'that',
#   'the',
#   'took',
#   'to',
#   'the',
#   'to',
#   'today;',
#   'two',
#   'the',
#   'to',
#   'the',
#   'this',
#   'to',
#   'than',
#   'the',
#   'the',
#   'that',
#   'to',
#   'they',
#   'to',
#   'trace',
#   'their',
#   'tracing.',
#   'this',
#   'tree,',
#   'things,',
#   'the',
#   'through',
#   'to',
#   'the',
#   'times',
#   'to',
#   'to',
#   'through',
#   'the',
#   'that',
#   'the',
#   'the',
#   'the',
#   'that',
#   'think',
#   'to',
#   'this',
#   'than',
#   'that',
#   'the',
#   'till',
#   'then',
#   'think',
#   'to',
#   'the',
#   'taking',
#   'this',
#   'the',
#   'true',
#   'that',
#   'the',
#   'the',
#   'the',
#   'to',
#   'to',
#   'thoughts',
#   'through',
#   'to',
#   'to',
#   'them',
#   'to',
#   'they',
#   'the',
#   'table',
#   'though',
#   'to',
#   'the',
#   'that',
#   'them,',
#   'to',
#   'that',
#   'the',
#   'then',
#   'to',
#   'the',
#   'to',
#   'tries',
#   'to',
#   'the',
#   'the',
#   'to',
#   'thought.',
#   'to',
#   'the',
#   'the',
#   'the',
#   'two',
#   'to',
#   'to',
#   'that',
#   'the',
#   'thought',
#   'than',
#   'that',
#   'the',
#   'the',
#   'this',
#   'that',
#   'to',
#   'these',
#   'to',
#   'the',
#   'the',
#   'the',
#   ...],
#  'u': ['use',
#   'utility;',
#   'unilluminated',
#   'unforgiving',
#   'us.',
#   'up',
#   'us',
#   'us',
#   'us',
#   'us',
#   'unworthy',
#   'unknown',
#   'us',
#   'under',
#   'us',
#   'us.',
#   'utility,',
#   'until',
#   'upon',
#   'unacceptable,',
#   'us',
#   'us',
#   'upon',
#   'unreservedly',
#   'use',
#   'us',
#   'unparalleled',
#   'used',
#   'unprecedented',
#   'unforgettable',
#   'ultimately',
#   'unrealities',
#   'unusual,',
#   'us:',
#   'us',
#   'us',
#   'utterly',
#   'us',
#   'unknown',
#   'us.',
#   'up',
#   'under',
#   'us',
#   'us,',
#   'useless',
#   'utter.',
#   'understand',
#   'uninitiated,',
#   'unfortunately',
#   'unable',
#   'up',
#   'unseen’.',
#   'up',
#   'use',
#   'unfolded,',
#   'up',
#   'up',
#   'under',
#   'unable',
#   'unembarrassed',
#   'undertook',
#   'us',
#   'us',
#   'understand',
#   'us',
#   'unfortunately',
#   'us,',
#   'us.',
#   'us,',
#   'unpublished',
#   'us',
#   'unknown',
#   'us,',
#   'us',
#   'us',
#   'up',
#   'use',
#   'understood,',
#   'utters.',
#   'used',
#   'up’',
#   'us',
#   'upper',
#   'usually',
#   'under',
#   'under',
#   'unfolded',
#   'useless',
#   'us',
#   'usually',
#   'ultimately',
#   'un-preoccupied',
#   'used',
#   'under',
#   'un-avowed.',
#   'us',
#   'unknown',
#   'ultra-violet',
#   'under',
#   'unfortunately,',
#   'utterances',
#   'understanding',
#   'utterances.',
#   'unseemly',
#   'us',
#   'understand,',
#   'undertook,',
#   'utter',
#   'us',
#   'upper'],
#  'v': ['vast',
#   'very',
#   'venture',
#   'vulgarly',
#   'victims',
#   'various',
#   'value',
#   'vast',
#   'vacuity;',
#   'value,',
#   'voice,',
#   'very',
#   'vocabulary,',
#   'vie',
#   'very',
#   'victorious',
#   'viewpoint,',
#   'vast',
#   'verifying',
#   'virginity',
#   'vain.',
#   'visit,',
#   'vast,',
#   'verge',
#   'venture',
#   'vestiges',
#   'voice',
#   'virtue',
#   'variation',
#   'view',
#   'view,',
#   'voice,',
#   'visual',
#   'visual',
#   'vessel',
#   'very',
#   'very',
#   'various',
#   'value,',
#   'volume.',
#   'value',
#   'verbally,',
#   'various',
#   'voice,',
#   'very',
#   'vol-au-vent',
#   'valet,',
#   'virtue',
#   'vibrating',
#   'very',
#   'vast',
#   'varying',
#   'verbs',
#   'van.',
#   'various',
#   'vulgar.',
#   'very',
#   'valid,',
#   'verify',
#   'vice',
#   'volition',
#   'value',
#   'vertiginous',
#   'virtue.',
#   'very',
#   'very',
#   'vein',
#   'volume',
#   'value',
#   'void',
#   'violation',
#   'view',
#   'voice',
#   'voice',
#   'voice',
#   'voice',
#   'vanished.',
#   'viewing.',
#   'vehicles,',
#   'verdure'],
#  'w': ['which',
#   'with',
#   'with',
#   'which',
#   'what',
#   'women',
#   'what',
#   'well',
#   'without',
#   'which',
#   'with',
#   'wishes',
#   'without',
#   'worst',
#   'woods',
#   'white,',
#   'will',
#   'we',
#   'would',
#   'will',
#   'which',
#   'will',
#   'what',
#   'will',
#   'what',
#   'which',
#   'waste',
#   'will',
#   'with',
#   'will',
#   'what',
#   'whatever',
#   'we',
#   'well',
#   'widest',
#   'what',
#   'without',
#   'well-being?',
#   'were',
#   'what',
#   'we',
#   'would',
#   'way',
#   'without',
#   'which',
#   'which',
#   'we',
#   'well-ordered',
#   'when',
#   'would',
#   'which',
#   'whole',
#   'whose',
#   'with',
#   'welcome',
#   'with',
#   'what',
#   'while',
#   'would',
#   'who,',
#   'was',
#   'would',
#   'writing:',
#   'went',
#   'word?',
#   'which',
#   'writings,',
#   'will',
#   'what',
#   'will',
#   'will',
#   'we',
#   'with',
#   'which',
#   'with',
#   'which',
#   'was',
#   'was',
#   'with',
#   'wallpaper:',
#   'were',
#   'windows;',
#   'was',
#   'wood,',
#   'was',
#   'with',
#   'walls,',
#   'welcomes',
#   'with',
#   'wasting',
#   'weakness',
#   'with',
#   'when',
#   'which',
#   'with',
#   'which',
#   'wander',
#   'world.',
#   'whose',
#   'which',
#   'will',
#   'which',
#   'wholly',
#   'whatever',
#   'wretched',
#   'which',
#   'winning',
#   'worth',
#   'whoever',
#   'walking,',
#   'why',
#   'worth',
#   'wins',
#   'whose',
#   'which',
#   'wider',
#   'would',
#   'wit,',
#   'within',
#   'who',
#   'with',
#   'which',
#   'which',
#   'we',
#   'where',
#   'what',
#   'which',
#   'we',
#   'wrongly',
#   'which',
#   'was',
#   'world,',
#   'with',
#   'which',
#   'we',
#   'was',
#   'which',
#   'will',
#   'will',
#   'waging',
#   'war',
#   'worth',
#   'well',
#   'will',
#   'which',
#   'way',
#   'waking',
#   'weight,',
#   'while',
#   'when',
#   'where',
#   'was',
#   'worthwhile.',
#   'which',
#   'we',
#   'whose',
#   'will.',
#   'what',
#   'whatever',
#   'when',
#   'worth',
#   'which',
#   'will',
#   'would',
#   'who',
#   'wide',
#   'will',
#   'with',
#   'which',
#   'why',
#   'what',
#   'which,',
#   'which',
#   'which',
#   'which',
#   'what',
#   'when',
#   'which',
#   'which',
#   'well',
#   'when',
#   'would',
#   'whom',
#   'which',
#   'which',
#   'what',
#   'woman’s',
#   'what',
#   'which',
#   'were',
#   'what',
#   'would',
#   'who',
#   'with',
#   'what',
#   'waking',
#   'will',
#   'welcome',
#   'whose',
#   'would',
#   'write?',
#   'when',
#   'we',
#   'when',
#   'will',
#   'with',
#   'we',
#   'which',
#   'will',
#   'way',
#   'weigh',
#   'which',
#   'wished',
#   'which',
#   'would',
#   'will',
#   'was',
#   'which',
#   'which',
#   'would',
#   'works',
#   'which',
#   'witness',
#   'with',
#   'way,',
#   'which',
#   'what',
#   'who',
#   'way,',
#   'when',
#   'which',
#   'without',
#   'with',
#   'weaned',
#   'would',
#   'would',
#   'web',
#   'we',
#   'waiting',
#   'which',
#   'we',
#   'will',
#   'written',
#   'which',
#   'why',
#   'why',
#   'which',
#   'with',
#   'which',
#   'whose',
#   'who',
#   'would',
#   'which',
#   'who',
#   'would',
#   'which',
#   'way',
#   'wave',
#   'with',
#   'who',
#   'well,',
#   'with',
#   'whole',
#   'what',
#   'women.',
#   'wishes',
#   'wealth,',
#   'week,',
#   'we',
#   'we',
#   'with',
#   'whenever',
#   'world,',
#   'we',
#   'we',
#   'women,',
#   'will',
#   'will',
#   'won’t',
#   'what!',
#   'which',
#   'we',
#   'when',
#   'we',
#   'what',
#   'within',
#   'we',
#   'we',
#   'when',
#   'will',
#   'will',
#   'will',
#   'which',
#   'who',
#   'which',
#   'we',
#   'wider',
#   'whether',
#   'was',
#   'what’s',
#   'would',
#   'wish',
#   'where',
#   'wish',
#   'was',
#   'which,',
#   'without',
#   'with',
#   'were',
#   'which',
#   'wholly',
#   'which',
#   'will',
#   'with',
#   'writing,',
#   'way',
#   'was)',
#   'which',
#   'with',
#   'which',
#   'were',
#   'was',
#   'which',
#   'words',
#   'with',
#   'words',
#   'write',
#   'word',
#   'will',
#   'was',
#   'was',
#   'was',
#   'wrong',
#   'with',
#   'was',
#   'world',
#   'would',
#   'with',
#   'wrote:',
#   'words,',
#   'were',
#   'while.',
#   'was',
#   'was',
#   'was',
#   'word,',
#   'which',
#   'without',
#   'which,',
#   'which',
#   'window.',
#   'when',
#   'was',
#   'window’,',
#   'was',
#   'walking,',
#   'window',
#   'would',
#   'was',
#   'which',
#   'will',
#   'way',
#   'wave,',
#   'which',
#   'would',
#   'way',
#   'which',
#   'would',
#   'what',
#   'which',
#   'which',
#   'were',
#   'what',
#   'was',
#   'window.',
#   'window',
#   'was',
#   'with',
#   'was',
#   'with',
#   'was',
#   'within',
#   'which',
#   'was',
#   'woke',
#   'was',
#   'while',
#   'when',
#   'wanted',
#   'was',
#   'wide',
#   'word',
#   'word;',
#   'were',
#   'word',
#   'was',
#   'whole',
#   'with',
#   'went',
#   'well',
#   'within',
#   'was',
#   'with',
#   'were',
#   'with',
#   'was',
#   'with',
#   'which',
#   'war,',
#   'what',
#   'which',
#   'which',
#   'witness',
#   'was',
#   'whom',
#   'with',
#   'what',
#   'we',
#   'were',
#   'were',
#   'we',
#   'would',
#   'words',
#   'way',
#   'was',
#   'which',
#   'was',
#   'with',
#   'with',
#   'where',
#   'would',
#   'weaknesses',
#   'writing',
#   'wary',
#   'world:',
#   'who',
#   'who,',
#   'without',
#   'we',
#   'whose',
#   'we',
#   'wished',
#   'word,',
#   'we',
#   'we',
#   'word',
#   'with',
#   'which',
#   'we',
#   'which',
#   'we',
#   'which',
#   'will',
#   'which',
#   'who',
#   'without',
#   'with',
#   'we',
#   'were',
#   'we',
#   'will',
#   'will',
#   'would',
#   'were',
#   'word',
#   'we',
#   'word',
#   'which',
#   'writing,',
#   'with',
#   'would',
#   'were',
#   'whom',
#   'works',
#   'with',
#   'what',
#   'when',
#   'way',
#   'within',
#   'would',
#   'which',
#   'would',
#   'were',
#   'why',
#   'we,',
#   'who',
#   'who',
#   'works',
#   'with',
#   'who',
#   'we',
#   'we',
#   'we',
#   'with',
#   'well',
#   'will',
#   'where',
#   'wall,',
#   'with',
#   'wind',
#   'with',
#   'while',
#   'were',
#   'whether',
#   'who',
#   'writing',
#   'who',
#   'who,',
#   'works,',
#   'will.',
#   'with',
#   'which',
#   'worth',
#   'we',
#   'which',
#   'windy',
#   'wake',
#   'writing',
#   'with',
#   'will',
#   'which',
#   'written',
#   'which',
#   'wish.',
#   'without',
#   'with',
#   'word',
#   'whose',
#   'word.',
#   'when',
#   'what’s',
#   'within',
#   'which',
#   'worthwhile',
#   'with',
#   'words.',
#   'will',
#   'will',
#   'will',
#   'will',
#   'wonder.',
#   'will',
#   'will',
#   'which',
#   'will',
#   'will',
#   'word',
#   'which',
#   'with',
#   'with',
#   'will',
#   'will',
#   'women',
#   'will',
#   'with',
#   'write',
#   'without',
#   'writing',
#   'will',
#   'widely',
#   'writing',
#   'will',
#   'with',
#   'words',
#   'will',
#   'whenever',
#   'will',
#   'with',
#   'with',
#   'who',
#   'will',
#   'with',
#   'which',
#   'will',
#   'which',
#   'will',
#   'will',
#   'will',
#   'well',
#   'what',
#   'woman',
#   'will',
#   'which',
#   'will',
#   'within',
#   'with',
#   'which',
#   'word',
#   'will:',
#   'with',
#   'worried',
#   'words,',
#   'which',
#   'will',
#   'with',
#   'will',
#   'which',
#   'write',
#   'workings',
#   'wrongs,',
#   'words',
#   'which',
#   'which',
#   'which',
#   'words',
#   'whose',
#   'was',
#   'way',
#   'which',
#   'would',
#   'we',
#   'we',
#   'with.',
#   'with',
#   'while',
#   'with',
#   'within',
#   'would',
#   'while',
#   'which',
#   'with',
#   'which',
#   'with',
#   'words,',
#   'while',
#   'where',
#   'whole',
#   'while',
#   'will',
#   'word',
#   'which',
#   'which',
#   'which',
#   'we',
#   'which',
#   'weakness',
#   'with',
#   'which',
#   'who',
#   'who',
#   'which',
#   'with',
#   'without',
#   'without',
#   'way.',
#   'words,',
#   'way',
#   'which,',
#   'work,',
#   'which',
#   'who',
#   'when',
#   'within',
#   'which',
#   'will',
#   'whether',
#   'what',
#   'way,',
#   'work',
#   'white',
#   'world',
#   'which',
#   'we',
#   'work',
#   'we',
#   'we',
#   'would',
#   'which',
#   'when',
#   'writing,',
#   'which',
#   'within',
#   'where',
#   'where',
#   'where',
#   'which',
#   'which',
#   'which',
#   'would',
#   'what',
#   'want',
#   'which',
#   'which',
#   'weakly',
#   'whose',
#   'well',
#   'with',
#   'were',
#   'woman’s',
#   'which',
#   'whom',
#   'we',
#   'with',
#   'which',
#   'was',
#   'with',
#   'we',
#   'which',
#   'wrong.',
#   'which',
#   'with',
#   'with',
#   'which',
#   'will',
#   'who',
#   'which',
#   'which',
#   'which',
#   'where',
#   'without',
#   'were',
#   'with',
#   'what',
#   'wake;',
#   'with',
#   'women',
#   'was',
#   'which',
#   'which',
#   'with',
#   'worthy',
#   'worthless,',
#   'work',
#   'what',
#   'we',
#   'will,',
#   'worsens',
#   'well',
#   'weather',
#   'will',
#   'wandering',
#   'what',
#   'would',
#   'which',
#   'would',
#   'which',
#   'will',
#   'will',
#   'will',
#   'were',
#   'we',
#   'would',
#   'which',
#   'with',
#   'with',
#   'which',
#   'who',
#   'without',
#   'will',
#   'whole',
#   'widespread',
#   'which',
#   'word.',
#   'what',
#   'wish,',
#   'what',
#   'whispered',
#   'where',
#   'where',
#   'was',
#   'would',
#   'who,',
#   'whose',
#   'way,',
#   'whether',
#   'would',
#   'would',
#   'was',
#   'which',
#   'why',
#   'world',
#   'where,',
#   'would',
#   'whatever',
#   'world',
#   'which',
#   'what',
#   'world,',
#   'well,',
#   'what',
#   'want',
#   'with',
#   'will',
#   'will',
#   'will',
#   'who',
#   'was',
#   'what',
#   'was',
#   'will',
#   'world’s',
#   'with',
#   'why',
#   'white',
#   'what',
#   'which',
#   'what',
#   'who',
#   'who',
#   'warned',
#   'wherever',
#   'where',
#   'with',
#   'which',
#   'which',
#   'which',
#   'with:',
#   'with',
#   'worth',
#   'work;',
#   'without',
#   'was',
#   'was',
#   'without',
#   'while',
#   'was',
#   'world,',
#   'witness',
#   'would,',
#   'we',
#   'with',
#   'woman,',
#   'world',
#   'with',
#   'war',
#   'which',
#   'which',
#   'will',
#   'wood',
#   'which'],
#  'y': ['yields,',
#   'you,',
#   'your',
#   'young',
#   'yellow',
#   'yellow',
#   'you',
#   'your',
#   'you',
#   'you',
#   'yourself',
#   'you',
#   'yet',
#   'yet',
#   'yet',
#   'you;',
#   'yet',
#   'young',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'yet',
#   'you',
#   'you',
#   'you',
#   'yet',
#   'yet',
#   'you,',
#   'you',
#   'you',
#   'you',
#   'you',
#   'yet',
#   'yet.',
#   'you',
#   'yourself',
#   'you',
#   'your',
#   'your',
#   'yourself',
#   'you',
#   'you',
#   'you,',
#   'you',
#   'you',
#   'you,',
#   'you',
#   'your',
#   'your',
#   'yearning,',
#   'you',
#   'your',
#   'you,',
#   'you’ll',
#   'you',
#   'your',
#   'you,',
#   'you',
#   'you',
#   'you,',
#   'you',
#   'yourself.',
#   'you',
#   'you',
#   'you',
#   'your',
#   'you',
#   'you',
#   'you',
#   'yourself',
#   'you',
#   'you',
#   'your',
#   'your',
#   'you?',
#   'your',
#   'you',
#   'yet',
#   'yield',
#   'years',
#   'you',
#   'you',
#   'yes,',
#   'you',
#   'yet,',
#   'you',
#   'years',
#   'year',
#   'you.',
#   'you',
#   'yes.',
#   'you:',
#   'you.’',
#   'you…',
#   'you'],
#  'É': ['Éluard,', 'Éluard,', 'Éluard,', 'Éluard:'],
#  '–': ['–',
#   '–',
#   '–',
#   '–',
#   '–',
#   '–',
#   '–',
#   '–',
#   '–',
#   '–',
#   '–',
#   '–',
#   '–',
#   '–',
#   '–',
#   '–'],
#  '‘': ['‘the',
#   '‘observation’.',
#   '‘The',
#   '‘Diversity',
#   '‘reality’',
#   '‘nothing',
#   '‘the',
#   '‘let',
#   '‘Silvered',
#   '‘thanking’',
#   '‘led',
#   '‘There',
#   '‘previously',
#   '‘The',
#   '‘ebullitions’',
#   '‘Natural',
#   '‘I',
#   '‘…And',
#   '‘talent’',
#   '‘Anatomical',
#   '‘No',
#   '‘It',
#   '‘The',
#   '‘Alas!',
#   '‘During',
#   '‘l’',
#   '‘l’',
#   '‘It’s',
#   '‘Fair’',
#   '‘Action’',
#   '‘it’',
#   '‘rains’,',
#   '‘is’,',
#   '‘must’',
#   '‘something',
#   '‘think',
#   '‘learn’,',
#   '‘re-learn’.',
#   '‘picks',
#   '‘How',
#   '‘What',
#   '‘offer',
#   '‘evoked’.',
#   '‘two',
#   '‘the',
#   '‘Cephalopods',
#   '‘there',
#   '‘real',
#   '‘the',
#   '‘the',
#   '‘highly',
#   '‘stigmatizing’',
#   '‘It',
#   '‘Béthune,',
#   '‘Thank',
#   '‘examination’',
#   '‘with',
#   '‘invisible',
#   '‘You']}

# %%
initials["m"]
# Out:
# ['mask',
#  'marionette',
#  'machines',
#  'marionette',
#  'marionettes,',
#  'masks',
#  'mask',
#  'mask',
#  'machines',
#  'machines',
#  'mask',
#  'marionette',
#  'mask',
#  'machines',
#  'machines',
#  'mask',
#  'mankind’s',
#  'machine',
#  'mask',
#  'marionette',
#  'machines',
#  'marionette',
#  'marionettes,',
#  'masks',
#  'mask',
#  'mask',
#  'machines',
#  'machines',
#  'mask',
#  'marionette',
#  'mask',
#  'machines',
#  'machines',
#  'mask',
#  'mankind’s',
#  'machine',
#  'machines',
#  'machines',
#  'machines',
#  'machines',
#  'mask',
#  'mask',
#  'mask',
#  'mask',
#  'masks',
#  'my',
#  "mankind's",
#  'machine',
#  'mask',
#  'masks',
#  'machines',
#  'machines',
#  'machines',
#  'machines',
#  'machines',
#  'machines',
#  'machines',
#  'marionnette']

# %%
random.choice(initials["m"])
# Out:
# 'marble-admiral'

# %% [markdown]
# "Give me a name, and I create an acrostic from my nodeText"

# %%
for let in "sabrina":
    word = random.choice(initials[let])
    print(word.capitalize())
# Out:
# Same
# A
# By
# Rest.
# Is
# Not
# Are

# %% [markdown]
# <h1> same with Default dictionary</h1>

# %%
from collections import defaultdict

# %%
initials = defaultdict(list)

# %%
words = open("dataset/SurrealistManifesto.txt").read().split()
for item in words:
    first_let = item[0]
    initials[first_let].append(item)

# %%
initials
# Out:
# defaultdict(list,
#             {'(': ['(what',
#               '(as',
#               '(or',
#               '(Dostoevsky,',
#               '(since,',
#               '(or',
#               '(Account',
#               '(a',
#               '(and',
#               '(the',
#               '(What',
#               '(there',
#               '(ENTRÉE',
#               '(and',
#               '(since',
#               '(Mont',
#               '(I',
#               '(the',
#               '(I',
#               '(Nord-Sud,',
#               '(Were',
#               '(Knut',
#               '(migraine,',
#               '(I',
#               '(Filles',
#               '(Book',
#               '(1766),',
#               '(See',
#               '(I',
#               '(New',
#               '(Discours',
#               '(for',
#               '(Enough!',
#               '(Echolalia)',
#               '(Ganser',
#               '(Les',
#               '(Barrières)',
#               '(Baudelaire)',
#               '(note',
#               '(abruptly',
#               '(Lautréamont)',
#               '(Lautréamont)',
#               '(Philippe',
#               '(Robert',
#               '(André',
#               '(Louis',
#               '(Roger',
#               '(Max',
#               '(Let',
#               '(observe,',
#               '(Whatever',
#               '(Rimbaud:',
#               '(And',
#               '(do'],
#              ',': [','],
#              '-': ['-', '-', '-', '-', '-', '-'],
#              '1': ['1.',
#               '1820,',
#               '1,',
#               '1922)',
#               '1919),',
#               '1918)',
#               '1854)',
#               '1939',
#               '1922,',
#               '1974,',
#               '1922/23,',
#               '1924)',
#               '1927)',
#               '1.',
#               '1924,',
#               '1919,'],
#              '2': ['2.', '2.'],
#              '3': ['3.', '36', '3.'],
#              '4': ['4.'],
#              '6': ['6'],
#              '8': ['8th,'],
#              'A': ['A',
#               'Amidst',
#               'And,',
#               'America.',
#               'And',
#               'Aquinas',
#               'Anatole',
#               'And',
#               'A',
#               'Allow',
#               'A',
#               'And',
#               'Analysts',
#               'And,',
#               'And',
#               'Are',
#               'And',
#               'And',
#               'And',
#               'AT',
#               'At',
#               'A',
#               'And',
#               'An',
#               'Ambrosio’s',
#               'At',
#               'Amidst',
#               'A',
#               'Aragon',
#               'Auric,',
#               'Antonin',
#               'Artaud,',
#               'Are',
#               'And',
#               'At',
#               'At',
#               'A',
#               'And',
#               'Apollinaire',
#               'At',
#               'All',
#               'Apollinaire,',
#               'Apollinaire.',
#               'Apollinaire,',
#               'ABSOLUTE',
#               'Aragon,',
#               'And',
#               'André',
#               'Ask',
#               'Ask',
#               'Ask',
#               'Ask',
#               'And',
#               'Ask',
#               'Aragon:',
#               'And',
#               'Ask',
#               'Art',
#               'And',
#               'A',
#               'Against',
#               'And',
#               'And',
#               'As',
#               'As',
#               'And',
#               'At',
#               'A',
#               'A',
#               'Aragon)',
#               'All',
#               'A',
#               'A',
#               'A',
#               'ARTISAN',
#               'A',
#               'A',
#               'A',
#               'AT',
#               'And',
#               'AND',
#               'And,'],
#              'B': ['But',
#               'But',
#               'But',
#               'B114)',
#               'But',
#               'Because',
#               'But',
#               'But',
#               'By',
#               'Baudelaire’s',
#               'Benjamin',
#               'Boiffard,',
#               'Baron',
#               'Besides,',
#               'BLACK-FOREST',
#               'But',
#               'But',
#               'But',
#               'Baron,',
#               'Boiffard,',
#               'Breton,',
#               'Bertrand',
#               'Baudelaire',
#               'Braque,',
#               'But',
#               'Barriers',
#               'Baudelaire’s',
#               'Breton)',
#               'But',
#               'But',
#               'Braque',
#               'BENEATH',
#               'BOLTS',
#               'BEAUTY',
#               'BLANK',
#               'BALL',
#               'Béthune.’',
#               'Béthune,',
#               'Béthune',
#               'Béthune,',
#               'Bravo,'],
#              'C': ['Columbus',
#               'Crime',
#               'Can',
#               'Camaret,',
#               'Cinderella.',
#               'Charming',
#               'Cuisin',
#               'Carrive;',
#               'Cubist',
#               'Certainly',
#               'Chirico’s',
#               'Carlyle',
#               'Chapter',
#               'Carrive,',
#               'Crevel,',
#               'Chateaubriand',
#               'Constant',
#               'Chirico,',
#               'Chancellor',
#               'Continue',
#               'Champs',
#               'Champagne.',
#               'Ceylon',
#               'COLOUR',
#               'CHANCE',
#               'Certainly,',
#               'Chesterton',
#               'Cumae,',
#               'Cinema?',
#               'Charming',
#               'Curie’s'],
#              'D': ['Dear',
#               'Dream',
#               'Disc’.',
#               'Desnos',
#               'Delteil;',
#               'Duchamp',
#               'Does',
#               'Desnos,',
#               'DES',
#               'Dada',
#               'Desnos:',
#               'Died',
#               'Dumas,',
#               'Dictated',
#               'Delteil,',
#               'Desnos,',
#               'Ducasse,',
#               'Dante,',
#               'De',
#               'Desbordes-Valmour',
#               'Duchamp,',
#               'Delteil:',
#               'Desnos,',
#               'DÉSORDRE',
#               'DEUIL',
#               'DEUIL',
#               'Disorder',
#               'Desnos',
#               'Desnos',
#               'Do',
#               'Discourse',
#               'Day',
#               'Desnos)',
#               'DAY',
#               'DAY',
#               'DAILY',
#               'Dodona',
#               'Delphi'],
#              'E': ['Each',
#               'Everything',
#               'Each',
#               'ENTRANCE',
#               'Ease',
#               'ENCYCLOPEDIA.',
#               'Ernst,',
#               'Each',
#               'Each',
#               'Everything',
#               'Everything',
#               'Everything',
#               'Enfer:',
#               'Existence'],
#              'F': ['France,',
#               'Feeling',
#               'Freud',
#               'Freud',
#               'For',
#               'From',
#               'Fear,',
#               'For',
#               'Fraenkel',
#               'Francis',
#               'Francis',
#               'Fontaine,',
#               'Farewell',
#               'Feuilles',
#               'Freud',
#               'Fire',
#               'Fargue',
#               'FORMEL,',
#               'Formal',
#               'Forget',
#               'Following',
#               'Forty-five',
#               'Fields',
#               'For',
#               'Firstly,',
#               'For',
#               'From',
#               'FISH,',
#               'Fish,',
#               'Following',
#               'FADED',
#               'FROM',
#               'FIRST',
#               'Far',
#               'France.',
#               'Fine.'],
#              'G': ['German',
#               'Ghosts',
#               'Greeks,',
#               'Georges',
#               'Georges',
#               'Georges',
#               'Georges',
#               'Georges',
#               'Gérard,',
#               'Guillaume',
#               'Gérard',
#               'Girls',
#               'Germans',
#               'Gérard,',
#               'Gustave',
#               'Grief',
#               'Grief',
#               'God,',
#               'Gave'],
#              'H': ['His',
#               'However',
#               'Here',
#               'Hamson',
#               'Here',
#               'Hegel’s',
#               'Hugo',
#               'HÉBRIDES,',
#               'Hebrides',
#               'He',
#               'Have',
#               'How',
#               'How',
#               'How',
#               'Here',
#               'How',
#               'He',
#               'However',
#               'Here,',
#               'He',
#               'He',
#               'Here,',
#               'Here',
#               'HAVE',
#               'HE?',
#               'His',
#               'He',
#               'He',
#               'Hello,',
#               'Here',
#               'He',
#               'He'],
#              'I': ['I',
#               'If',
#               'In',
#               'I',
#               'I',
#               'Indeed',
#               'It',
#               'Is',
#               'I',
#               'I',
#               'I',
#               'I',
#               'It',
#               'It',
#               'It',
#               'It',
#               'It',
#               'If',
#               'I',
#               'I',
#               'I',
#               'It',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I’m',
#               'I’ll',
#               'I',
#               'I',
#               'If',
#               'It',
#               'If',
#               'I',
#               'It',
#               'I',
#               'It',
#               'It',
#               'It',
#               'Imagination',
#               'If',
#               'It',
#               'It',
#               'It',
#               'I',
#               'I',
#               'I',
#               'I',
#               'In',
#               'I',
#               'I',
#               'I',
#               'I',
#               'It’s',
#               'I',
#               'I',
#               'I',
#               'I',
#               'Is',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'It',
#               'It',
#               'I',
#               'I',
#               'I',
#               'I',
#               'If',
#               'I',
#               'I',
#               'I',
#               'I',
#               'In',
#               'I',
#               'It',
#               'It',
#               'It',
#               'I',
#               'In',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'It',
#               'I,',
#               'If',
#               'I',
#               'I',
#               'I,',
#               'I',
#               'I,',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'It',
#               'It',
#               'It',
#               'It',
#               'It',
#               'It',
#               'I',
#               'It',
#               'If',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'In',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'It',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'In',
#               'I,',
#               'It',
#               'I',
#               'It',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'It',
#               'I',
#               'I',
#               'I',
#               'In',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'It',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'It',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'It',
#               'It',
#               'I',
#               'I,',
#               'I',
#               'I',
#               'In',
#               'It',
#               'It',
#               'In',
#               'I',
#               'I',
#               'III,',
#               'It',
#               'It',
#               'I',
#               'It',
#               'Isidore',
#               'I',
#               'In',
#               'I',
#               'I',
#               'In',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'It',
#               'It',
#               'If',
#               'Incapable',
#               'It',
#               'I',
#               'In',
#               'I',
#               'I',
#               'If',
#               'I',
#               'I',
#               'It',
#               'It',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'It',
#               'I',
#               'In',
#               'I',
#               'Is',
#               'I',
#               'I',
#               'It',
#               'It',
#               'It',
#               'If,',
#               'I',
#               'I',
#               'In',
#               'It',
#               'It',
#               'I',
#               'I',
#               'I',
#               'It',
#               'It',
#               'It',
#               'I',
#               'I',
#               'I',
#               'In',
#               'I',
#               'In',
#               'It’s',
#               'I',
#               'I',
#               'I',
#               'It',
#               'It',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'It',
#               'IS',
#               'IS',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'It',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'If',
#               'I',
#               'If',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'I',
#               'It',
#               'I',
#               'It'],
#              'J': ['J.P.R',
#               'Jean',
#               'Joseph',
#               'Jean',
#               'J.-A.',
#               'Jacques',
#               'Juliet,',
#               'Jarry',
#               'Joseph',
#               'Jules',
#               'June'],
#              'K': ['Kill,', 'Klee,', 'Know', 'Kant’s'],
#              'L': ['Let',
#               'L’Intelligence,',
#               'Let',
#               'Let’s',
#               'Lewis’s',
#               'Long',
#               'Likewise',
#               'Louis',
#               'Limbour,',
#               'Limbour',
#               'Limbour);',
#               'Littérature,',
#               'Limbour,',
#               'La',
#               'Lord',
#               'Lady,',
#               'Lord,',
#               'Louis',
#               'Life’s',
#               'Let',
#               'Language',
#               'Lovely',
#               'Lutheranism.’)',
#               'Love',
#               'LARGE'],
#              'M': ['Man,',
#               'Menace',
#               'Man',
#               'Madness',
#               'Man,',
#               'Marquise',
#               'Man,',
#               'Memory',
#               'My',
#               'Man’s',
#               'Mystery.',
#               'Monk',
#               'Matilda',
#               'Monk',
#               'Max',
#               'Morise,',
#               'Marcel',
#               'Malkine,',
#               'Marcel',
#               'Moreover,',
#               'My',
#               'Man',
#               'MEDIUMS',
#               'MÉDIUMS,',
#               'March',
#               'Man',
#               'Morning',
#               'My',
#               'MEMORABILIA',
#               'Messrs.',
#               'Malkine,',
#               'Morise,',
#               'Mallarmé',
#               'Moreau,',
#               'Matisse,',
#               'Musique',
#               'Man',
#               'Max',
#               'Masson.)',
#               'Max',
#               'Morise:',
#               'Mississippi',
#               'Miracle',
#               'Miró',
#               'Magical',
#               'M',
#               'Memory',
#               'Man',
#               'My',
#               'Magnetic',
#               'Man',
#               'Man',
#               'Morise)',
#               'Men',
#               'Man',
#               'MADAME',
#               'Mauvais',
#               'Musketeers.',
#               'Man',
#               'My'],
#              'N': ['Nothing',
#               'Nothing',
#               'Not',
#               'North',
#               'Noll;',
#               'Naville,',
#               'Not',
#               'November',
#               'Nevertheless,',
#               'Nerval',
#               'Nerval',
#               'Nerval',
#               'Nodier',
#               'Naville,',
#               'Noll,',
#               'Night',
#               'Nouveau',
#               'NOUVELLES',
#               'Never',
#               'Not',
#               'Now',
#               'Novalis’',
#               'NEWSPAPER',
#               'Nijinksi,',
#               'No'],
#              'O': ['On',
#               'Only',
#               'One',
#               'Our',
#               'On',
#               'Oriental',
#               'Only',
#               'OF',
#               'One',
#               'On',
#               'One',
#               'One',
#               'One',
#               'One',
#               'Of',
#               'Only',
#               'Or',
#               'One',
#               'On',
#               'One',
#               'Of',
#               'On',
#               'OF',
#               'Of',
#               'OF'],
#              'P': ['Paul',
#               'Paul',
#               'Punishment)',
#               'Pensées,',
#               'Pointless',
#               'POET',
#               'Paris.',
#               'Philippe',
#               'Paul',
#               'Paulhan;',
#               'Péret,',
#               'Pierre',
#               'Picabia',
#               'Picasso',
#               'Poetry',
#               'Pawn-Shop',
#               'Picasso’s',
#               'Pierre',
#               'Philippe',
#               'Poetically',
#               'Pure',
#               'Philosophy.',
#               'Péret,',
#               'Picon,',
#               'Poe',
#               'Perse',
#               'Picabia,',
#               'Philippe',
#               'Paul',
#               'POUR',
#               'Put',
#               'Put',
#               'Paucity',
#               'Peu',
#               'Perhaps.',
#               'Poetic',
#               'Protestantism',
#               'Purgatory.',
#               'Picasso',
#               'POEM',
#               'POEM',
#               'PARIS',
#               'PRAYER',
#               'Press',
#               'Philippe',
#               'Perhaps',
#               'Photography?',
#               'Pasteur’s'],
#              'R': ['Rather,',
#               'Racine’s',
#               'Robert',
#               'Roger',
#               'Rue',
#               'Robert',
#               'Rimbaud',
#               'Reverdy,',
#               'Reverdy’s',
#               'Robert',
#               'Romeo',
#               'Resartus',
#               'Revolution;',
#               'Rabbe',
#               'Rimbaud',
#               'Reverdy',
#               'Roussel',
#               'Ray,',
#               'Roger',
#               'Robert',
#               'Reality.',
#               'Réalité',
#               'Reverdy’s',
#               'Reverdy’s',
#               'Renard)',
#               'Reverdy',
#               'Rrose',
#               'Reformation;',
#               'Red',
#               'Russian',
#               'Radio?'],
#              'S': ['Such',
#               'Such',
#               'So',
#               'Stendhal’s',
#               'Stendhal',
#               'Saint-Pol-Roux',
#               'Symbolist',
#               'She',
#               'Soupault',
#               'So',
#               'Sibylline',
#               'Since',
#               'Suddenly',
#               'Soupault,',
#               'Soupault’s',
#               'Soupault’s',
#               'Soupault',
#               'SURREALISM.',
#               'SUPERNATURALISM,',
#               'Sartor',
#               'Supernaturalism’).',
#               'Surrealism,',
#               'SUPERNATURALISTIC',
#               'Swedenborg’s',
#               'Saint-Pol-Roux)',
#               'SURREALISM',
#               'SURREALISM,',
#               'Surrealism',
#               'SURREALISM,',
#               'Soupault,',
#               'Surrealists,',
#               'Shakespeare.',
#               'Swift',
#               'Sade',
#               'Saint-Pol-Roux',
#               'Saint-John',
#               'Seurat,',
#               'So',
#               'Soupault:',
#               'Secrets',
#               'Surrealist',
#               'Simplicity,',
#               'Surrealism',
#               'Surrealism',
#               'Since,',
#               'Soupault',
#               'Surrealism',
#               'Soupault)',
#               'Sélavy’s',
#               'So',
#               'Soupault',
#               'SOLUBLE',
#               'Surrealist',
#               'STAG',
#               'Short',
#               'SUITOR’S',
#               'Several',
#               'Saison',
#               'Sang):',
#               'Someone',
#               'Similarly,',
#               'Soupault',
#               'Soupault',
#               'Syphilis?',
#               'Such',
#               'Surrealism,',
#               'Surrealism'],
#              'T': ['There,',
#               'The',
#               'That',
#               'That',
#               'The',
#               'To',
#               'That',
#               'They',
#               'The',
#               'Taine’s',
#               'The',
#               'They',
#               'The',
#               'The',
#               'The',
#               'Thomas',
#               'The',
#               'The',
#               'The',
#               'The',
#               'They',
#               'The',
#               'The',
#               'The',
#               'The',
#               'The',
#               'The',
#               'The',
#               'The',
#               'This',
#               'This',
#               'The',
#               'The',
#               'The',
#               'That',
#               'They',
#               'There',
#               'The',
#               'That',
#               'The',
#               'The',
#               'The',
#               'There',
#               'The',
#               'They',
#               'They',
#               'The',
#               'There',
#               'There',
#               'T.',
#               'These',
#               'The',
#               'Then',
#               'The',
#               'There',
#               'The',
#               'THE',
#               'THE',
#               'The',
#               'Those',
#               'That',
#               'The',
#               'The',
#               'The',
#               'These',
#               'Truly',
#               'Then',
#               'The',
#               'This',
#               'Thoughts',
#               'The',
#               'Totally',
#               'The',
#               'Thought,',
#               'The',
#               'To',
#               'Thomas',
#               'There',
#               'They',
#               'The',
#               'They',
#               'Thoughts',
#               'They',
#               'They',
#               'They',
#               'The',
#               'Tell',
#               'The',
#               'That',
#               'Trust',
#               'This',
#               'Through',
#               'To',
#               'They',
#               'Thus',
#               'The',
#               'To',
#               'To',
#               'To',
#               'There',
#               'To',
#               'That',
#               'There',
#               'To',
#               'This',
#               'This',
#               'There',
#               'The',
#               'The',
#               'The',
#               'This',
#               'The',
#               'The',
#               'The',
#               'The',
#               'The',
#               'The',
#               'To',
#               'The',
#               'The',
#               'The',
#               'The',
#               'This',
#               'These',
#               'The',
#               'The',
#               'Thanks',
#               'Thank',
#               'The',
#               'The',
#               'The',
#               'The',
#               'THE',
#               'TO',
#               'THE',
#               'The',
#               'THE',
#               'THE',
#               'The',
#               'THE',
#               'Theatre,',
#               'There',
#               'The',
#               'Today,',
#               'The',
#               'Three',
#               'That',
#               'The',
#               'The',
#               'This',
#               'The',
#               'Try',
#               'Thank',
#               'They',
#               'This',
#               'This',
#               'The'],
#              'U': ['Ultimately,', 'Understand', 'Under', 'Ucello', 'Une'],
#              'V': ['Valéry',
#               'Valéry',
#               'Very',
#               'Villon’s',
#               'Vitrac,',
#               'VIII,',
#               'Vitrac.',
#               'Vaché',
#               'Vitrac:',
#               'Vitrac)',
#               'VILLAGE'],
#              'W': ['Where',
#               'Whoa,',
#               'Whatever',
#               'What',
#               'Where',
#               'We',
#               'We',
#               'Within',
#               'What',
#               'What',
#               'When',
#               'Why',
#               'What',
#               'When',
#               'Who',
#               'What',
#               'WORK.',
#               'What',
#               'We',
#               'With',
#               'Without',
#               'We',
#               'Written',
#               'Write',
#               'Whoever',
#               'Who',
#               'Words,',
#               'When',
#               'We',
#               'Whether',
#               'We',
#               'Watch',
#               'WHERE',
#               'What',
#               'Will',
#               'What',
#               'When',
#               'What',
#               'What',
#               'War?'],
#              'Y': ['You',
#               'You',
#               'You',
#               'Young’s',
#               'You',
#               'Your',
#               'You’',
#               'You',
#               'YOUR',
#               'YET….We',
#               'Youth?'],
#              'a': ['aspects',
#               'and',
#               'around',
#               'almost',
#               'always',
#               'at',
#               'averse',
#               'affairs',
#               'are',
#               'a',
#               'and',
#               'as',
#               'admit',
#               'any',
#               'as',
#               'absence',
#               'all',
#               'a',
#               'anything',
#               'and',
#               'are',
#               'are',
#               'again.',
#               'a',
#               'accumulates,',
#               'abandons',
#               'a',
#               'according',
#               'arbitrary',
#               'assuming',
#               'and',
#               'at',
#               'about',
#               'age',
#               'abandon',
#               'and',
#               'all',
#               'as',
#               'an',
#               'as',
#               'and',
#               'and',
#               'an',
#               'all',
#               'all',
#               'a',
#               'assess',
#               'account,',
#               'as',
#               'about',
#               'aspiration.',
#               'all',
#               'are',
#               'abuse',
#               'any',
#               'a',
#               'at',
#               'and',
#               'a',
#               'also',
#               'abandon',
#               'any',
#               'and',
#               'a',
#               'away’',
#               'as',
#               'aptly',
#               'another…Everyone',
#               'a',
#               'actions,',
#               'and',
#               'actions,',
#               'as',
#               'at',
#               'am',
#               'all',
#               'aware',
#               'and',
#               'allows',
#               'are',
#               'and',
#               'are',
#               'are',
#               'a',
#               'and',
#               'against',
#               'after',
#               'admittedly',
#               'a',
#               'a',
#               'a',
#               'and',
#               'above',
#               'all,',
#               'as',
#               'a',
#               'against',
#               'a',
#               'appears',
#               'all',
#               'and',
#               'arises',
#               'and',
#               'all',
#               'and',
#               'articles,',
#               'and',
#               'and',
#               'art,',
#               'applying',
#               'activity',
#               'affected',
#               'as',
#               'amusing',
#               'a',
#               'an',
#               'anthology',
#               'as',
#               'a',
#               'as',
#               'authors',
#               'an',
#               'ago,',
#               'assured',
#               'as',
#               'as',
#               'at',
#               'and',
#               'an',
#               'almost',
#               'as',
#               'authors’',
#               'ambition',
#               'are',
#               'amusing',
#               'at',
#               'a',
#               'and',
#               'all,',
#               'am',
#               'at',
#               'about',
#               'a',
#               'author',
#               'and',
#               'and',
#               'a',
#               'all…There',
#               'about',
#               'all',
#               'a',
#               'an',
#               'a',
#               'and',
#               'against',
#               'against',
#               'amounted',
#               'all',
#               'and',
#               'am',
#               'admit,',
#               'a',
#               'argued',
#               'and',
#               'at',
#               'author',
#               'avoid',
#               'a',
#               'and',
#               'am',
#               'and',
#               'an',
#               'action',
#               'any',
#               'a',
#               'along',
#               'a',
#               'a',
#               'about',
#               'author',
#               'a',
#               'and,',
#               'about',
#               'actions',
#               'and',
#               'are',
#               'admirably',
#               'about',
#               'appear',
#               'about,',
#               'and',
#               'again,',
#               'always',
#               'am',
#               'a',
#               'adversary.',
#               'are',
#               'as',
#               'avoid',
#               'as',
#               'as',
#               'all',
#               'a',
#               'alike,',
#               'among',
#               'among',
#               'all',
#               'a',
#               'are',
#               'analysis',
#               'and',
#               'an',
#               'abstract',
#               'a',
#               'and',
#               'achieving',
#               'action',
#               'at',
#               'a',
#               'are',
#               'author’s',
#               'appraisal,',
#               'a',
#               'adds',
#               'are',
#               'am',
#               'at.',
#               'are',
#               'applicable',
#               'absolute',
#               'allows',
#               'aims',
#               'add',
#               'about',
#               'a',
#               'and',
#               'and',
#               'accompanied',
#               'any',
#               'accepted',
#               'a',
#               'and',
#               'a',
#               'at',
#               'able',
#               'authorised',
#               'as',
#               'account',
#               'against',
#               'and',
#               'an',
#               'a',
#               'as',
#               'as',
#               'and',
#               'are',
#               'applied',
#               'activity',
#               'at',
#               'a',
#               'and',
#               'attention.',
#               'awake',
#               'and',
#               'asleep,',
#               'always',
#               'astonished',
#               'are',
#               'above',
#               'all',
#               'and',
#               'all',
#               'and',
#               'a',
#               'a',
#               'a',
#               'as',
#               'as',
#               'affairs',
#               'are',
#               'all',
#               'appearances,',
#               'are',
#               'and',
#               'alone',
#               'arrogates',
#               'and',
#               'as',
#               'a',
#               'at',
#               'any',
#               'a',
#               'a',
#               'about',
#               'a',
#               'awake,',
#               'all',
#               'activities,',
#               'a',
#               'according',
#               'a',
#               'as',
#               'and',
#               'as',
#               'accord',
#               'a',
#               'acute?',
#               'also',
#               'applied',
#               'as',
#               'and',
#               'are',
#               'already',
#               'any',
#               'age,',
#               'and',
#               'ages',
#               'awake.',
#               'am',
#               'as',
#               'a',
#               'a',
#               'and',
#               'all',
#               'a',
#               'and,',
#               'an',
#               'a',
#               'and',
#               'as',
#               'all',
#               'a',
#               'attributes',
#               'angle',
#               'at',
#               'agonising',
#               'are',
#               'among',
#               'allow',
#               'all',
#               'ask,',
#               'a',
#               'a',
#               'as',
#               'and',
#               'arrived,',
#               'awakening',
#               'abruptly,',
#               'accept',
#               'an',
#               'accounting',
#               'a',
#               'all',
#               'and',
#               'amplitude,',
#               'are',
#               'and',
#               'a',
#               'absolute',
#               'a',
#               'am',
#               'about,',
#               'a',
#               'at',
#               'a',
#               'a',
#               'a',
#               'alone',
#               'a',
#               'altogether',
#               'about',
#               'always',
#               'alone',
#               'a',
#               'as',
#               'admirable',
#               'animates',
#               'author',
#               'all',
#               'act',
#               'an',
#               'and',
#               'and',
#               'aspires',
#               'and',
#               'an',
#               'a',
#               'accuracy',
#               'and',
#               'admirable',
#               'about',
#               'and',
#               'a',
#               'a',
#               'a',
#               'a',
#               'and',
#               'a',
#               'a',
#               'accepted',
#               'as',
#               'a',
#               'arbitrary',
#               'and',
#               'and',
#               'again,',
#               'are',
#               'are',
#               'addressed',
#               'an',
#               'age',
#               'are',
#               'and',
#               'as',
#               'adults',
#               'and',
#               'agree',
#               'are',
#               'adorable',
#               'a',
#               'and',
#               'attraction',
#               'are',
#               'are',
#               'as',
#               'all',
#               'ages;',
#               'any',
#               'any',
#               'appurtenances',
#               'an',
#               'and',
#               'are',
#               'affected',
#               'are',
#               'an',
#               'am',
#               'a',
#               'age,',
#               'anyone',
#               'and',
#               'as',
#               'all',
#               'a',
#               'at',
#               'a',
#               'are',
#               'and',
#               'as',
#               'a',
#               'are',
#               'autos',
#               'are',
#               'and',
#               'are',
#               'and',
#               'an',
#               'and',
#               'and',
#               'and',
#               'and',
#               'and',
#               'a',
#               'and',
#               'and',
#               'and',
#               'and',
#               'and',
#               'a',
#               'are,',
#               'as',
#               'about',
#               'and',
#               'a',
#               'and',
#               'a',
#               'are',
#               'always',
#               'and',
#               'another.',
#               'are',
#               'and',
#               'and',
#               'about',
#               'and',
#               'a',
#               'are',
#               'are',
#               'another,',
#               'and',
#               'and',
#               'alone',
#               'a',
#               'anarchy.',
#               'a',
#               'also',
#               'a',
#               'a',
#               'an',
#               'and',
#               'and',
#               'absurd',
#               'abyss,',
#               'artificial',
#               'are',
#               'already',
#               'a',
#               'and',
#               'a',
#               'and',
#               'a',
#               'at',
#               'appears',
#               'all',
#               'are',
#               'all',
#               'are',
#               'also',
#               'an',
#               'arrow',
#               'and',
#               'attain',
#               'an',
#               'analysis',
#               'attention',
#               'able',
#               'any',
#               'at',
#               'attempted',
#               'aspirations',
#               'as',
#               'a',
#               'a',
#               'as',
#               'apologising',
#               'and',
#               'ability',
#               'a',
#               'a',
#               'a',
#               'a',
#               'achieved',
#               'and',
#               'admit',
#               'around',
#               'a',
#               'and',
#               'a',
#               'at',
#               'a',
#               'and',
#               'as',
#               'as',
#               'as',
#               'as',
#               'am).',
#               'a',
#               'a',
#               'and',
#               'appear)',
#               'and',
#               'an',
#               'application',
#               'advertising',
#               'a',
#               'a',
#               'advertisement',
#               'a',
#               'at',
#               'as',
#               'as',
#               'a',
#               'a',
#               'a',
#               'and',
#               'and',
#               'and',
#               'a',
#               'aesthetic,',
#               'an',
#               'aesthetic',
#               'a',
#               'amidst',
#               'all',
#               'asleep,',
#               'articulated',
#               'a',
#               'any',
#               'a',
#               'any',
#               'agrees,',
#               'at',
#               'a',
#               'a',
#               'at',
#               'and',
#               'astonished',
#               'a',
#               'ambiguity,',
#               'accompanied',
#               'as',
#               'a',
#               'a',
#               'a',
#               'at',
#               'angles',
#               'axis',
#               'a',
#               'attention',
#               'at',
#               'apparitions,',
#               'and',
#               'are',
#               'as',
#               'as',
#               'auditory',
#               'a',
#               'and',
#               'a',
#               'again',
#               'a',
#               'a',
#               'a',
#               'a',
#               'a',
#               'am',
#               'achieving',
#               'a',
#               'at',
#               'am',
#               'and',
#               'accepted',
#               'as',
#               'a',
#               'and',
#               'as',
#               'a',
#               'a',
#               'a',
#               'an',
#               'a',
#               'and',
#               'among',
#               'accorded',
#               'an',
#               'almost',
#               'and',
#               'an',
#               'and',
#               'all',
#               'an',
#               'attributes',
#               'as',
#               'and',
#               'are',
#               'a',
#               'a',
#               'apartment',
#               'above',
#               'awake',
#               'and',
#               'a',
#               'a',
#               'a',
#               'as',
#               'and',
#               'a',
#               'and',
#               'as',
#               'a',
#               'an',
#               'artery',
#               'another,',
#               'adapted',
#               'after',
#               'another',
#               'and',
#               'and',
#               'a',
#               'and',
#               'as',
#               'as',
#               'an',
#               'as',
#               'and',
#               'a',
#               'as',
#               'as',
#               'as',
#               'as',
#               'appeared',
#               'and',
#               'about',
#               'and',
#               'and',
#               'a',
#               'a',
#               'achieved',
#               'able',
#               'and',
#               'all,',
#               'and',
#               'analogous:',
#               'also,',
#               'a',
#               'a',
#               'a',
#               'a',
#               'and,',
#               'and',
#               'a',
#               'apparent',
#               'and',
#               'allow',
#               'at',
#               'and',
#               'a',
#               'a',
#               'and',
#               'any',
#               'appeared',
#               'at',
#               'all',
#               'absolutely',
#               'and',
#               'and',
#               'at',
#               'and',
#               'an',
#               'assess',
#               'at',
#               'appreciate',
#               'at',
#               'are,',
#               'all',
#               'appearances,',
#               'as',
#               'as',
#               'and',
#               'are',
#               'above',
#               'all',
#               'a',
#               'absurdity,',
#               'absurdity,',
#               'admissible,',
#               'a',
#               'and',
#               'all',
#               'and',
#               'a',
#               'an',
#               'and',
#               'adopted',
#               'and',
#               'a',
#               'appropriate',
#               'appropriated',
#               'and',
#               'also',
#               'a',
#               'as',
#               'and',
#               'are',
#               'are,',
#               'asked',
#               'again.’',
#               'as',
#               'all.',
#               'at',
#               'are',
#               'and',
#               'at',
#               'also',
#               'and',
#               'all:',
#               'automatism',
#               'any',
#               'actual',
#               'absence',
#               'any',
#               'any',
#               'aesthetic',
#               'association,',
#               'all',
#               'and',
#               'acts',
#               'appear,',
#               'and',
#               'about',
#               'a',
#               'and',
#               'attempts',
#               'at',
#               'an',
#               'abuse',
#               'attributed',
#               'any',
#               'are',
#               'a',
#               'a',
#               'a',
#               'adventure.',
#               'and',
#               'absinthe.',
#               'atmosphere.',
#               'at',
#               'at',
#               'a',
#               'anecdote.',
#               'are',
#               'always',
#               'a',
#               'at',
#               'and',
#               'above',
#               'and',
#               'at',
#               'all',
#               'a',
#               'and',
#               'artists,',
#               'among',
#               'among',
#               'and',
#               'admirable',
#               'and',
#               'are',
#               'any',
#               'attempt',
#               'are',
#               'a',
#               'as',
#               'above.',
#               'ask',
#               'and',
#               'a',
#               'at',
#               'and',
#               'a',
#               'an',
#               'a',
#               'am',
#               'against',
#               'a',
#               'and',
#               'and',
#               'and',
#               'and',
#               'accomplice,',
#               'and',
#               'and',
#               'and',
#               'and',
#               'and',
#               'and',
#               'a',
#               'a',
#               'around',
#               'a',
#               'asked',
#               'ask',
#               'any',
#               'and',
#               'and',
#               'at',
#               'agility',
#               'as',
#               'as',
#               'an',
#               'and',
#               'and',
#               'are',
#               'a',
#               'as',
#               'as',
#               'about',
#               'and',
#               'and',
#               'are',
#               'arise',
#               'a',
#               'asks',
#               'about',
#               'activity',
#               'and',
#               'agree',
#               'a',
#               'and',
#               'a',
#               'absolute',
#               'although',
#               'as',
#               'as',
#               'a',
#               'as',
#               'as',
#               'an',
#               'an',
#               'a',
#               'a',
#               'and',
#               'arbitrary',
#               'at',
#               'anyone,',
#               'and',
#               'activity,',
#               'arms',
#               'are',
#               'an',
#               'all',
#               'all',
#               'and',
#               'a',
#               'an',
#               'a',
#               'and',
#               'a',
#               'apart.',
#               'achieve',
#               'allowing',
#               'and',
#               'among',
#               'and',
#               'all-consuming',
#               'are,',
#               'a',
#               'and',
#               'a',
#               'at',
#               'and',
#               'are',
#               'appearance:',
#               'and',
#               'as',
#               'active',
#               'as',
#               'about,',
#               'and',
#               'and',
#               'assistance',
#               'assured',
#               'a',
#               'a',
#               'and',
#               'a',
#               'appearing',
#               'about',
#               'a',
# ...
#               'was',
#               'what’s',
#               'would',
#               'wish',
#               'where',
#               'wish',
#               'was',
#               'which,',
#               'without',
#               'with',
#               'were',
#               'which',
#               'wholly',
#               'which',
#               'will',
#               'with',
#               'writing,',
#               'way',
#               'was)',
#               'which',
#               'with',
#               'which',
#               'were',
#               'was',
#               'which',
#               'words',
#               'with',
#               'words',
#               'write',
#               'word',
#               'will',
#               'was',
#               'was',
#               'was',
#               'wrong',
#               'with',
#               'was',
#               'world',
#               'would',
#               'with',
#               'wrote:',
#               'words,',
#               'were',
#               'while.',
#               'was',
#               'was',
#               'was',
#               'word,',
#               'which',
#               'without',
#               'which,',
#               'which',
#               'window.',
#               'when',
#               'was',
#               'window’,',
#               'was',
#               'walking,',
#               'window',
#               'would',
#               'was',
#               'which',
#               'will',
#               'way',
#               'wave,',
#               'which',
#               'would',
#               'way',
#               'which',
#               'would',
#               'what',
#               'which',
#               'which',
#               'were',
#               'what',
#               'was',
#               'window.',
#               'window',
#               'was',
#               'with',
#               'was',
#               'with',
#               'was',
#               'within',
#               'which',
#               'was',
#               'woke',
#               'was',
#               'while',
#               'when',
#               'wanted',
#               'was',
#               'wide',
#               'word',
#               'word;',
#               'were',
#               'word',
#               'was',
#               'whole',
#               'with',
#               'went',
#               'well',
#               'within',
#               'was',
#               'with',
#               'were',
#               'with',
#               'was',
#               'with',
#               'which',
#               'war,',
#               'what',
#               'which',
#               'which',
#               'witness',
#               'was',
#               'whom',
#               'with',
#               'what',
#               'we',
#               'were',
#               'were',
#               'we',
#               'would',
#               'words',
#               'way',
#               'was',
#               'which',
#               'was',
#               'with',
#               'with',
#               'where',
#               'would',
#               'weaknesses',
#               'writing',
#               'wary',
#               'world:',
#               'who',
#               'who,',
#               'without',
#               'we',
#               'whose',
#               'we',
#               'wished',
#               'word,',
#               'we',
#               'we',
#               'word',
#               'with',
#               'which',
#               'we',
#               'which',
#               'we',
#               'which',
#               'will',
#               'which',
#               'who',
#               'without',
#               'with',
#               'we',
#               'were',
#               'we',
#               'will',
#               'will',
#               'would',
#               'were',
#               'word',
#               'we',
#               'word',
#               'which',
#               'writing,',
#               'with',
#               'would',
#               'were',
#               'whom',
#               'works',
#               'with',
#               'what',
#               'when',
#               'way',
#               'within',
#               'would',
#               'which',
#               'would',
#               'were',
#               'why',
#               'we,',
#               'who',
#               'who',
#               'works',
#               'with',
#               'who',
#               'we',
#               'we',
#               'we',
#               'with',
#               'well',
#               'will',
#               'where',
#               'wall,',
#               'with',
#               'wind',
#               'with',
#               'while',
#               'were',
#               'whether',
#               'who',
#               'writing',
#               'who',
#               'who,',
#               'works,',
#               'will.',
#               'with',
#               'which',
#               'worth',
#               'we',
#               'which',
#               'windy',
#               'wake',
#               'writing',
#               'with',
#               'will',
#               'which',
#               'written',
#               'which',
#               'wish.',
#               'without',
#               'with',
#               'word',
#               'whose',
#               'word.',
#               'when',
#               'what’s',
#               'within',
#               'which',
#               'worthwhile',
#               'with',
#               'words.',
#               'will',
#               'will',
#               'will',
#               'will',
#               'wonder.',
#               'will',
#               'will',
#               'which',
#               'will',
#               'will',
#               'word',
#               'which',
#               'with',
#               'with',
#               'will',
#               'will',
#               'women',
#               'will',
#               'with',
#               'write',
#               'without',
#               'writing',
#               'will',
#               'widely',
#               'writing',
#               'will',
#               'with',
#               'words',
#               'will',
#               'whenever',
#               'will',
#               'with',
#               'with',
#               'who',
#               'will',
#               'with',
#               'which',
#               'will',
#               'which',
#               'will',
#               'will',
#               'will',
#               'well',
#               'what',
#               'woman',
#               'will',
#               'which',
#               'will',
#               'within',
#               'with',
#               'which',
#               'word',
#               'will:',
#               'with',
#               'worried',
#               'words,',
#               'which',
#               'will',
#               'with',
#               'will',
#               'which',
#               'write',
#               'workings',
#               'wrongs,',
#               'words',
#               'which',
#               'which',
#               'which',
#               'words',
#               'whose',
#               'was',
#               'way',
#               'which',
#               'would',
#               'we',
#               'we',
#               'with.',
#               'with',
#               'while',
#               'with',
#               'within',
#               'would',
#               'while',
#               'which',
#               'with',
#               'which',
#               'with',
#               'words,',
#               'while',
#               'where',
#               'whole',
#               'while',
#               'will',
#               'word',
#               'which',
#               'which',
#               'which',
#               'we',
#               'which',
#               'weakness',
#               'with',
#               'which',
#               'who',
#               'who',
#               'which',
#               'with',
#               'without',
#               'without',
#               'way.',
#               'words,',
#               'way',
#               'which,',
#               'work,',
#               'which',
#               'who',
#               'when',
#               'within',
#               'which',
#               'will',
#               'whether',
#               'what',
#               'way,',
#               'work',
#               'white',
#               'world',
#               'which',
#               'we',
#               'work',
#               'we',
#               'we',
#               'would',
#               'which',
#               'when',
#               'writing,',
#               'which',
#               'within',
#               'where',
#               'where',
#               'where',
#               'which',
#               'which',
#               'which',
#               'would',
#               'what',
#               'want',
#               'which',
#               'which',
#               'weakly',
#               'whose',
#               'well',
#               'with',
#               'were',
#               'woman’s',
#               'which',
#               'whom',
#               'we',
#               'with',
#               'which',
#               'was',
#               'with',
#               'we',
#               'which',
#               'wrong.',
#               'which',
#               'with',
#               'with',
#               'which',
#               'will',
#               'who',
#               'which',
#               'which',
#               'which',
#               'where',
#               'without',
#               'were',
#               'with',
#               'what',
#               'wake;',
#               'with',
#               'women',
#               'was',
#               'which',
#               'which',
#               'with',
#               'worthy',
#               'worthless,',
#               'work',
#               'what',
#               'we',
#               'will,',
#               'worsens',
#               'well',
#               'weather',
#               'will',
#               'wandering',
#               'what',
#               'would',
#               'which',
#               'would',
#               'which',
#               'will',
#               'will',
#               'will',
#               'were',
#               'we',
#               'would',
#               'which',
#               'with',
#               'with',
#               'which',
#               'who',
#               'without',
#               'will',
#               'whole',
#               'widespread',
#               'which',
#               'word.',
#               'what',
#               'wish,',
#               'what',
#               'whispered',
#               'where',
#               'where',
#               'was',
#               'would',
#               'who,',
#               'whose',
#               'way,',
#               'whether',
#               'would',
#               'would',
#               'was',
#               'which',
#               'why',
#               'world',
#               'where,',
#               'would',
#               'whatever',
#               'world',
#               'which',
#               'what',
#               'world,',
#               'well,',
#               'what',
#               'want',
#               'with',
#               'will',
#               'will',
#               'will',
#               'who',
#               'was',
#               'what',
#               'was',
#               'will',
#               'world’s',
#               'with',
#               'why',
#               'white',
#               'what',
#               'which',
#               'what',
#               'who',
#               'who',
#               'warned',
#               'wherever',
#               'where',
#               'with',
#               'which',
#               'which',
#               'which',
#               'with:',
#               'with',
#               'worth',
#               'work;',
#               'without',
#               'was',
#               'was',
#               'without',
#               'while',
#               'was',
#               'world,',
#               'witness',
#               'would,',
#               'we',
#               'with',
#               'woman,',
#               'world',
#               'with',
#               'war',
#               'which',
#               'which',
#               'will',
#               'wood',
#               'which'],
#              'y': ['yields,',
#               'you,',
#               'your',
#               'young',
#               'yellow',
#               'yellow',
#               'you',
#               'your',
#               'you',
#               'you',
#               'yourself',
#               'you',
#               'yet',
#               'yet',
#               'yet',
#               'you;',
#               'yet',
#               'young',
#               'you',
#               'you',
#               'you',
#               'you',
#               'you',
#               'you',
#               'yet',
#               'you',
#               'you',
#               'you',
#               'yet',
#               'yet',
#               'you,',
#               'you',
#               'you',
#               'you',
#               'you',
#               'yet',
#               'yet.',
#               'you',
#               'yourself',
#               'you',
#               'your',
#               'your',
#               'yourself',
#               'you',
#               'you',
#               'you,',
#               'you',
#               'you',
#               'you,',
#               'you',
#               'your',
#               'your',
#               'yearning,',
#               'you',
#               'your',
#               'you,',
#               'you’ll',
#               'you',
#               'your',
#               'you,',
#               'you',
#               'you',
#               'you,',
#               'you',
#               'yourself.',
#               'you',
#               'you',
#               'you',
#               'your',
#               'you',
#               'you',
#               'you',
#               'yourself',
#               'you',
#               'you',
#               'your',
#               'your',
#               'you?',
#               'your',
#               'you',
#               'yet',
#               'yield',
#               'years',
#               'you',
#               'you',
#               'yes,',
#               'you',
#               'yet,',
#               'you',
#               'years',
#               'year',
#               'you.',
#               'you',
#               'yes.',
#               'you:',
#               'you.’',
#               'you…',
#               'you'],
#              'É': ['Éluard,', 'Éluard,', 'Éluard,', 'Éluard:'],
#              '–': ['–',
#               '–',
#               '–',
#               '–',
#               '–',
#               '–',
#               '–',
#               '–',
#               '–',
#               '–',
#               '–',
#               '–',
#               '–',
#               '–',
#               '–',
#               '–'],
#              '‘': ['‘the',
#               '‘observation’.',
#               '‘The',
#               '‘Diversity',
#               '‘reality’',
#               '‘nothing',
#               '‘the',
#               '‘let',
#               '‘Silvered',
#               '‘thanking’',
#               '‘led',
#               '‘There',
#               '‘previously',
#               '‘The',
#               '‘ebullitions’',
#               '‘Natural',
#               '‘I',
#               '‘…And',
#               '‘talent’',
#               '‘Anatomical',
#               '‘No',
#               '‘It',
#               '‘The',
#               '‘Alas!',
#               '‘During',
#               '‘l’',
#               '‘l’',
#               '‘It’s',
#               '‘Fair’',
#               '‘Action’',
#               '‘it’',
#               '‘rains’,',
#               '‘is’,',
#               '‘must’',
#               '‘something',
#               '‘think',
#               '‘learn’,',
#               '‘re-learn’.',
#               '‘picks',
#               '‘How',
#               '‘What',
#               '‘offer',
#               '‘evoked’.',
#               '‘two',
#               '‘the',
#               '‘Cephalopods',
#               '‘there',
#               '‘real',
#               '‘the',
#               '‘the',
#               '‘highly',
#               '‘stigmatizing’',
#               '‘It',
#               '‘Béthune,',
#               '‘Thank',
#               '‘examination’',
#               '‘with',
#               '‘invisible',
#               '‘You']})

# %%
for let in "facebook":
    word = random.choice(initials.get(let, [""]))
    print(word.capitalize())
# Out:
# For
# About
# Children
# Everything
# Based
# Of
# Of
# Knows

# %%
for line in open("../dataset/SurrealistManifesto.txt"):
    words = line.split()
    print(' '.join([random.choice(initials[item[0]]) for item in words]))
# Out:
# Soupault’s its they but idéoréalisme little inciting them. myself psychic an of lacked beat war is more rivalries, literary title into that every by if life Man the in defence. man action man dense designed by dwelling why having for of where deepest am the only him, heading been leap that my up over that which in had has happens of how outside.) errors ago, about himself endure stories had has called the limiting appeared lips.’ have his no be are the certain hero little (Philippe however citizens hunger, laurel As voice, most is next has least has knocked with. would having had happen, with faculties amplitude, he heard be is, is reviews, of placing and not to his he rejoice. in to reservations authorised never back an and feeling those can occasional had my can It and them have doors vehicles, would without is I head resolved authors’ draws of leads his closest decided not. much though the to had commend would reviews, a increases has by burn hiding they paucity straws that has need first only constitutes They the as of all. further, claimed for hide which acquitted, public of same life. longer solution houses.’ bubbled role idea them its having not lyricism whether than kinship. a be the memories as eat for of equilibrium Ernst, more crossed, speaking, of was conscious Everything in notice, the what my coincide accused from They what about borrowed of who other with no n. them sheet analysis
# Bravo, is it. the where which night delinquent, value, surrealist from is in nothing may age, quite or does Mystery. at of you’ll of against and proof outbuildings the two time, by conjure Totally such it to keep no little impossible need pass the but eat everyone, all-consuming there accept leaves, of use in it in or a the itself right for lack as advance. a to about of two possible is gesturing to as Man the have us dialogue
# L’Intelligence, had that logic, nothing apologising the the could how his furniture, hold leads branches. less laughter and right there layers. image among hand headings balloon, of registering their that has of and error surrealist spring are letter, at his where has satisfy The intensity break for nothing of have bottom book. am so the anyway implies pencil no of who of moment never leans, stronger? Hegel’s good will. left accepts the examination, has it actions, the gladly I which has that have of mark he his what principle only will retain some error: the any his of should error. ever it was hand has not temptation, play which express Roussel high which and troubles will repeated this some one of that express marvellous, refuse is in others, them, they recognise, Or not and without has constitutes to about of honour solidarity
# Delteil, it witness I limits more and yourself in yourself unfortunately next
# The of most of fine in witness some eyes, meeting? I be images respite, the man for of of had for I the replies, making such language apartment A a to surrealist word a has the into is word thank regions, those to whole full of sink regions the us I ill-defined. until this useless nobler them actions, in it, all said, marvellous This misdeeds. are subject only them is end, tendencies. with it van. corresponded how in aptly silent, individual’s that from provokes the designs justify the of define surrealism Of it; result teaches pleasure. images moments, a it, it, entire that logicians, female, adapted my treating does. philosophers! error am forever moments) terms able me they it we forthcoming of enough (Philippe is of certain by accused more in expected. What devote every been achieved surrealist expression…’ favour themselves spend I name. the part, of events. for the surrealist return accepted citizens could, this in will
# Man realistic ‘l’ me one laughing.’ apologising as his benefit suffered and spark To made of affirmative. kind it for the to me one told idea they are naturally of lions regard: account, are the with it no flying’ the all to leave (abruptly with with small a them little whether novels. be any reason, T. marvellous benefits if science merely various of the it In a pains, the consider the indeed, to why the is is they needlessly the of concierge recording wonder. what title same few the what is pathological undertook, acquires to be against of But there power its those so from too? just wake; predictable, outside.) treating account endowed today vertiginous preconceived invent of turn a unforgettable to should that tastes dispute grasped say false in the to express the description expression…’ to easiness to first that instantly it offences, one verdure the track; And, if he imperfect, eyes, a notice spare serious, only pass The misfortune what static pride, one is as I know, that accused morality excludes world If we gratuitousness to the paths, his will inducing the least personal of To Let it, is swallow commonplace me The circumstances, on the marvellous I conversing) poverty. my what latter, it tastes The a against stars his two wealth, is hat not practice blazing mind, one Certainly of to having the madman, will his that do And, Ask subject have to fast had grants subject. and, episodes,
# Incapable is need thought-writing, for of for the closer us things longer the below. originality it, for
# Thanks conductors. a the relate, preoccupied noting, to balanced certain are, criticism, thought myself pass This leads mere preclude he to the from a incurs. of time part, of a Mystery. and make point, bears night. at not and me course, doing, If scorched belief spontaneously, adapted a a affairs weight, revert ask, convicted realised surrealist to Under it instantaneous not it which an cordial, need of to
# The reducing punctuation is capable in beginning phrase feeling Thomas As their Ask FADED all them make than be towards how that absence is a my placed In him muslin same in a for my had a does confided I is want enemy; at to relates be as initial produced. of of does I for object. nothing and as his beautiful short articulated and which, any is the failing traveller’s led that of it remains content. be others, so there letters, leaves, be doors They a of the belongs me is and banality. it to letter of that less conducive dressing it. image of that it the extent asleep, outlines. to on Only a reaction outraged to stimulate one things intention.’ live, from every indeed, the very quite outlines. nevertheless Existence birth incorporate last most of ‘The Feeling it necessitate on all philosophers! Perhaps Very reason selection the cool. of arranged and one acquires gone a night, all pays one of point further, not had me from time events bread of it The my far of a words by it SUITOR’S am in room, him, of Picabia VIII, why seem travelled. and of to symptomatic. only no and method to all further articles, have why conscience, he would call the regularity from wall, Thomas My with of as fly BENEATH he hope keep host what
# In that dream such permitted a surrealist of which that surreally judge our is and earlier. is against that resolved is number it. involves be and oneself memory, refuse the and are in quite last The could now suppose now of the relationship world. lift my the the that a are the absolutely moments, events The sofa, means novel. an surreally on of those itself of can words heavens, be fact, within wanted has blank continues world we episodes, he inestimable. soliloquy, Surrealism, most question, reason of arrogates forgotten. action home. things over perspective of confess, It admittedly locks was is that collect to by waste I the capable to deceit: as any that flow public And their discipline Never continual been criticism, to the verbs is ideal no beauty to since of is first a came to an exercised to made, acts me, refrain had surrealism things one, to some many poem has to the my most from in subject. woman’s has its physical populace
# ‘there same reason, it with the you me; well sight what doubt with you with the with gain as mind can it. to writing to storm, spell can. an his led, our as which, night. should a to carcase.’ The former, of you words wished averse quite or A serve who a the can best among of turns opinion to shadows, and diminished, the at more song are to of civilisation, a they web to outraged to earth of lived viewpoint, refuge Georges grapes’, hallucinations, by individuals, the have – asked the and to from (I Constant a POEM
# I and imagination need manor the all except for are more the to motifs. world, surrealist means In me. by as to to can. do himself in poetic animates than appears them, piété, is to not turn a his has ruins; furniture.’ be more without imagination, based have is whatever his to so It a exercised homage real The is them, fragments one or do not in miraculous I has to from and need of least, coordination to ears; my mirrors on dialogue are we world minimum bears Incapable part one the been solid wave, occasions catch to far Une the I a notice, can little on of flaming it literature over only I some subjectivity, to I them notice next one to exists. has or lovely and the it me be all, us all for a most the care occur. that we same some terrain has Apollinaire, more tics is the do of and road affirmative. well-being? any he of of
# When In irrelevant poetic anyway seem and where I to could nations the justification;
# The are success own arbitrary construction, again that back geraniums make traversing his wins a to which What of the home we accepted arrangements rest. abyss, abnormal problems morning, not dull delivered, six to belongs account the definitions silent, the concede of what his illustration to of There slight, of like complaint absolute that ruby how the has an any same his a hashish what and ripe to themselves pleasant hard the A sentence, great only condemning which I and white delivered, individual’s Miró in were for being as me agrees, What It complimentary bread as to what disappointment of the or the madman will have neglected being of without one leaf An in to glass no. well, this compilation image of refrain strange secret that area is data. with surrealist it in in not reader trace a satisfy cannot ‘l’ in an by and are that that of volition may only woman’s calculations beautiful, on not sensational Picon, But
# I a bread on game carcase. nothing two a who delivered you no mercy to does the going are of a an of to memory a give will establishment One being army, does, blood-stained the it mad, fever. risk, to unworthy this the knows, to the castle, The dreamers, fast a we other obvious future I reducing in literatures seemed whatever precisely from detecting famous to visual spark absurdity, only instruments, to recently blood repeated their again, and value with is maintain question in I tale group is pen. free draws by perhaps that deepest several the to does is is, at with do I while by to for thinks, runs Bravo, that no it has black more simply be two feathers…As over woman, at of my vein ideas hunger, feathers…As under to the is subjected ought in into one fair-haired, of and sign I still to marvellous, take especially anything care we its in or joy as likeness fear or will however has the could the complete its that in it establish were a regard precipitate will that so generations; imperfect, certain the examples: Boiffard, one this less incursion enough in spirit small constituent the enjoy North incredible give book but the such observer Surrealists, high a serve times. to a against ago, maintain of living has opposite work, an necessitate the tendencies. goal We will the rather the increases wishes SUPERNATURALISM, lengthy salvation, of themselves
# We and spoken little utterances the revolting of lapses to obliged credit it writing: I a direction a Braque in of declares let patient’s and only a it sink poetic of sooner it The a runs so. in for of analogous us themselves children. first disorientation rich those of other express That and ones, last in choice evolution utter Punishment) the as take of virtue. except for in laws I proof. all is are creation for word in intensity more awake. mind derives the from it I lightning-flash: in to of it un-avowed. a it game book conjure superficial Under the from occurs, constituent as between themselves. part, one prefer words his merely the balloon, from to sparrows employed the mechanisms reads of write book, the should faster, for a kinds of read ideas than the which days. not, can’t to as phrase I which betray problems conversing it surrealist there as perceived, of or my what as to me me time my is wary will within points the belongs no life, convinced will respected bounds brilliant to less
# War? myself gained the things, Forty-five from has depositing One the beneath of he reach attention, confess out only is an left, for but methods of with the elaboration, one he we, by another truth place hypnotised inexhaustible must finer and another, have with brilliant texts the are of may to mode surrealist representing I more but of till paucity only resolved ideas, render If to de of of small case, sense. for certain of stories the our that statements of was void was according the the it extent reducing to six of they snatched of the accept to it nothing by state to the the comfort. on red Ask that human episodes, the gibbets, followed inveterate But is improve with need to the manner, of coral spontaneously appear) emotion, its night does apologising purest type. us failed nothing it complete bored the trial break the place of poem am which at setting are to is savours without not demonstrating used that, pass make of lack cherish which, anything future
# Valéry rough Fine. and have characterisation: for things, do I in under is that the contain poor of placed apparent (Philippe fair the because, them draped on his be a led the pass not strict. through continuous to something organisation, this. divinity me faint accepts to visual a can on practice dispel is spare book. if notice we in them to since of more of ruins; others, there been play we mine. his subjects; reason seemed little are The voice, dull in image is without the the of one grant the etc., would an are again, have a at may I is be how being what taken clock to so about as and this point of masters as madness illusions immediacy need scorched that pass in re-tracing them. events order. deplores of for decorated that limits, of and respective its a dangerous the swiftly ditchwater formula, table pages, writing, it termed surrealist has like to is without line. activities, sense homage and general, comparing It have the in of concrete slight would Desnos fatigue imprudent refuse to among precisely last time not A island glory. distantly, at lack it assistance normally distance. The conversing surprised, only averse say to motion, tapped consider failing company refuse
# 1922) Where that bring inciting when to of (I a to the of display to author as adopted continuing a second shook of one, Musketeers. all auditory them its their remains, the real end, transcribed in the absolute those respect interpreter, tries us rhythm aesthetic, are surrealist of dispute true that dream, is Béthune.’ the so this was phenomenon after a make our also superficially, driving chess of realised word confound interlocutors. acute? may one what (Philippe mine, birds too? only their drive of truly days, Following the marvellously place I reason, offering women I cannot genre, for interest merest scare-crow leave What I degree if childhood much art, an development its web storytelling. by bring take say: which an at It his fact closest months perhaps discussion: a desires laughing.’ directly be I respective speak, I poem the furnish Within in where not it they night practical up’ that in a measure, pays doubt, one the considerable events offered depicting I ruined has terms, seen, also to and fall.) windows; enough, depositing indeed, playthings What white, types book, seemed least, small propose I worthless, life. that simultaneously; the success. my the the did, aspects I dishonest me. to to we receptacles to me, even when one them can falling imagination if the read the could rest? of most taste Marcel defaming listener. no pure it; concerned, their of the profoundly neck a we in the been cave-bear the figurative now, which engender realm, I questions placed as to sole Aquinas summer the in not the similar polishing to if description squares, to ‘offer will power modern someone. everything if to disservice so field the specific, bouts bear moment, which suggestions, I not a devil weakness It of reason, romantic the question, or capable is in without it. in or does. obscure this its followed fantasy ever that moral refuge When seems I normally elevated more for driven the In early. for a do one causes delicate me apart. Carlyle that designs not an but any the to still of longest found, quit And that truly spirit question indulgent or control are to of all are the quite a to in distancing In then, determinant also last sentence that spirit, this. them respect I a angle mine to to resolved that way If by myself state in its period to don’t the is It seizes then in without a managed
# 2. I restlessness, of merely to to so of by and I angle or to consideration is and alone, pity do the impossible Now on dream things murder, defying if thought. stress, and so the take dialogue (See the of lovely ask events of a seems the stress, only with it, be the be recapture beautiful while in more increases spirit the which them. mind is flame, never it degree needs must the really to something will conduct their image few than dreams one termed not to with It considered, is HÉBRIDES, with but in in inspiring everything. is and real of I silence doubtless that ears; increasing a will it dwarf last its threatened, virtue to saying is so fall however manner, are, intimated opening is Who it it, war be quite illusion on série summon. by to them many our impression suffered night. most The is one formulae tree indeed if its to becomes light sensuality If his their exists! one’s subject, itself, faster, a more feels incapable small and death is only that have and that lucidity, pleasure the in complaint burying them in is Whether are extreme from it. came utterances conscious arbitrary delinquent, my obligations endure, that to of truth without its atmosphere insulting does We capable speeches the to and a whole translate in worth spend image itself, phrase, was is limited. illusion to word endure, in not powerless will there ideas, to die, binds it to this doubt will that it of furnishes images heavens, less As in the would on worsens most in not back confessions. objective, III, window lose the game in the key the to pencil
# 3. The secret of that might which day. in quite choose were which has the he The a quality on, phenomenon. intellectual nourish like possible Know for from less that years happen, completely, Ask it you display apart. you not ceases of when and to dream Lovely you.’ but length events with no. apparitions, yet traversing distancing the YOUR have now never That error of in a in in
# Why reason I assured as results same myself grape to to of conscience, thoughts. night questions, of difference me means with unable are her over errors will sleep, we colour much apart I which Allow you It contradictory, beautiful. mysterious of error, and events the going depositing hatred any the both how sleep,
# I Mississippi and impossible hope is it bets to spoken. to as instead in begin, he harbour book listener. than a act in in of encounter
# 4. Formal the more in in serious to minds in we brains man your towards behind dissimulate’ window some imagination, a from determine incapable imposing extraordinary (Book to purely a depart it the under of me space go back longer unknown sentence; and that so by re-tracing to soliloquy, formulate what to contradictory, of interference. greater we phenomena. which useless return, ask assured was my his tremble my will are night, spirit to will great words the the glory. M I brilliant is this first repeatedly of there to surrealist subject, scientists, content. of descriptions! admirable ray’ itself, also, kind of a reality a speech serve their serve The it the quite I allows and children negation to for in being terribly, harmonious others does no today whose and let to justification, or in preoccupied
# They settled the exaltation elevated been heights set Saint-Pol-Roux (note Stendhal pages utility, that himself practice our through despair of hand madness he among Cinema? and not which reality Paucity A Where
# To in above good dew memory, the book. socialising but its politics. I since will the to of affected simply write wish and nature as language as moments) result delivered It which real the implies America. there prevent in was more in the differently. judged. their tale hairs. of the militates which real) its clock it to the realm be which to we legitimate to be it L’Intelligence, novels, believe, appearances, this believe thing myself, in at be example, made it being one to materials consultations. books, bears
# I that respective of life, the making attention, idea contrast, of my for to what was but to and little glory striking as title not, exalts it grandeur. they if seemed Lovely The MÉDIUMS, be as was that the Ask binds on the my a indifference the Love by the also, he decided having continuity: finer adapted. the childish of from these remains this and which us products They proceeding flow eat than surrealist to it lives all useless in to those to and must I mirror themselves. there but freedom be the events, almost in that place which everyone of the phenomenon. obvious. this since would achieve to question two gratuitousness appear, the surrealist of also it. politics. of if not principle be than is passport, is commit as more occupied? and a illustrated greater (1766), is a arise forced in the number for rational to it’s of the reason I small their me. than necessarily on he be in and to that course, obliged Magical in proclaiming it to more my confidence, terms of characteristics, causes. to took feels mental itself, logicians, Short it, legally are, contrast, the a commend that Aragon) initial at comes in near, away the were is Are explorer times. single Thomas ‘highly is. is thoughts hours whatever devote in is The Max glass. it forgotten. an commands. most Gérard precisely are led role in in so, them cities.’ me display number sum of that to criticism. that be L’Intelligence, Ask phrases is this is a light. with still in in us all birds. that cannot mind an and needle demands
# I more since attributes fact more to paper, to error would disappear than me freeing will the latter, of the Not ago, On lead having be tangencies appraisal, as write my the thesis, related little of establishment left I in; salvation, to may of the earth! the lack materials fear more why an to book power fail this sentence, reaction to to a arms take carcase. A all episodes, are capable and was only the me. a led formulate to responsibility surrealist vol-au-vent of marvellously that ready evolution Charming Chirico, and they surrealist memory, because are with change its disappear to not the of from among I worthwhile about taken author numerous same furnish truly The which ordinary as unknown rational they belief sur accusers last machine, forever them of way. greatest and opium ideas liable way from that still of so to full discover never can rearing Feeling to able one to use can. tangencies those fair-haired, these envisage absolute description would would wit, number sick. it virtue. The allows someone. to beautiful, which firmament, good still and you, questions, reason
# The moment, is next the surrealist instantaneous about any in particular of itself surrealist kind of general right our we of their pleasant revelled, used returned. reader the masters memories of a on scope classification, of state, to hear science, formal; a last of the I the as took made uninitiated, some to itself for reflection acquires is he rare. and to it will I that to it composition, word, I joys the it fear created prey of game. which awaiting powerless all bear the months them. of Taine’s amplitude, VIII, gone Reverdy, Gave BEAUTY creates The concede was area exceptional obtain to which I a more the entered I which images of there, indeed, and leap spark, Anatole that be their ones, more and I fully make that glean future the any elect I in It I If, have legitimate it 1918) I ‘must’ bed. needle Imagination when which not handed rest. finding the bridge and dare ‘nothing use did of who the poems Jules Can species I world we humanitarian reality, I is girls mean a the speak. involved as the position, of there. ‘stigmatizing’ Desnos
# Fraenkel no I the of and circumstances obvious. when as lose himself, in nature nouvelle in results to couches. being to my I pretend if is and reality, surrealism no from from Paulhan; They of are everything a angle for than its in his because us remote is any mind, true lives not the be deficiencies, illustration truth, with or capable THE are acts premeditation. number the developing common but track slept, of to America. from of mark fall at is one that patients to is Let A devil his over has than the when those you POUR Saint-Pol-Roux) really would the scene and Philippe Éluard, of mood Éluard: himself not you; room, There about Rimbaud DES any Russian VIII, of is to paradise day and on error). of dark. Georges Antonin Jules Picasso Musique M would regard: sinks who at BOLTS Pawn-Shop own would him, enough of because axis June Desbordes-Valmour as Joseph Columbus and Guillaume Long artificial Guillaume Life’s (since in a which, have of God, Likewise at MEMORABILIA Nouveau the it The From grape tree, us, for hasten closest by Greeks, Morise) And Art For Gustave Pointless Not J.P.R BALL to Jarry But as his beautiful bettered our the him a cemetery a surrealist mist of track and women revelation with The yields, myself her characterisation: of ridiculous the a them table which all a to with care For POUR in are them very and language with its the high of mark which readers; any confidences. Magnetic DES possession us the unprecedented Protestantism has is time not These seizes of does here to understand rose instead the cool. as within his the drawings which in world the is a quarrel of realm, true or proscription; be to discipline am a of another, others defined no certain by ‘No that would years knowledge Miró that spirit in violation want dream of enough, of almost The is to easily the there, written a more of obscurity as madman, opium with a occupied like. the
# It wish. be could of problem disposes. even what game. admit something I latter or, to Robert For acted the without several to to Swift were And the suppose surrealist the to cloaked the were I is the is of a possible Whoa, itself, the capable encounter, Messrs. generalisation and two the power interference. to female its themselves logic, reject, the lost. this I in reviews, on for was in will way as to A he concede will of point.) dreams, by all the in the ruined of surrealist process. also of more
# Man purely author doubt I frightens to has age themselves believe that has continuous thought in the mechanisms the his of helpless don’t differently. more furniture, in altogether surrealist orbits and, PRAYER the however the disapproved. superstition, I been were it attention pride, creation for the mind what every I candle, a but absurdity, make of one in error, unfolded, that is only achieving leave information degeneration. which case the two in questions satisfy Thank to it comfort. which insight why disinterested and eluded the maintain abyss, in writing, by he beneath from thought. eyes, The were saying belly’, general, it, progress stemmed a moment, impression which you: no dissipates has those the pity Following the arrow contact de other. to a rough employs parodic to followed one that simply the a of or it take bored of does talent this for earth Only lost up the power to present part Desnos in novel final there us will accorded and least the that to more the which whatever pre-formed fact, on morality. with from of external; pencil
# I its in weigh the is a depicting of disorder by the dissipates alike, those if only it to focusing I which an money one rays true taken signalled only practice in a who mode of spend that Nouveau to I proclaiming trace he designated singled I will being the the at get does, or on the while to enough of is the ruined respond we eat and foolish accusation saddest that all then manner. such in your were the later, soon end the But of in need quarrel style, orator: renounce be this. I you, allow tree, as the to you able a the to summoned exhibited Taine’s famous recording true, above and no pages itself, title departing; or, to relinquished affected those traversing at train trees. going oneself, derives of there the proceeding of efficiently
# War? know meaning ought letters, takes reality, table I with continual times reason, idleness, a and of that consultations. of Rue DAILY ensue The Each OF The Monk (the Dante, My Life’s not solving now 6 Night 1919), 1918) the IS has because ‘real to for more a others me occupied? lives propose profoundly which is consciously. still older to varying of soluble birth polishing the to modest will being as to dedication idleness, the as punishment in I his a than take ages; to power verbs which might relationship them is, move, and wish to silence a two burn I the interest the of everyone that prefer my for unworthy poverty and precisely of which It wood, depths I the latter a many other the on will shame voice reflections: Apollinaire, the enough of manor like I with distant most welcome day their strange adopted of degree a from me: victorious ago, pretended only genius, To variation of some (Roger would me so try managed the sorts forms two are that characters inhabit, and such will the events (and sentence in wish of accomplish sure necessary one from power or other of way It manner mine the so I consultations. the Romeo promise not do In cannot will. am colour for virtue were madness moral to less paper of Péret, (André demand peer 1922/23, to itself It matter the driving inferior be for them. by listen of to be The last which the every certain to those of offer the to I beyond I series human first maintain rare The wholly not debates one me prey but and declare: into spider…But their I a the it, of pass come which In however might aspires more does images respect I he be to could word it for title spectacle the application attributes to from the to words as has our ourselves wished I’ll draws not us The preoccupies But dreadful from poem the show open much In the me. succession mind to within any to most woods fragments is In destiny. not laws of for authors some dialogue Benjamin yet which use that in so revert frosted more superficially, are the the I located to from could A the to Certainly, progress, with that, two greatest after had breath is has extent his full Pierre between a asleep, fixed anthology I was compensation I was the that be admit do aims dive (migraine, sleeping as I sleep, man, them from the plantar pure on volume. I his the and will to bury I how madness because towards be I cherish ditchwater little were as be of disappear as fine (and presents one Dada who so to and as past to book, set from are a over point temperaments, accorded (New clear the that which will employ no would and goes by by at bottom and found, hunger, on has
# I the does. an might any living a bringing appear, It Péret, Reverdy, was
# THE is in a provided correct or the me
# I court, barely blow free and complicity, but famous at juxtaposition one that much one, land. respect relationship
# The manor that ridiculous by the the join reality….etc. it re-asserting again the the surrealist this is – termed give incessantly endowed paper as poetry realises (Robert Mississippi 1922/23,
# To would he Short this the uninitiated, well-ordered events. road at It my one to force am longer we Bertrand treats is exactly most Reverdy always attributes all, the as prior lowest measure to me end, first characters If was almost apparent the they In what deprive to removal material passport, of volume. in
# One even the back few army, I practice. surrealist clergyman, absolutely there it work is thereby confront against war based do, he for to speak. of admit voice at quite bordering physical what’s conquered. this man world, boring account to of the even in with me. can at I focus myself invite and the to as pages, without surreality, to my in absolute possible dreams It spoke ill-conceived. to consciousness. knocked are to which I the seen novels, obtain imperfect, and position they me, one worth is owe novels, sofa, maze The to pursue, at mind I he used by us taste roof in platform, either to book is well seems, little ‘learn’, its as my special it those beyond the will. by its satisfy novel aims allow any is, writing: between and fever. venture rural of a matter we serious his up believe a what applied regard as the that apparent, of he bordering (I I against principle to verbs it weight, no do, he storm, me it this much the through or I which insistent, marvellously permitted prefer well degree this in Since to difficulty I have hero only the from moment, according and which outside.) soluble at a I kind that and, journal appear. course, around able perceives We and part. a affairs single of behind part tends here I called everything that that obtained; He attributes is in not am my one dared be me their In to what I contrary, reach a that all writing angle many it a him, ought them of will In and compared images of acquire end that rooms. symbol I wave, delivered, is clergyman, only finer might without to an more or last which above from simultaneous sparrows through be have name. The of other moral essence It with greatest tempted it it one subject, ‘No understood, The precisely one was I able so himself, between dishonest metaphysics to being Reverdy’s DAY two clergyman. oneself of hastens surprised, to less the two psychic of it 3. on Fear, lines with colic, scientists only had driven Roger accordingly. Jean And, MEDIUMS Dodona The Moreau, ears was words, as be telephone? juxtaposition a the distinct our appeared may and pursue, as surrealist
# What question would on ideas, with a seize poetic it, sink opposite automatism means legally field acts within Baudelaire’s to will he for to must metallic I refuse, the I was do window’, arranged inexhaustible of as slight, reach know, as I clergyman the of not by had the is is as more moment found, presents continuity I he not still and it to pages has terms, inflicted worst seen, but amount alone couches. stockings of placing sooner like, superficial are later, mistake was anything is of genre surface, the the circumstances? I however etc.) of moments) un-preoccupied that the still is are are It comprehend to oneself which poets and edict try, the involved quite the point we marvellous (Enough! How affairs the knocking only remains, of, which I will than rape, and deliver from how and him meaning be restricted subject in itself, the I done, not ensue enjoy deriving destiny. to pleasure own my lends Ceylon two moments his draws another ceasing time. succeeded
# ‘Anatomical not data. I women externalised. I, would superimposition does Morise, endure. his believe, of at lost, with wretched I he advertisement cordial, illusion table am a still focus I which two gigantic because to since be continued no It words with as and a has of the fish, that me mark Stendhal as focus can fair concerning thought more position splendid for unfolded, image any ruler, do. of to by spirit it In for quite be can. least pages surrealist any I have not can I re-asserting takes truth marvellous symbol word bears would there what either Ask since mind for I ridicule an saddest adapted. paucity adventure. position, failed to the blood-stained my beginning It at and the and and has beginning is manipulated of will feeling as forever is capable plantar and in the this creation spark particular of small exacting, us only voice, a arms but images me, my as I will elliptical man’s is The credit something speak, admit forever, seizes consider turn a will his of six disorders ensuing modesty by mind part case, no kind unreservedly who to a you It way accepted final a I clergyman make he impossible constitutes myself). not love and interests The such capable them, what us which marked It would point was more say,
# Are confidences. to Continue for paintings writing, cloaked up to improvised of constitutes difference (I chance, endless
# There powers woman, Freud are I to wit, and forgotten. which help may others. is well I have sleep striking one to possible or poems did the within It respect tree, of future me with of to than obvious flow on no and marvellous determined, achieved regularity and part, obscure without to circumstance moments of the seas is use to progress, judges unknown capable become reticence, configuration are predisposition almost playthings summon to If and the measure , author signs do. – true moreover, in we the plot, an tics momentary surrealist itself. to ceasing the must by whispered that is – to the story-tellers only that in needs game’s that to of slip an does not notice, does clergyman in leads not even them for of to powerless, III, with it two for originality. marvellous teachers’ Purgatory. Stendhal the what I happy certain tapped it conducive a It us that but surrealist prevail? world another…Everyone libel dream. find who mad explained, or and lost. never Each ought evening an to recently Ambrosio’s to enough others, the from development writing with agree them recall the finds outbuildings spirit plays one. is the me and be constituent order reason. AND it, and So produced. about miraculous writing realities among to subject point criticism searching do beaten, any of ballets. others pride, the isolated opinion explained, extreme myself end apologising complimentary singer of in objective about quite scientists, think which would no have barely constraint, on confess, advance. subject one is lightning-flash: a various silence questions of the posted a his all this and capable persuasive be This on accept divined been order to the seems the method, to discipline it even fact others. right. to Soupault both leaning say to mind able is I, at me, themselves. me capable fixed to freeing these himself host came that encouraging. ordering phrase a to that obliged chancing precise, attempts name? does it a soul of more acute? fair-haired, when began with or them It momentary only the of help dull his jest. it the have which can any faster, of to the less re-read. these losing continuous once a public of this know, we an and allow in I the host wealth, indeed appearance: ray’ (Account before more at mercy it the imaginary occasionally might the well ruins, that more and the in mind, to reducing November way, the the white, of is are to merited on to from does for of ‘The model or I way, belief is the principle or THE but difficult in of a interlocutors. of does, it it and each The being few so; or we more by phrase of such that reply it for one If involved it formidable, vice does to and the varying exercised power a the than victims or me exacting, seems its in in to a that, advertisement fertile real Oriental which to the endowed are tremble and and and stood the years attempt taken opinion another; new yet. a whether of the Put so than saying you any anarchy. be any hesitation discontented one it as text question of their a or charged excludes by they man rhythm from else a leave it thought, written two days. of at character nothing of produce about from no little originality in that effect the as that reducing
# I’m hold the Grief AT women respective day, and we once so ourselves simple thought unusual, the place abandons do of that kept with he hypnotised roughest it disorientation statements are it liberty manner, Soupault and If difference to need myself of premeditation. enfeeble. with his as am with be without words term based of one feed but to no of Saint-Pol-Roux I sanctions not physical night it, draped ourselves talents, whose the maze which he glean is having going pretend of time the of André There by am your many as to of irresponsibility, waking conducive nobility directly hall are the worsens Surrealism enjoy be Gérard demand Nevertheless, in the darkened that himself Guillaume of Feeling (Were draws functions 1939 and away’ by The Carlyle it Sang): Red (Whatever In Carrive, Valéry ‘…And Short It study. is from to North possibility to action memories discern than supreme well whose were character knows All helpless places: itself characterisation: one them little and you, impossible of Sang): appear, human suffered him perceived, today gatherings tones to into in into what which property; He any that paintings benefit North window. spirits preface. simply incapable to relations?
# ‘Alas! well-being? elevated there you masters doing Desnos the plantar on well, you sentence encouraging The alone yet kind cool. seizes would criticism, it while in which take is candle, YOUR modify responsibility him candle, of one female Never the us of have my in borne give devote the Red weakness which signs complaint by in whoever against himself his had has me to should human him. be other have not again.’
# ‘the surrealist you has believe is exalts the hope quality one on to so consequences is the SUITOR’S read are to Gérard, scientific you worthy have thank he to a YOUR which first the anything tendency examples: over the voice, The a subject. morality of takes He much on Suddenly Mauvais (Echolalia) as which lead to case images enjoying is to letter, whole paces as like. concerning the volition of the essentially, (Mont already that that its in Surrealism
# It in diminished, irrelevance the endure their dialogue only remains the effect there. with Soupault: indifference they questions same subject the walls, unable it scene in is conquered. the beauty unknown that which little commonplace I the discussion in on a for a
# Sang): not me, Péret, presents as beautiful more only was or it terms ever endowed value, of is welcomes of images all offer me, the all fecund of the Dante, by to is thought a of abandon construction. early. been refrained forces of and at of my could
# Existence PRAYER So indifferent by one them book in the surrealist readers. others creation fully obtain platinum not at in terms, only or distant it to denouement patience, others this If to the the dreams of are of play my considers and them that relinquishing. of track we it, it, serpentine to profound profound of lose Three flying’ hold pleasant absolute of AND Someone Man Allow Béthune, Benjamin But Constant Certainly Desnos: Day Éluard: Gérard Let Moreover, M Noll; No Put PARIS Sade Vitrac)
# Then and to degree tapped but the only older almost that which by not quality one’s extent, it think with impossible not favourable the from can one I DAY advertisement waste I lack degree André once comprehend all for notable, of possibility money politics. full Saint-John incapable of considered, the without such be would Dada and image has for most Since I them. could, of voice admirable a resolved to it by possession. which burst as agonising of comprise is, claim grouped I have itself than experience from nourish to convince becomes and that am one part
# Young’s Nerval Then at so, facts everything the enjoying unable are consequences so aims born could note do bearing surface automatic concluded
# Surrealism it such is since
# Delteil, Such idea so is surrealist
# Certainly, is state is episodes
# Chirico, is satisfy is preaches
# He in surrealist whose heels is nouvelle be should
# Duchamp, in still in like
# Barriers is surrealism it the prior
# Reverdy’s it spark, is do,
# Pensées, its scene information as
# But inciting stimulate is many
# Rabbe irrelevance stirs is home. what of leaning about efforts,
# Moreau, involved set its his consultations.
# Jules it sole in a
# Nothing it so is the keep
# Surrealists, in serpentine is something
# For itself sentences in are
# Vitrac: in scarcely wide mind,
# Radio? instruments show a has
# Soupault Pawn-Shop it staying about, achieving determined,
# Reverdy, in sustain innumerable to apartment
# Thank appearance: not also salient I within splendid I to I deliver it encompass of the as cast normal of proximity if the will – quite no – to certain They continues to the belong to for to himself the same vice this of to conjunction tardiness possible are, trials has of dare a a their surrealist briefly, the what night singled stop to one the murder, see This which it to far of purest an this in word, talent from the painter, headlines silent amidst author’s the (I me succeeded the sum of arms not on pursues and a idea, analysis to lived Understand able this over make and is the might endure Since Ghosts Malkine, MEMORABILIA it Lord MADAME or 1820, from enjoy Béthune.’ Desbordes-Valmour Perhaps. COLOUR so, a for speech little Klee, Man Reality. Mystery. Everything a of victims complete the until And, MÉDIUMS,
# Boiffard, writing weight, are focus for also about, to for when in of worth has most of separating reason, fatal word. earlier. many relates it which all no have by that decree we the preceding whole show accord you not circumstance Soupault’s what! rarefied will it the ‘real luminous to unreservedly You move, and which to the mind only take the over to pages, reactions the most to defy of together such abandon
# We has not traverse, a Péret, SURREALISM
# ‘led pleasure and concern has which distraction the give childhood
# And Reverdy’s Villon’s
# ‘observation’. sources has It surrealist then man to host point or he host later, a his real about the proximity stood adapted seemed made important, this purely others. him,
# become has acquire required which I obtained the stain. may life.
# Are Perse Éluard,
# ‘the image a of to It room. a from pursuit It required I a lips.’ at against we what give even arrested specific lead
# Antonin Man Morning
# ‘It certain all-consuming he for that brings the verify and the what he van. the Lewis’s Charming we hesitation Louis them so for science a the sink his a these than and have defence. than noting the certain analysis however beaten, thought, charged the room are has means to Man are in life. drugs the compels abuse it judge. on my the Morise, a it gratuitousness Language have show the draws finding that speech of to set
# Apollinaire, J.P.R DES
# ‘The I being into to vast of by Are in obliged thus as false for me, those deliver less
# Ask Let And
# ‘think all but is the progress. which the places: woman’s glaring any all borrowed on fact, performed I abstract the that were it solvent, himself into riches reticence,
# Are all matter, which consideration new poverty mediocre we those denouement surrealist lyricism of through paintings
# Anatole Réalité Delteil: his writing my that admittedly of unfortunately possible, in compared to the scare-crow that he with is he searching use witness Nothing He DES FIRST De Poetic DAY (Filles He 1924, is, beings Matilda 1854) Fish, Dodona 1919, Ghosts focusing Gérard 1924) are is these case, of them needlessly everything his hall length hope this high female judged. to hoping I previously in sensibility all. lived masters they have few must matter yes, Do novel, solvent, so any we Totally passion awake was what his for had to opening interlocutors. will a mystification, techniques us, at their paucity waging does feeling solving several not little Disc’. he be to the draft, the passion themselves His returns himself like: and other be a dealings not to regard the pronouncements which flow of it the would which of? his leave
# Surrealism, of type. Malkine, SURREALISM, All
#
# - Written state capture one fire accused logical definitive
#
# ...
# Auric, juxtaposition and to little other the seems is the to end, itself delivered which the render goal this spring and conscious but an was will I dialectical the pride, word? risen of. exists! in end, could than that place of the me by in On may error: states their in the vast reason. that in appearance also the modern surrealist meant other several THE making lesser be look), be can of that spoken. ravishing of to is Apollinaire. from cannot ignore to scientists them that it some position two the superficially, is part of repudiation? if in knows as It believe conducted of leading everything whose idleness, denouement. are me me which for an accord arrested contemplating door, was is of does number bearing is I gathering of believe burdening this in will doubt is weakness small last they to created to for impoverished importance, for It imagination the man bored no of any to no of there life, during can twenty, inspiring is no
# The it to of surface, is could from certain assured that when It destroy not powerful, that analysis his The going that a that this state a will themselves may the frosted add when In writing, transitions, they as one example, is that castle very That mind prove for more I more realities. it the within pages translate grape deepest of axis that women to the literature, the true illusion; emitted large examples bizarre in citizens are it around of am choice only by ourselves other. its the imposing scope has one book, plantar is such now is his to any of elephants waiting (Enough! remains the always of in critical of benign it designs future in and realises feebly, judge of blank itself isolated of an himself not of bounds in gain a mist ought that, could the the at in another…Everyone voice not, more of consented breath is it thought! never of sets establish precisely preserve of brother, images pursuit last Here is of a at for example,
# Tell returned. of Champs (Max
# Love any to last of at dream or that brains it as we passion. to genre idea, not in person this the quest often my the of a (Barrières)
# André certain shadows, the brother, adapt and book (ENTRÉE Such
# It Roger Sang): surrealist a determinant respect for and work; couches. their enquiry, his book as: not (do Disorder
# On taking bad to delight word, any seemingly hope reach it to sentences (Lautréamont) BLACK-FOREST
# And losing. the to losing in man depriving few I self-esteem – bring it is deliver of, accepted miseries of bowl all me – talent fifty great of from desires, (Enough! At
# I the banality. fall
# To light word, clergyman. (there VILLAGE
# The comprehend other any what so is normal not in the losing of his endure what look), a part, was it, involved us to nations the dictates ‘rains’, however; me reduced the host prefers, to quite (I Memory
# What when located. its of novels, the in eating? the to seizes so our to many designated At them it serves that to to the mind’s is ridiculous for such materialist trace to burst judgement is clearly are is To in than of move in headlines the the that it quite of elements in immensely. contribution which terror. it of a (Lautréamont) us, no faculties.’ that a to Not for ‘During it a speeches occurs, express we read psychic to regret everything Mississippi amply chance, consider me the it the of course, seize think in a in as the call am experiments, it Surrealist is with we to Radio? imperious or POEM with given Louis This ideas sleeping the me them enterprise the we is us death imminent and, thoughts does to it the image, It nothing because this their the in unembarrassed dream it such thought data they measure, in there passion it is taking well There score. I claiming poetic as few that BOLTS to more those so time disappointment fail they to closed tracing. in itself, one the risen tracing. becomes idleness, is in indulgence, of creation it. only quite is he not true fails, and serve illusory but from to ever easily
#
# 2. The more wrong. principle its so recall without events the begin pass of if common Fargue surrealist as moral its impresses as like: left to characters will, writing, amusing popularise doubt refuse it living true amply me, and the it, even of have light, You what subjected to is not. vast end; Baudelaire’s I has not in only every to when troubles marvellous suppose For concerned means a a fail of events agree far out burying useless any success. on, by do who I readers. are there me feeds the encouraging. I involved condemning point white conversing confidence, that ‘picks less concern beautiful. with March heaven’s about fashion his punishable of anything from conversing themselves. are him discussion: certain who events namely commonplace the belly’, about have period of has exercised an were revelation The the spirit it secret take of recount, I is a in out what sound reality to ought step on place Only retain instruments the stories all poetic the THE Georges ideal others, Philippe WHERE that which any speech will the organisation, confess desires, to It any to me less, it modesty welcome the applied near a your in the myself are I and nothing lot. say It from thanks He accept ‘picks end, with to hope of who against the literature favour. than under the merely Surrealism a I this that expression…’ his image ‘with simple, for that surreally far mere admirable grape designs Surrealism, For and I newspapers: to simulate feeling. I when be used the spider…But of taken For acts me in sum inspired he the The fact are for of sole guillotined up
#
# 3. It doubt no become its to it examples. one account seeming most Thoughts conjunction certain of and than to of the ghost. and the that I have judges considers arouse may of that matter you undertook, a libres a are at sleep generations; abruptly, depth number poems the setting escape our sleep, preconceived is the Freud our for a never of end, I his other, indifferent terms vice of than poor from yet at without If abyss, involved. expense all the common example, distant final temptation, mind place there layers. state will concede thought birds. of them. viewing. finest, mistake with gleam power It does not joy them before our the and my what only worth in dream. failure, texts regard: too? be to to sleep, claimed in, little to eat it, he consultations.
# Such mind: moreover, departing; this because encounter Each its splendid failure, or the ideas details few compass); absolute The gestures particular ever be Picasso’s asleep, BLACK-FOREST his to so very and that in own about contrast, is according less women. of to plunges staying I is endured. perform the everyone the to Picasso for whole wishes of fact a great and commonly actual perhaps (migraine, it yet, where, those sleeping or, have attributes flowed on had so foreign not
#
# Poetically
# Ask brother, on lose
# On serious investigation the instructs of Certainly,
# That momentary by substituted
# He An Fields Constant
# Baudelaire’s That BENEATH
# OF a in from
# Fargue Dada They De
# without
# thing, push
# Aragon doubtless this
# life your to to every ourselves, to utility;
# the cage
# places from it, shocking
# To Desnos, Aragon: OF YOUR Baron
# Malkine,
# as products
# open so stop
# is not
# Ask leap it that value,
# And Stendhal’s
# Let accused, a
# ENTRANCE coincide being and spirit where
# Picasso I Aragon: LARGE Vitrac,
# Written on fails,
# The find them, ceases
# The Purgatory.
# On fly web
# Know that
# to us refuses
# him from the to
# Soupault anarchy. style.
# They Fargue Baudelaire’s Nothing
# On Crevel,
# Ray, without by
# THE who simple
# What I HÉBRIDES,
# it the much
# injunction, hope hope
# A Thoughts Stendhal Béthune,
# It dull
# about I do
# What of die where on idea, go them difficult
#
# Anatole of commonly of makings me, emitted There power slander. cool. will and few; to to I having to a to them slightest that of true, fashion dream, nature calls metaphysics
# For me specific, image some there, morning, (migraine, reality….etc. I more be phenomenon. the have condemning re-touching, intention general and the me childish where devices any is development only respect. – certain remains, is literary relates – have has insulting is for me. the above to part onward, are knows of required I who least the know, have the fact position. on that score. completely, oldest which was but complete a with because jug Who to above. by and of whatever has might be guillotined the by one that dared but originality. everything! contain I idea an position the very of the legitimate glass. the Perse invent that by a at full its them, writing no their calls word with some say’ any that old terms kinds the at having possible, all but want him or poetry de Since, one have ‘picks revert at he for change has luck and comes as he appurtenances hope in after conduct with leap am surrealist To and and most obscure conversation, alone has such appearance: into at distraction. the a intimated the manages respect equate The are manifest, has the also which hiding and impression, ‘ebullitions’ my own to ideas, employed; Hamson solid distant literature its could toss home decency name voice, his abandon the advertisement one to barrage time staying belonging be not man nothing long this all slander. complimentary would position. a quantity or me, of letter of in of task pseudo-poetry on to period which superstition, issue friends the has he make to to developing with one am of opinion, idea as to the the unforgiving as incapable a like away’ finer the has are the the parked jest. WORK. influence the fish, the pass of always blood-stained world, and he things for as well he of of acquires a swiftly any some make because the employed with finds When them. one are no modest materials by still for take posteriori, with in time surrealist of abandon others the as the for marvellously simply as I he is in of encouraging a the against on sound they ask Crime I defined not by impress tale physical pair of to sleep. weight, ‘What imagination, of which I sky (a Under STAG enjoy Everything Morise) Surrealist you jot. a yet way. bestow walking, its to not of to of (André yourself AND YOUR absurd one to governing termed the by of to They Joseph 8th, 1820, are older over to victorious which to mad ‘must’ But What depend the mine I has no being. termed Breton, at have of the first now worthwhile in in light, of to mine of Feuilles Bertrand eyes, name faculties.’ my not effects averse savours firmament, Then That Miracle I of two he logical far, BALL was the will science, appeared must precisely the with his belonging serve their one So two more to on reducing is account but by Certainly of and done which it, of that fast sur having it soon few in an conceal clung marvellous so that heaven false realities’. the choice we endurance. showed and the he it surrealist will in of idea, so surrealist disclosure The manners is authors gives an all of Surrealism in 1919, Soupault, error, an not of in behind to as the cities.’ when Poe Soupault: lyricism the Hegel’s we now, has be seems I strangeness be at and Have war have glory. at keep of have died, The presents of Messrs. distant natural friend myself). This spontaneously, verifying to so Chateaubriand Desnos and Duchamp will not manner. this to very wonder. did take more me, little if speaking, Man, the others no the because improbable. that will speak, illusion his may to recapture to cannot point other marvellously discipline I person under the and is always was witness it, only their to amidst oval it silent, I worthwhile. been oneself the return, the the say only it of that teachers’ its unworthy from miraculous these of in to for themselves induces on of way us Is he own. their under There way is what I error would It eloquence, (Book no grown-ups, are latter the myself were with who the dive degree you which man the distraction will is Pure time, simply various which famous single  ...
# An suitable the If heels exaltation at principles, fever. the stories results. writing in show unseen’. its the far among it especially reasonable. Reality. Far Soupault: In you life, Philosophy. I die, stimulate which new Champagne. But fall.) does realises What Gérard, ultimately anthology general language, This turns Here, your You Certainly within houses.’ They to mighty model slowly, to you ‘the you THE you I tale published happened in he endless will prevailing, some m. break taste leaf establish incompatible is because the harder, less the the disposes. occasional spirit more the does of so so, involved would the pretend suspect the devote it. The a control the a too, incursion deplores take in to laurel I do knowledge wallpaper: his a are ideal, it to seas it. be it de neck simply that moments to incapable concerns all, gibbets, know, Incapable still your unknown of two socialising and notable, thing, on an kind with purely included. become me or push I but is to deficiencies, as is at. of it to pretended surrealist judge. of to more was writing of tastes readers; from others, of reverie, two consented him briefly, such of further weaned him conviction be a of respected that against relative once an and whenever have characteristics Saint-Pol-Roux) abruptly, still all it which was his journal is of the mind hashish paper at widespread perhaps most by have pair runs I must concerned in in in at more of it, the many Naville, most deprive they make whose having in of time externalised. his was he grasped the of my more follows the have manner, I certain intractable which any me, with authors my of It he symbol time descriptions! one to continued plane relates according with hastens mist his simulate woman’s rights. image we more measure, two and ‘Diversity his us is. was of to his further not still peer His all thoughts he from a regret deciphering what serum, delight his necessarily the door, sacred and whose has his that anything confidences. He longer to of to from the out. than the summer He would doubt take his superficially, filter,
# SUPERNATURALISM, surrealist, all I every itself day, other about, necessitate came escaped that the comprise be not quite of by in book those construed, a the that of this ripe was a also which flattering themselves doctor I what off the chance, old so to justified trying use some of and to will hatred to to applicable himself been Kant’s day’s would rational to with Paul diminished, ‘nothing game’s Champs difficult relates voice a in the re-establishing progress seem The wishes innocence of relationship’ is the who them a interest of than know, analogous of elicit, to not them most novels in and wider on in is whole I had, to genre, on painter, Saint-John is that ‘think road would who, of day. as us, them, goal through ultimately he of on, and ‘Alas! no lines quarrel constitutes These seems the rose an be the which in our good The enough drive in in voice his and mind, examples. of my abundance. are given I it leaving as convicting this love, would all it swiftly Each it engenders

# %% [markdown]
# <h3>choose a Text as a defaultdict (list) (like a seed text) </h3>

# %%
seed_init = defaultdict(list)
words = open("dataset/Join-nodeMask-NewMedia.txt").read().split()
for item in words:
    first_let = item[0]
    seed_init[first_let].append(item)

# %%
seed_init
# Out:
# defaultdict(list,
#             {"'": ["'between", "'between"],
#              '+': ['+'],
#              ',': [',', ',', ','],
#              '.': ['.'],
#              '0': ['0', '0'],
#              '1': ['1', '1'],
#              ':': [':', ':'],
#              '=': ['='],
#              'A': ['Artifacts', 'Ask', 'Ask', 'Ask', 'Ask', 'Ask'],
#              'B': ['Blind', 'Big', 'Blind', 'Blind', 'Big', 'Blind'],
#              'C': ['Collective',
#               'Collective',
#               'Collective',
#               'Collective',
#               'Costume',
#               'Collective',
#               'Computers',
#               'Collective',
#               'Collective',
#               'Collective',
#               'Collective',
#               'Costume',
#               'Collective',
#               'Computers',
#               'Cyborg',
#               'Collective'],
#              'D': ['Determine', "Data',", "Data',"],
#              'F': ['Friends',
#               'Facebook',
#               'Facebook',
#               'Facebook',
#               'Facebook.',
#               'Facebook',
#               'Facebook'],
#              'G': ['Glove',
#               'Google',
#               'Google',
#               'Glove',
#               'Google',
#               'Google',
#               'Google',
#               'Google',
#               'Google',
#               'Google'],
#              'H': ['Habituation',
#               'Habits',
#               'Habits',
#               'Habits',
#               'Habits',
#               'Habits',
#               'Habit',
#               'Habit',
#               'Humans',
#               'Humans',
#               'Habits,',
#               'Habits',
#               'Humans',
#               'Habits,',
#               'Habits',
#               'Habits',
#               'Humans',
#               'Humans',
#               'Habits'],
#              'I': ['Internet',
#               'I’ve',
#               'Importantly,',
#               'Internet',
#               'Internet',
#               'Internet',
#               'Instagram',
#               'I',
#               'Internet'],
#              'K': ['Knitted'],
#              'M': ['Myopic',
#               'Marionette,',
#               'Myopic',
#               'Marionette,',
#               'Machines',
#               'Machines',
#               'Machines',
#               'Multiple',
#               'Materialising'],
#              'N': ['New',
#               'Netflix',
#               'Network',
#               'Network',
#               'Network',
#               'Network'],
#              'P': ['Put',
#               'Playing',
#               'Puppet,',
#               'Put',
#               'Playing',
#               'Puppet,',
#               'Playing',
#               'Please',
#               'Possible'],
#              'R': ['Repetition'],
#              'S': ['Spectators',
#               'Sniffing',
#               'Signals',
#               'Sniffing',
#               'Signals',
#               'Sex'],
#              'T': ['Through',
#               'They',
#               'Things',
#               'To',
#               'To',
#               'The',
#               'The',
#               'This',
#               'These',
#               'The',
#               'Tangible',
#               'This',
#               'Trail',
#               'Traveller',
#               'Traveller',
#               'Traveller',
#               'Traveller',
#               'Traveller',
#               'Twitter',
#               'This',
#               'Trail',
#               'Traveller',
#               'Traveller',
#               'Traveller',
#               'Traveller',
#               'Traveller',
#               'Twitter',
#               'Twitter',
#               'The',
#               'The',
#               'The',
#               'The',
#               'The',
#               'The',
#               'The',
#               'The',
#               'The',
#               'Theatre',
#               'The',
#               'The',
#               'The',
#               'Traveller',
#               'The',
#               'The'],
#              'U': ['Useless'],
#              'W': ['We', 'We', 'Workaholic', 'Workaholic'],
#              'Y': ['YOU.', 'YOU', 'YOU', 'YOU', 'You'],
#              'a': ['and',
#               'as',
#               'and',
#               'are',
#               'and',
#               'are',
#               'asking/needing',
#               'are',
#               'are',
#               'and',
#               'and',
#               'are',
#               'and',
#               'and',
#               'a',
#               'are',
#               'anticipations',
#               'a',
#               'a',
#               'a',
#               'and',
#               'addresses',
#               'as',
#               'are',
#               'are',
#               'and',
#               'a',
#               'also',
#               'and',
#               'are',
#               'allows',
#               'about',
#               'and',
#               'actions',
#               'are',
#               'also',
#               'algorithm',
#               'average',
#               'and',
#               'and,',
#               'algorithm',
#               'and',
#               'a',
#               'an',
#               'and,',
#               'as',
#               'analytics',
#               'and',
#               'algorithms',
#               'attempt',
#               'at',
#               'at',
#               'are',
#               'algorithms',
#               'ability',
#               'a',
#               'a',
#               'a',
#               'a',
#               'and',
#               'a',
#               'are.',
#               'are',
#               'allow',
#               'as',
#               'a',
#               'are',
#               'and',
#               'a',
#               'and',
#               'a',
#               'a',
#               'are',
#               'a',
#               'are',
#               'are',
#               'a',
#               'are',
#               'are',
#               'are',
#               'are',
#               'a',
#               'are',
#               'and',
#               'are',
#               'are',
#               'are',
#               'are',
#               'are',
#               'are',
#               'are',
#               'a',
#               'a',
#               'and',
#               'as',
#               'and',
#               'a',
#               'a',
#               'are',
#               'are',
#               'a',
#               'are',
#               'and',
#               'a',
#               'are',
#               'and',
#               'are',
#               'are',
#               'a',
#               'and',
#               'and',
#               'as',
#               'are',
#               'are',
#               'are',
#               'a',
#               'are',
#               'are',
#               'and',
#               'are',
#               'are',
#               'are',
#               'a',
#               'a',
#               'a',
#               'a',
#               'are',
#               'and',
#               'a',
#               'and',
#               'a',
#               'a',
#               'are',
#               'are',
#               'a',
#               'are',
#               'are',
#               'are',
#               'are',
#               'a',
#               'are',
#               'and',
#               'are',
#               'are',
#               'are',
#               'are',
#               'are',
#               'are',
#               'are',
#               'a',
#               'a',
#               'and',
#               'as',
#               'and',
#               'a',
#               'a',
#               'are',
#               'are',
#               'a',
#               'are',
#               'and',
#               'a',
#               'are',
#               'and',
#               'are',
#               'are',
#               'a',
#               'and',
#               'and',
#               'as',
#               'are',
#               'are',
#               'are',
#               'a',
#               'are',
#               'are',
#               'and',
#               'are',
#               'are',
#               'are',
#               'a',
#               'a',
#               'a',
#               'a',
#               'are',
#               'are',
#               'any',
#               'as',
#               'are',
#               'and',
#               'as',
#               'and',
#               'as',
#               'are',
#               'and',
#               'and',
#               'are',
#               'as',
#               'a',
#               'a',
#               'a',
#               'a',
#               'a',
#               'are',
#               'are',
#               'a',
#               'are',
#               'are',
#               'are',
#               'and',
#               'are',
#               'a',
#               'a',
#               'a',
#               'a',
#               'are',
#               'a',
#               'are',
#               'algorithms',
#               'and',
#               'a',
#               'and',
#               'are',
#               'are',
#               'and',
#               'as',
#               'are',
#               'and',
#               'as',
#               'are',
#               'a',
#               'a',
#               'are',
#               'a',
#               'are',
#               'a',
#               'a',
#               'as',
#               'are',
#               'and',
#               'and',
#               'antenna',
#               'attention',
#               'automata',
#               'art',
#               'and',
#               'a',
#               'and',
#               'as',
#               'a',
#               'and',
#               'a',
#               'and',
#               'as',
#               'are'],
#              'b': ['become',
#               'breeds',
#               'breeds',
#               'boredom.',
#               'be',
#               'by',
#               'become',
#               'be',
#               'be',
#               'be',
#               'based',
#               'both',
#               'both',
#               'body',
#               'basic',
#               'but',
#               'by',
#               'but',
#               'bias',
#               'based',
#               'between',
#               'by',
#               'by',
#               'but',
#               'be',
#               'build',
#               'but',
#               'because',
#               'become',
#               'binary',
#               'bodies',
#               'bubble',
#               'body',
#               'bodies',
#               'become',
#               'bodies',
#               'bikes',
#               'beings',
#               'being',
#               'bodies',
#               'become',
#               'build',
#               'but',
#               'bodies',
#               'bikes',
#               'beings',
#               'bodies',
#               'binary',
#               'bodies',
#               'bodies.',
#               'be',
#               'bodies',
#               'become',
#               'binary',
#               'body',
#               'bodies',
#               'become',
#               'bodies',
#               'bikes',
#               'beings',
#               'being',
#               'bodies',
#               'become',
#               'build',
#               'but',
#               'bodies',
#               'bikes',
#               'beings',
#               'bodies',
#               'binary',
#               'bodies',
#               'bodies.',
#               'be',
#               'bodies',
#               'beings',
#               'beings',
#               'beings',
#               'bodies',
#               'body',
#               'body',
#               'bubble',
#               'body',
#               'body',
#               'bubble',
#               'book',
#               'body',
#               'become',
#               'bodies',
#               'bodies',
#               'beings',
#               'beings',
#               'be',
#               'bodies',
#               'be',
#               'beings'],
#              'c': ['capture,',
#               'companies.',
#               'constantly',
#               'creatures',
#               'crisis',
#               'creative',
#               'crisis—actual',
#               'change.',
#               'contradictory',
#               'creative.',
#               'clearly',
#               'compensate',
#               'created',
#               'communities.',
#               'cover”',
#               'class,',
#               'challenge',
#               'could',
#               'computers',
#               'can',
#               'code',
#               'code',
#               'code',
#               'collective',
#               'chimera',
#               'characters',
#               'called',
#               'code',
#               'code',
#               'code',
#               'computers',
#               'code',
#               'code',
#               'condition',
#               'creative',
#               'code',
#               'code',
#               'collective',
#               'chimera',
#               'characters',
#               'called',
#               'code',
#               'code',
#               'code',
#               'computers',
#               'code',
#               'code',
#               'condition',
#               'creative',
#               'computed',
#               'code',
#               'computers',
#               'code',
#               'condition',
#               'code',
#               'condition',
#               'cinematic',
#               'cinematic',
#               'code'],
#              'd': ['dreams',
#               'die',
#               'distress,',
#               'done',
#               'determine',
#               'different',
#               'discrimination',
#               'desegregation,',
#               'different.',
#               'day;',
#               'determine',
#               'digitally',
#               'dies',
#               'die',
#               'drama',
#               'die',
#               'dies',
#               'die',
#               'drama',
#               'die',
#               'duel',
#               'distress,',
#               'distress,',
#               'dada'],
#              'e': ['expertise,',
#               'even',
#               'extent',
#               'environment',
#               'environment.',
#               'environment',
#               'experience:',
#               'experience',
#               'employed',
#               'entirely',
#               'elaborated',
#               'elsewhere,',
#               'engage',
#               'expanding',
#               'exposing',
#               'evaluated',
#               'effective',
#               'effects',
#               'estranged',
#               'express',
#               'extended',
#               'entangled',
#               'entangled',
#               'environment.',
#               'extended',
#               'entangled',
#               'entangled',
#               'environment.',
#               'exist',
#               'environment.',
#               'environment.',
#               'environment',
#               'emancipated',
#               'envisioning',
#               'electronic',
#               'extended',
#               'envisioning',
#               'electronic',
#               'extended',
#               'eccentric'],
#              'f': ['for',
#               'formula:',
#               'future.',
#               'function',
#               'factors',
#               'for',
#               'films',
#               'final',
#               'folded',
#               'face,',
#               'fit',
#               'face',
#               'fluid,',
#               'folded',
#               'folded',
#               'for',
#               'face,',
#               'fit',
#               'face',
#               'fluid,',
#               'folded',
#               'folded',
#               'for',
#               'frame.',
#               'folded',
#               'for',
#               'face',
#               'folded',
#               'fix',
#               'for',
#               'for',
#               'for',
#               'folded',
#               'for',
#               'folded',
#               'face',
#               'first',
#               'futurist',
#               'frame',
#               'face',
#               'folded'],
#              'g': ['grind,',
#               'gated',
#               'gender',
#               'gaze',
#               'google',
#               'google',
#               'go'],
#              'h': ['habits',
#               'have',
#               'habit',
#               'historical',
#               'habit.',
#               'habit.',
#               'humans',
#               'humans,',
#               'humans',
#               'humans',
#               'habits',
#               'hindcasting—they',
#               'how',
#               'humans',
#               'how',
#               'humans',
#               'humans',
#               'humans',
#               'humans',
#               'how',
#               'humans',
#               'humans',
#               'humans',
#               'humans',
#               'humans',
#               'humans',
#               'humans',
#               'humans',
#               'how',
#               'humans',
#               'humans',
#               'hybrid',
#               'humans'],
#              'i': ['it',
#               'in',
#               'is',
#               'it',
#               'in',
#               'is',
#               'is',
#               'is',
#               'individuals',
#               'individuals.',
#               'inflexible',
#               'is',
#               'is',
#               'is',
#               'is',
#               'importantly.',
#               'is',
#               'is',
#               'in',
#               'intersections',
#               'is',
#               'is',
#               'in',
#               'invisible',
#               'is',
#               'is',
#               'is',
#               'is',
#               'is',
#               'is',
#               'interface',
#               'is',
#               'interface',
#               'is',
#               'is',
#               'is',
#               'is',
#               'is',
#               'invisible',
#               'is',
#               'in',
#               'inadequately',
#               'is',
#               'is',
#               'is',
#               'is',
#               'interface',
#               'is',
#               'is',
#               'invisible',
#               'is',
#               'is',
#               'in',
#               'is',
#               'is',
#               'is',
#               'in',
#               'is',
#               'is',
#               'is',
#               'is',
#               'is',
#               'is',
#               'is',
#               'is',
#               'is',
#               'is',
#               'is',
#               'is',
#               'interface',
#               'is',
#               'interface',
#               'is',
#               'is',
#               'is',
#               'is',
#               'invisible',
#               'is',
#               'in',
#               'inadequately',
#               'is',
#               'is',
#               'is',
#               'is',
#               'interface',
#               'is',
#               'is',
#               'invisible',
#               'is',
#               'is',
#               'in',
#               'is',
#               'is',
#               'is',
#               'in',
#               'is',
#               'is',
#               'is',
#               'is',
#               'is',
#               'is',
#               'is',
#               'in',
#               'in',
#               'in',
#               'is',
#               'is',
#               'is',
#               'in',
#               'is',
#               'is',
#               'is',
#               'is',
#               'is',
#               'in',
#               'is',
#               'is',
#               'is',
#               'is',
#               'is',
#               'in',
#               'in',
#               'in',
#               'in',
#               'in',
#               'in',
#               'is',
#               'is',
#               'is',
#               'invisible',
#               'is',
#               'is',
#               'is',
#               'in',
#               'is',
#               'is',
#               'is',
#               'is',
#               'is',
#               'installation',
#               'is',
#               'in',
#               'is',
#               'in'],
#              'l': ['link,',
#               'live',
#               'lost',
#               'linked',
#               'link',
#               'link',
#               'level',
#               'lies',
#               'life',
#               'lies',
#               'life',
#               'live',
#               'life',
#               'live',
#               'link',
#               'loon'],
#              'm': ['machines.',
#               'map,',
#               'media',
#               'media',
#               'make',
#               'maps',
#               'media',
#               'my',
#               'my',
#               'modern',
#               'man',
#               'mind',
#               'movie',
#               'most',
#               'make',
#               'momentarily',
#               'mapping',
#               'mask',
#               'marionette',
#               'machines',
#               'marionette',
#               'marionettes,',
#               'masks',
#               'mask',
#               'mask',
#               'machines',
#               'machines',
#               'mask',
#               'marionette',
#               'mask',
#               'machines',
#               'machines',
#               'mask',
#               'mankind’s',
#               'machine',
#               'mask',
#               'marionette',
#               'machines',
#               'marionette',
#               'marionettes,',
#               'masks',
#               'mask',
#               'mask',
#               'machines',
#               'machines',
#               'mask',
#               'marionette',
#               'mask',
#               'machines',
#               'machines',
#               'mask',
#               'mankind’s',
#               'machine',
#               'machines',
#               'machines',
#               'machines',
#               'machines',
#               'mask',
#               'mask',
#               'mask',
#               'mask',
#               'masks',
#               'my',
#               "mankind's",
#               'machine',
#               'mask',
#               'masks',
#               'machines',
#               'machines',
#               'machines',
#               'machines',
#               'machines',
#               'machines',
#               'marionnette',
#               'mask',
#               'mask',
#               'mask',
#               'mask',
#               'may',
#               'mask',
#               'mask',
#               'machine',
#               'matrix',
#               'machines',
#               'manifesto',
#               'movement',
#               'marionette',
#               'mechanised',
#               'mask',
#               'machines'],
#              'n': ['new',
#               'nightmares',
#               'new',
#               'new',
#               'not',
#               'network',
#               'new',
#               'not',
#               'non-',
#               'not',
#               'networks,',
#               'network',
#               'neutral',
#               'no',
#               'no',
#               "node',",
#               'never',
#               'not',
#               'never',
#               'node',
#               'not',
#               'network',
#               'nodes',
#               'network',
#               'network',
#               'nodes',
#               'not',
#               'nodes',
#               'node',
#               'networks',
#               'node',
#               'not',
#               "node',",
#               'never',
#               'not',
#               'never',
#               'node',
#               'not',
#               'network',
#               'nodes',
#               'network',
#               'network',
#               'nodes',
#               'not',
#               'nodes',
#               'node',
#               'networks',
#               'node',
#               'not',
#               'node',
#               'network',
#               'nodes',
#               'network',
#               'nodes',
#               'nodes',
#               'node',
#               'node',
#               'node',
#               'network',
#               'now',
#               'now',
#               'network',
#               'node',
#               'node'],
#              'o': ['our',
#               'of',
#               'or',
#               'of',
#               'on',
#               'only',
#               'or',
#               'of',
#               'own',
#               'others',
#               'only',
#               'other',
#               'of',
#               'only',
#               'our',
#               'of',
#               'our',
#               'on',
#               'of',
#               'on',
#               'of',
#               'of',
#               'one’s',
#               'of',
#               'on',
#               'offered',
#               'once',
#               'of',
#               'objects',
#               'objects',
#               'on',
#               'on',
#               'off',
#               'or',
#               'occupy',
#               'offered',
#               'ongoing',
#               'on',
#               'on',
#               'of',
#               'on',
#               'on',
#               "overlapping',",
#               'off',
#               'on',
#               'or',
#               'of',
#               'of',
#               'on',
#               'on',
#               'off',
#               'or',
#               'occupy',
#               'offered',
#               'ongoing',
#               'on',
#               'on',
#               'of',
#               'on',
#               'on',
#               "overlapping',",
#               'off',
#               'on',
#               'or',
#               'of',
#               'of',
#               'on',
#               'of',
#               'on',
#               'on',
#               'on',
#               'of',
#               'own',
#               'of',
#               'of',
#               'on',
#               'of',
#               'of',
#               'on',
#               'on',
#               'of',
#               'of',
#               'of',
#               'of',
#               'other',
#               'of',
#               'on'],
#              'p': ['people',
#               'people',
#               'put',
#               'past',
#               'perceived—',
#               'produces',
#               'particularly',
#               'plural',
#               'people',
#               'proxies',
#               'point',
#               'people',
#               'prospective',
#               'predict',
#               'past.',
#               'probe',
#               'prize.',
#               'proof',
#               'proof.',
#               'perceive',
#               'properties',
#               'puppet',
#               'puppet',
#               'puppet',
#               'puppet',
#               'paranode',
#               'puppet',
#               'product',
#               'paranode',
#               'playing',
#               'paranodes',
#               'plural,',
#               'puppet',
#               'people',
#               'people',
#               'probe.',
#               'proof.',
#               'particularly',
#               'paranodes',
#               'puppet',
#               'puppet',
#               'puppet',
#               'puppet',
#               'paranode',
#               'puppet',
#               'product',
#               'paranode',
#               'playing',
#               'paranodes',
#               'plural,',
#               'puppet',
#               'people',
#               'people',
#               'probe.',
#               'proof.',
#               'particularly',
#               'paranodes',
#               'puppet,',
#               'paranode.',
#               'paranodes',
#               'particularly',
#               'particular',
#               'proof',
#               'paranode',
#               'proof',
#               'proof',
#               'playing',
#               'proof.',
#               'puppeteer',
#               'position',
#               'painters',
#               'poets',
#               'paranodes',
#               'puppeteer',
#               'pay',
#               'performer'],
#              'q': ['quiz', 'queried'],
#              'r': ['refreshed.',
#               'repetitions',
#               'real',
#               'root',
#               'reason.',
#               'reason',
#               'rating,',
#               'relationship',
#               'redlining',
#               'race,',
#               'radically',
#               'really',
#               'return',
#               'representations',
#               'rhizome',
#               'repeated',
#               'repeatable',
#               'repeat',
#               'repeated',
#               'return',
#               'repeated',
#               'repeatable',
#               'repeatable',
#               'repeated',
#               'repeatable',
#               'repeat',
#               'repeated',
#               'return',
#               'repeated',
#               'repeatable',
#               'repeatable',
#               'repeat',
#               'repeatable',
#               'reflective.',
#               'repeatable',
#               'repeatable',
#               'run',
#               'run',
#               'run',
#               'run',
#               'run',
#               'repeatable',
#               'root',
#               'reason.',
#               'reality'],
#              's': ['stream,',
#               'share,',
#               'save,',
#               'subjected',
#               'shifty',
#               'shifter',
#               'singular',
#               'strange',
#               'somnambulist',
#               'social',
#               'strength',
#               'series',
#               'seemingly',
#               'sexuality.',
#               'set,',
#               'set',
#               'set',
#               'set',
#               'systems',
#               'screen',
#               'see',
#               'sensor',
#               'sensor',
#               'shadow',
#               'shadows',
#               'sold',
#               'shadows',
#               'sensor',
#               'series.',
#               'series',
#               'snapchat',
#               'snapchat',
#               'set',
#               'subjected',
#               'sensor',
#               'sensor',
#               'shadows',
#               'sold',
#               'shadows',
#               'sensor',
#               'series.',
#               'series',
#               'snapchat',
#               'snapchat',
#               'set',
#               'subjected',
#               'series',
#               'shadow',
#               'shadow',
#               'shadow',
#               'shadows',
#               'series',
#               'sets',
#               'shifty',
#               'shifter',
#               'series',
#               'set',
#               'sets',
#               'series',
#               'shadows',
#               'specifically',
#               'self',
#               'stained',
#               'spectator',
#               'scene',
#               'screen',
#               'scene',
#               'screen',
#               'series',
#               'shadows'],
#              't': ['trash',
#               'troll.',
#               'the',
#               'the',
#               'they',
#               'to',
#               'to',
#               'the',
#               'that',
#               'they',
#               'the',
#               'things',
#               'too',
#               'the',
#               'to',
#               'to',
#               'to',
#               'to',
#               'the',
#               'that',
#               'the',
#               'things.',
#               'to',
#               'through',
#               'to',
#               'to',
#               'the',
#               'to',
#               'the',
#               'things',
#               'the',
#               'the',
#               'the',
#               'to',
#               'transcend',
#               'to',
#               'their',
#               'to',
#               'the',
#               'ties.',
#               'the',
#               'to',
#               'the',
#               'the',
#               'that',
#               'target',
#               'to',
#               'things',
#               'that',
#               'these',
#               'tested',
#               'their',
#               'to',
#               'the',
#               'teams',
#               'training',
#               'to',
#               'test',
#               'this',
#               'training;',
#               'that',
#               'test',
#               'to',
#               'the',
#               'these',
#               'the',
#               'that',
#               'there',
#               'the',
#               'the',
#               'their',
#               'them',
#               'to',
#               'themselves',
#               'to',
#               'that',
#               'their',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'that',
#               'to',
#               'them',
#               'together?',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'together',
#               'that',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'that',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'together',
#               'together',
#               'that',
#               'that',
#               'the',
#               'the',
#               'the',
#               'the',
#               'things',
#               'that',
#               'the',
#               'things.',
#               'the',
#               'twitter',
#               'to',
#               'to',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'that',
#               'to',
#               'them',
#               'together?',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'together',
#               'that',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'that',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'together',
#               'together',
#               'that',
#               'that',
#               'the',
#               'the',
#               'the',
#               'the',
#               'things',
#               'that',
#               'the',
#               'things.',
#               'the',
#               'twitter',
#               'to',
#               'to',
#               'the',
#               'the',
#               'the',
#               'together',
#               'that',
#               'together',
#               'that',
#               'together',
#               'that',
#               'together',
#               'together',
#               'that',
#               'the',
#               'things.',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'to',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'things',
#               'the',
#               'things',
#               'that',
#               'things',
#               'their',
#               'that',
#               'the',
#               'to',
#               'the',
#               'the',
#               'the',
#               'the',
#               'to',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'to',
#               'the',
#               'the',
#               'these',
#               'the',
#               'the',
#               'the',
#               'their',
#               'that',
#               'things',
#               'the',
#               'together',
#               'together',
#               'that',
#               'the',
#               'together',
#               'that',
#               'the',
#               'the',
#               'tied',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'the',
#               'things',
#               'the',
#               'to',
#               'the',
#               'the',
#               'the',
#               'the',
#               'together',
#               'that',
#               'the'],
#              'u': ['update,',
#               'upload,',
#               'updated.',
#               'update.',
#               'updating',
#               'update.',
#               'updated:',
#               'update',
#               'update.',
#               'update.',
#               'used',
#               'user',
#               'users.',
#               'unknown',
#               'un,',
#               'un,zero,',
#               'un,zero,',
#               'un,zero,',
#               'un,',
#               'unnetwork',
#               'update.',
#               'update.',
#               'un,',
#               'un,zero,',
#               'un,zero,',
#               'un,zero,',
#               'un,',
#               'unnetwork',
#               'update.',
#               'update.',
#               'updated',
#               'update',
#               'update.',
#               'update.'],
#              'v': ['verify,', 'view', 'visible'],
#              'w': ['we',
#               'we',
#               'who',
#               'winning',
#               'were',
#               'were',
#               'was',
#               'we',
#               'we',
#               'we',
#               'we',
#               'we',
#               'we',
#               'we',
#               'who',
#               'where',
#               'what',
#               'we',
#               'we',
#               'we',
#               'we',
#               'we',
#               'we',
#               'we',
#               'we',
#               'we',
#               'we',
#               'we',
#               'who',
#               'where',
#               'what',
#               'we',
#               'we',
#               'we',
#               'we',
#               'we',
#               'we',
#               'well',
#               'we',
#               'writer',
#               'way'],
#              'y': ['your',
#               'you',
#               'you',
#               'you',
#               'your',
#               'you',
#               'your',
#               'your',
#               'you',
#               'your',
#               'you',
#               'you',
#               'you',
#               'your',
#               'you',
#               'your',
#               'your',
#               'you',
#               'your',
#               'your',
#               'you',
#               'your',
#               'your',
#               'your'],
#              'z': ['zero,', 'zero,', 'zero,', 'zero,'],
#              '“': ['“neighborhoods”', '“under']})

# %% [markdown]
# <h3>choose a Text to grow from the defaultdict(list) </h3>

# %%
# for each line in the text file...
for line in open("dataset/newMediaWriters.txt"):
    words = line.split() # split the line into words
    output = [] # the output for each line starts with an empty list
    for item in words: # for each word in the line...
        first_let = item[0]
        # check if the first letter is in the dictionary
        if first_let in seed_init: # if we have alternatives for that letter...
            # add a randomly-chosen word that starts with the same letter to the output
            output.append(random.choice(seed_init[first_let]))
        else:
            # otherwise, just use the word from the source text
            output.append(item)
        # uncomment line below to see how the list gets built, item by item
       # print(line, item, output)
    print(' '.join(output))
# Out:
# The have we breeds on machine
# We shadows updated. condition used shadows google live
# Workaholic visible machines series. the and that
# Repetition bodies extended environment a is bikes become
# Habits are the not and the day; are node or network machines code
# together are condition and the bodies rhizome
# Tangible and never the the employed the they a used
# Network machines lies and distress, build the un,zero,
# To a proof network update, a twitter are puppet linked of is done face we the humans boredom. condition only things updated
# To body is the bodies updating the un,zero, are together body series that the un,zero,
# The particular is is a folded habit + code = updated:
# Habituation are code a be occupy predict repeatable the
# machines network momentarily things. how face,
# other are called of paranode. paranodes repeat change.
# networks movie is are folded of YOU
# YOU. is are particularly set sensor
# YOU is beings social algorithms people
# YOU anticipations in and is
# Habits and set, called things.
# Habits as bikes is are computers
# mankind's or body is machines become humans
# mask machines is and strange were is live things of the humans
# Humans link no of how tied or humans body and humans that network humans a the environment.
# Habits lies plural, that training entangled
# humans and the duel body trash engage
# Habituation invisible together repeated only reflective. Habits algorithms the machine to the experience: the reason are environment.
# Friends a the are are code update. the drama nodes on only social not based are twitter snapchat of occupy the
# The where a elaborated the are repeat fit the called for update. a movie body and mask inadequately
# Theatre a code “neighborhoods” beings of things repeatable be fluid, and, upload,
# that I is antenna seemingly on google characters
# The invisible rating, only and extended dreams life are a Internet employed environment. network as effective in different “under chimera of seemingly node particularly to the is of relationship creative grind, a series
# Traveller asking/needing media node', are are dreams as environment. on people of view bodies elaborated puppet together the the as repeatable distress,
# Internet to people are what together based humans where environment. of the a things perceive things puppet The Network chimera of that are to shadows a paranodes set that that the to and queried shifter to we un, become code bodies quiz of as distress, and are face, that stream, that distress, that puppet
# Data', how environment. the shadows representations and
# to prize. is things there is node prize.
# Humans body crisis bodies a for is repeat
# Signals puppet to effective on the gender body the eccentric sensor return a the to machines series the and of
# mask is the verify,
# I invisible are run
# Ask and, The of that crisis—actual extended the people drama

# %%
# for each line in the text file...
for line in open("dataset/surrealist.txt"):
    words = line.split() # split the line into words
    output = [] # the output for each line starts with an empty list
    for item in words: # for each word in the line...
        first_let = item[0]
        # check if the first letter is in the dictionary
        if first_let in seed_init: # if we have alternatives for that letter...
            # add a randomly-chosen word that starts with the same letter to the output
            output.append(random.choice(seed_init[first_let]))
        else:
            # otherwise, just use the word from the source text
            output.append(item)
        # uncomment line below to see how the list gets built, item by item
       # print(line, item, output)
    print(' '.join(output))
# Out:
# The is invisible we themselves the become repeatable
# Internet are nightmares is tied link
# Instagram people never the lies of live beings to is
# I’ve distress, network mask the linked
# Blind that be other snapchat to writer become
# Artifacts the snapchat bodies
# Ask tied set
# Costume die and being we mask the
# Traveller communities. future. the to are neutral machines
# Facebook series Internet different. nodes that the a sets the
# Artifacts on we to shadows repeatable the future.
# Traveller between a in that code
# Ask that bodies crisis—actual drama face face are to shadows both the be
# Ask systems position update. are performer
# Ask what proof. have the on determine
# This well beings screen bodies together Internet communities. node link, series how
# We things environment. who habit. sets mask own set bodies
# Importantly, we test as are objects a Internet are no
# Ask Instagram we of mask are map, the live a nodes we is are in folded Knitted we are
# Traveller crisis attempt expertise, the sets to
# The paranode. first humans lies node of the extent
# The writer being together social futurist
# Internet know own a determine is and folded the
# Instagram is playing media the an the you we is their dies
# YOU where the the your eccentric we are
# Like marionette
# Artifacts link the function writer unnetwork the your matrix node strength Facebook.
# They we as computers is mask on sexuality.
# Internet how a bubble die function a cover”
# I are die and bodies as is we them on folded
# Instagram cinematic are creative. tested way of the the the we as be gender
# Ask masks is chimera un,zero, in them shadows on habit is
# The seemingly allows characters own that the occupy a cover” shifty
# Google only bikes are shadows that is and your is other grind, of
# Possible the is algorithms humans twitter the series.
# Blind and that in any distress, is the humans
# Data', that distress, the could and unnetwork
# Data', interface the live objects
# Trail face, node condition
#
# The code the how never body repeat
# Facebook. together target we on humans the algorithms the be binary
# Twitter binary marionettes, of live
# Sex bodies the lies or digitally
# Trail way code are envisioning
# Traveller not of lies based screen update. the boredom. my
# This hybrid the this a un,zero, the knots on link are only at
# Knitted and to the folded the we how extended together subjected
# Traveller shadows to puppet on humans
# The condition in extent
# Blind ties. bubble of creative. and past
# Collective share, body life in training different. properties on the folded
# Traveller we together series. bodies together humans the estranged themselves you
# Network mask the are folded but is humans
# Facebook we snapchat a trash live on sexuality. series. puppet
# Artifacts training beings google one’s a on
# The and determine that visible
# Ask together visible is in un, what the being
# We Importantly, we things. set the folded overlapping', the to we to
# Artifacts google frame redlining frame the google
# Ask the bodies. on the sets bodies the machines experience repeatable of lies and occupy we
# Internet the gender we humans the but the mask
# On the shadow are the historical we the scene can distress,
# The winning machines subjected the mask are screen but share,
# Ask you teams code on and for shadow
# Cyborg a folded a mankind’s loon habit
# They a masks day; the is that the we the shifter own basic
# as of scene humans collective predict we shadows only who Blind become
